# %%
from unet import UNet
from unet import TiedUNet
from torchsummary import summary
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = UNet(n_channels=1, n_classes=15, bilinear=True).to(device)
summary(model, input_size=(1, 160, 192))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 160, 192]             640
#        BatchNorm2d-2         [-1, 64, 160, 192]             128
#               ReLU-3         [-1, 64, 160, 192]               0
#             Conv2d-4         [-1, 64, 160, 192]          36,928
#        BatchNorm2d-5         [-1, 64, 160, 192]             128
#               ReLU-6         [-1, 64, 160, 192]               0
#         DoubleConv-7         [-1, 64, 160, 192]               0
#          MaxPool2d-8           [-1, 64, 80, 96]               0
#             Conv2d-9          [-1, 128, 80, 96]          73,856
#       BatchNorm2d-10          [-1, 128, 80, 96]             256
#              ReLU-11          [-1, 128, 80, 96]               0
#            Conv2d-12          [-1, 128, 80, 96]         147,584
#       BatchNorm2d-13          [-1, 128, 80, 96]             256
#              ReLU-14          [-1, 128, 80, 96]               0
#        DoubleConv-15          [-1, 128, 80, 96]               0
#              Down-16          [-1, 128, 80, 96]               0
#         MaxPool2d-17          [-1, 128, 40, 48]               0
#            Conv2d-18          [-1, 256, 40, 48]         295,168
#       BatchNorm2d-19          [-1, 256, 40, 48]             512
#              ReLU-20          [-1, 256, 40, 48]               0
#            Conv2d-21          [-1, 256, 40, 48]         590,080
#       BatchNorm2d-22          [-1, 256, 40, 48]             512
#              ReLU-23          [-1, 256, 40, 48]               0
#        DoubleConv-24          [-1, 256, 40, 48]               0
#              Down-25          [-1, 256, 40, 48]               0
#         MaxPool2d-26          [-1, 256, 20, 24]               0
#            Conv2d-27          [-1, 512, 20, 24]       1,180,160
#       BatchNorm2d-28          [-1, 512, 20, 24]           1,024
#              ReLU-29          [-1, 512, 20, 24]               0
#            Conv2d-30          [-1, 512, 20, 24]       2,359,808
#       BatchNorm2d-31          [-1, 512, 20, 24]           1,024
#              ReLU-32          [-1, 512, 20, 24]               0
#        DoubleConv-33          [-1, 512, 20, 24]               0
#              Down-34          [-1, 512, 20, 24]               0
#         MaxPool2d-35          [-1, 512, 10, 12]               0
#            Conv2d-36          [-1, 512, 10, 12]       2,359,808
#       BatchNorm2d-37          [-1, 512, 10, 12]           1,024
#              ReLU-38          [-1, 512, 10, 12]               0
#            Conv2d-39          [-1, 512, 10, 12]       2,359,808
#       BatchNorm2d-40          [-1, 512, 10, 12]           1,024
#              ReLU-41          [-1, 512, 10, 12]               0
#        DoubleConv-42          [-1, 512, 10, 12]               0
#              Down-43          [-1, 512, 10, 12]               0
#          Upsample-44          [-1, 512, 20, 24]               0
#            Conv2d-45          [-1, 512, 20, 24]       4,719,104
#       BatchNorm2d-46          [-1, 512, 20, 24]           1,024
#              ReLU-47          [-1, 512, 20, 24]               0
#            Conv2d-48          [-1, 256, 20, 24]       1,179,904
#       BatchNorm2d-49          [-1, 256, 20, 24]             512
#              ReLU-50          [-1, 256, 20, 24]               0
#        DoubleConv-51          [-1, 256, 20, 24]               0
#                Up-52          [-1, 256, 20, 24]               0
#          Upsample-53          [-1, 256, 40, 48]               0
#            Conv2d-54          [-1, 256, 40, 48]       1,179,904
#       BatchNorm2d-55          [-1, 256, 40, 48]             512
#              ReLU-56          [-1, 256, 40, 48]               0
#            Conv2d-57          [-1, 128, 40, 48]         295,040
#       BatchNorm2d-58          [-1, 128, 40, 48]             256
#              ReLU-59          [-1, 128, 40, 48]               0
#        DoubleConv-60          [-1, 128, 40, 48]               0
#                Up-61          [-1, 128, 40, 48]               0
#          Upsample-62          [-1, 128, 80, 96]               0
#            Conv2d-63          [-1, 128, 80, 96]         295,040
#       BatchNorm2d-64          [-1, 128, 80, 96]             256
#              ReLU-65          [-1, 128, 80, 96]               0
#            Conv2d-66           [-1, 64, 80, 96]          73,792
#       BatchNorm2d-67           [-1, 64, 80, 96]             128
#              ReLU-68           [-1, 64, 80, 96]               0
#        DoubleConv-69           [-1, 64, 80, 96]               0
#                Up-70           [-1, 64, 80, 96]               0
#          Upsample-71         [-1, 64, 160, 192]               0
#            Conv2d-72         [-1, 64, 160, 192]          73,792
#       BatchNorm2d-73         [-1, 64, 160, 192]             128
#              ReLU-74         [-1, 64, 160, 192]               0
#            Conv2d-75         [-1, 64, 160, 192]          36,928
#       BatchNorm2d-76         [-1, 64, 160, 192]             128
#              ReLU-77         [-1, 64, 160, 192]               0
#        DoubleConv-78         [-1, 64, 160, 192]               0
#                Up-79         [-1, 64, 160, 192]               0
#            Conv2d-80         [-1, 15, 160, 192]             975
#           OutConv-81         [-1, 15, 160, 192]               0
#           Softmax-82         [-1, 15, 160, 192]               0
# ================================================================
# Total params: 17,267,151
# Trainable params: 17,267,151
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 451.64
# Params size (MB): 65.87
# Estimated Total Size (MB): 517.63
# ----------------------------------------------------------------

# %%
model = TiedUNet(n_channels=1, n_classes=15, bilinear=True).to(device)
summary(model, input_size=(1, 160, 192))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 160, 192]             640
#        BatchNorm2d-2         [-1, 64, 160, 192]             128
#               ReLU-3         [-1, 64, 160, 192]               0
#             Conv2d-4         [-1, 64, 160, 192]          36,928
#        BatchNorm2d-5         [-1, 64, 160, 192]             128
#               ReLU-6         [-1, 64, 160, 192]               0
#         DoubleConv-7         [-1, 64, 160, 192]               0
#          MaxPool2d-8           [-1, 64, 80, 96]               0
#             Conv2d-9           [-1, 64, 80, 96]          36,928
#       BatchNorm2d-10           [-1, 64, 80, 96]             128
#              ReLU-11           [-1, 64, 80, 96]               0
#            Conv2d-12           [-1, 64, 80, 96]          36,928
#       BatchNorm2d-13           [-1, 64, 80, 96]             128
#              ReLU-14           [-1, 64, 80, 96]               0
#         MaxPool2d-15           [-1, 64, 40, 48]               0
#            Conv2d-16           [-1, 64, 40, 48]          36,928
#       BatchNorm2d-17           [-1, 64, 40, 48]             128
#              ReLU-18           [-1, 64, 40, 48]               0
#            Conv2d-19           [-1, 64, 40, 48]          36,928
#       BatchNorm2d-20           [-1, 64, 40, 48]             128
#              ReLU-21           [-1, 64, 40, 48]               0
#         MaxPool2d-22           [-1, 64, 20, 24]               0
#            Conv2d-23           [-1, 64, 20, 24]          36,928
#       BatchNorm2d-24           [-1, 64, 20, 24]             128
#              ReLU-25           [-1, 64, 20, 24]               0
#            Conv2d-26           [-1, 64, 20, 24]          36,928
#       BatchNorm2d-27           [-1, 64, 20, 24]             128
#              ReLU-28           [-1, 64, 20, 24]               0
#         MaxPool2d-29           [-1, 64, 10, 12]               0
#            Conv2d-30           [-1, 64, 10, 12]          36,928
#       BatchNorm2d-31           [-1, 64, 10, 12]             128
#              ReLU-32           [-1, 64, 10, 12]               0
#            Conv2d-33           [-1, 64, 10, 12]          36,928
#       BatchNorm2d-34           [-1, 64, 10, 12]             128
#              ReLU-35           [-1, 64, 10, 12]               0
#          Upsample-36           [-1, 64, 20, 24]               0
#            Conv2d-37           [-1, 64, 20, 24]          73,792
#       BatchNorm2d-38           [-1, 64, 20, 24]             128
#              ReLU-39           [-1, 64, 20, 24]               0
#            Conv2d-40           [-1, 64, 20, 24]          36,928
#       BatchNorm2d-41           [-1, 64, 20, 24]             128
#              ReLU-42           [-1, 64, 20, 24]               0
#          Upsample-43           [-1, 64, 40, 48]               0
#            Conv2d-44           [-1, 64, 40, 48]          73,792
#       BatchNorm2d-45           [-1, 64, 40, 48]             128
#              ReLU-46           [-1, 64, 40, 48]               0
#            Conv2d-47           [-1, 64, 40, 48]          36,928
#       BatchNorm2d-48           [-1, 64, 40, 48]             128
#              ReLU-49           [-1, 64, 40, 48]               0
#          Upsample-50           [-1, 64, 80, 96]               0
#            Conv2d-51           [-1, 64, 80, 96]          73,792
#       BatchNorm2d-52           [-1, 64, 80, 96]             128
#              ReLU-53           [-1, 64, 80, 96]               0
#            Conv2d-54           [-1, 64, 80, 96]          36,928
#       BatchNorm2d-55           [-1, 64, 80, 96]             128
#              ReLU-56           [-1, 64, 80, 96]               0
#          Upsample-57         [-1, 64, 160, 192]               0
#            Conv2d-58         [-1, 64, 160, 192]          73,792
#       BatchNorm2d-59         [-1, 64, 160, 192]             128
#              ReLU-60         [-1, 64, 160, 192]               0
#            Conv2d-61         [-1, 64, 160, 192]          36,928
#       BatchNorm2d-62         [-1, 64, 160, 192]             128
#              ReLU-63         [-1, 64, 160, 192]               0
#            Conv2d-64         [-1, 15, 160, 192]             975
#           Softmax-65         [-1, 15, 160, 192]               0
# ================================================================
# Total params: 779,151
# Trainable params: 779,151
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 286.35
# Params size (MB): 2.97
# Estimated Total Size (MB): 289.44
# ----------------------------------------------------------------
