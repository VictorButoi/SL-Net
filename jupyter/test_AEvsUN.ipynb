# %%
import argparse
import logging
import os
import sys

import numpy as np
from tqdm import tqdm
from matplotlib import pyplot as plt

import torch
import torch.nn as nn
from torch import optim
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import DataLoader, random_split

sys.path.append("..")
sys.path.append("../scripts/")
import superlayer.utils

from scripts import eval_net, train_net, get_args

from superlayer.models import SuperNet, AESuperNet
from superlayer.utils import BrainD, dice_coeff, one_hot, plot_img_array, plot_side_by_side

# %%
dir_img = '/home/gid-dalcaav/projects/neuron/data/t1_mix/proc/resize256-crop_x32-slice100/train/vols/'
dir_mask = '/home/gid-dalcaav/projects/neuron/data/t1_mix/proc/resize256-crop_x32-slice100/train/asegs/'

dir_train = '/home/vib9/src/SL-Net/jupyter/partitions/train.txt'
dir_val = '/home/vib9/src/SL-Net/jupyter/partitions/val.txt'

dir_checkpoint_1 = 'checkpoints_1/'
dir_checkpoint_2 = 'checkpoints_2/'

# %%
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
args = get_args()
device = torch.device('cuda')
logging.info(f'Using device {device}')
# Out:
# INFO: Using device cuda

# %%
target_label_numbers = [0,2,3,4,10,16,17,28,31,41,42,43,49,53,63]
val_percent = 0.1
batch_size = args.batchsize
lr = args.lr
img_scale = args.scale
writer = SummaryWriter(comment=f'LR_{lr}_BS_{batch_size}_SCALE_{img_scale}')

# %%
net1 = SuperNet(input_ch=1, out_ch=15, use_bn=True, superblock_size=64, depth=4)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net1.to(device=device)
train_scores1, val_scores1, train_var_1, val_var_1 = train_net(net=net1,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)
# Out:
# INFO: Network:
# 	1 input channels
# 	15 output channels (classes)
#
# INFO: Creating dataset with 7329 examples
# INFO: Creating dataset with 7329 examples
# INFO: Starting training:
#         Epochs:          8
#         Batch size:      8
#         Learning rate:   0.001
#         Training size:   7329
#         Validation size: 7329
#         Checkpoints:     True
#         Device:          cuda
#         Images scaling:  1
#
# Epoch 1/8:  20%|█▉        | 1456/7329 [00:07<00:32, 182.87img/s, loss (batch)=0.24]
# Validation round:   0%|          | 0/916 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/916 [00:00<10:43,  1.42batch/s]
# Validation round:   1%|          | 9/916 [00:00<07:34,  2.00batch/s]
# Validation round:   2%|▏         | 17/916 [00:01<05:24,  2.77batch/s]
# Validation round:   3%|▎         | 23/916 [00:01<03:50,  3.88batch/s]
# Validation round:   3%|▎         | 26/916 [00:01<03:03,  4.84batch/s]
# Validation round:   4%|▎         | 33/916 [00:01<02:13,  6.61batch/s]
# Validation round:   4%|▍         | 36/916 [00:01<01:49,  8.06batch/s]
# Validation round:   5%|▍         | 42/916 [00:02<01:28,  9.93batch/s]
# Validation round:   5%|▌         | 50/916 [00:02<01:11, 12.13batch/s]
# Validation round:  90%|█████████ | 828/916 [00:32<00:03, 22.99batch/s]
# Validation round:  91%|█████████ | 834/916 [00:32<00:03, 22.12batch/s]
# Validation round:  92%|█████████▏| 842/916 [00:33<00:03, 23.06batch/s]
# Validation round:  93%|█████████▎| 850/916 [00:33<00:02, 23.80batch/s]
# Validation round:  94%|█████████▎| 858/916 [00:33<00:02, 24.01batch/s]
# Validation round:  95%|█████████▍| 866/916 [00:33<00:01, 25.33batch/s]
# Validation round:  95%|█████████▌| 874/916 [00:34<00:01, 24.89batch/s]
# Validation round:  96%|█████████▋| 882/916 [00:34<00:01, 25.41batch/s]
# Validation round:  97%|█████████▋| 890/916 [00:34<00:01, 25.47batch/s]
# Validation round:  98%|█████████▊| 898/916 [00:35<00:00, 25.50batch/s]
# Validation round:  99%|█████████▉| 906/916 [00:35<00:00, 26.30batch/s]
# Validation round: 100%|█████████▉| 914/916 [00:35<00:00, 26.10batch/s]
#                                                                       INFO: Validation Dice Loss: 0.06992253487091918
# Epoch 1/8:  40%|███▉      | 2920/7329 [00:50<00:23, 186.16img/s, loss (batch)=0.213]
# Validation round:   0%|          | 0/916 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/916 [00:00<11:57,  1.28batch/s]
# Validation round:   1%|          | 9/916 [00:01<08:26,  1.79batch/s]
# Validation round:   1%|▏         | 12/916 [00:01<06:02,  2.49batch/s]
# Validation round:   2%|▏         | 17/916 [00:01<04:21,  3.44batch/s]
# Validation round:   2%|▏         | 20/916 [00:01<03:14,  4.61batch/s]
# Validation round:   3%|▎         | 25/916 [00:01<02:22,  6.27batch/s]
# Validation round:   3%|▎         | 28/916 [00:01<01:52,  7.91batch/s]
# Validation round:   4%|▎         | 33/916 [00:01<01:25, 10.36batch/s]
# Validation round:   4%|▍         | 36/916 [00:01<01:11, 12.33batch/s]
# Validation round:   4%|▍         | 41/916 [00:02<00:57, 15.31batch/s]
# Validation round:   5%|▍         | 44/916 [00:02<00:50, 17.23batch/s]
# Validation round:   5%|▌         | 49/916 [00:02<00:43, 20.02batch/s]
# Validation round:   6%|▌         | 52/916 [00:02<00:40, 21.51batch/s]
# Validation round:   6%|▌         | 57/916 [00:02<00:36, 23.62batch/s]
# Validation round:   7%|▋         | 60/916 [00:02<00:36, 23.36batch/s]
# Validation round:   7%|▋         | 65/916 [00:02<00:34, 24.97batch/s]
# Validation round:   7%|▋         | 68/916 [00:03<00:36, 23.53batch/s]
# Validation round:   8%|▊         | 73/916 [00:03<00:34, 24.43batch/s]
# Validation round:   8%|▊         | 76/916 [00:03<00:33, 24.76batch/s]
# Validation round:   9%|▉         | 81/916 [00:03<00:31, 26.28batch/s]
# Validation round:   9%|▉         | 84/916 [00:03<00:34, 24.03batch/s]
# Validation round:  10%|▉         | 89/916 [00:03<00:30, 27.50batch/s]
# Validation round:  10%|█         | 93/916 [00:04<00:33, 24.42batch/s]
# Validation round:  11%|█         | 98/916 [00:04<00:37, 22.02batch/s]
# Validation round:  12%|█▏        | 106/916 [00:04<00:35, 22.51batch/s]
# Validation round:  91%|█████████ | 831/916 [00:33<00:03, 22.14batch/s]
# Validation round:  92%|█████████▏| 839/916 [00:34<00:03, 22.72batch/s]
# Validation round:  92%|█████████▏| 847/916 [00:34<00:02, 23.62batch/s]
# Validation round:  93%|█████████▎| 855/916 [00:34<00:02, 20.54batch/s]
# Validation round:  94%|█████████▍| 863/916 [00:35<00:02, 22.15batch/s]
# Validation round:  95%|█████████▌| 871/916 [00:35<00:01, 22.88batch/s]
# Validation round:  96%|█████████▌| 879/916 [00:35<00:01, 23.24batch/s]
# Validation round:  97%|█████████▋| 887/916 [00:36<00:01, 23.67batch/s]
# Validation round:  98%|█████████▊| 895/916 [00:36<00:00, 24.14batch/s]
# Validation round:  99%|█████████▊| 903/916 [00:36<00:00, 24.60batch/s]
# Validation round:  99%|█████████▉| 911/916 [00:37<00:00, 25.21batch/s]
#                                                                       INFO: Validation Dice Loss: 0.05613030326516087
# Epoch 1/8: 100%|█████████▉| 7312/7329 [03:02<00:00, 210.91img/s, loss (batch)=0.208]
# Validation round:   0%|          | 0/916 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/916 [00:00<10:19,  1.48batch/s]
# Validation round:   1%|          | 9/916 [00:00<07:20,  2.06batch/s]
# Validation round:   2%|▏         | 17/916 [00:01<05:15,  2.85batch/s]
# Validation round:   3%|▎         | 25/916 [00:01<03:49,  3.89batch/s]
# Validation round:   4%|▎         | 33/916 [00:01<02:49,  5.20batch/s]
# Validation round:   4%|▍         | 41/916 [00:02<02:08,  6.82batch/s]
# Validation round:   5%|▌         | 49/916 [00:02<01:39,  8.70batch/s]
# Validation round:   6%|▌         | 57/916 [00:02<01:18, 10.89batch/s]
# Validation round:   7%|▋         | 65/916 [00:03<01:03, 13.40batch/s]
# Validation round:   8%|▊         | 73/916 [00:03<00:52, 15.94batch/s]
# Validation round:   9%|▉         | 81/916 [00:03<00:46, 17.97batch/s]
# Validation round:  10%|▉         | 89/916 [00:04<00:41, 19.74batch/s]
# Validation round:  11%|█         | 97/916 [00:04<00:38, 21.06batch/s]
# Validation round:  11%|█▏        | 105/916 [00:04<00:37, 21.89batch/s]
# Validation round:  12%|█▏        | 113/916 [00:05<00:35, 22.31batch/s]
# Validation round:  13%|█▎        | 121/916 [00:05<00:34, 23.16batch/s]
# Validation round:  14%|█▍        | 129/916 [00:05<00:33, 23.58batch/s]
# Validation round:  15%|█▍        | 137/916 [00:06<00:33, 23.58batch/s]
# Validation round:  16%|█▌        | 145/916 [00:06<00:32, 23.90batch/s]
# Validation round:  17%|█▋        | 152/916 [00:06<00:25, 29.48batch/s]
# Validation round:  17%|█▋        | 156/916 [00:06<00:34, 21.78batch/s]
# Validation round:  18%|█▊        | 161/916 [00:07<00:36, 20.63batch/s]
# Validation round:  18%|█▊        | 169/916 [00:07<00:34, 21.70batch/s]
# Validation round:  19%|█▉        | 177/916 [00:07<00:32, 22.79batch/s]
# Validation round:  20%|██        | 185/916 [00:07<00:31, 23.24batch/s]
# Validation round:  21%|██        | 193/916 [00:08<00:30, 23.83batch/s]
# Validation round:  85%|████████▍ | 777/916 [00:31<00:05, 23.44batch/s]
# Validation round:  86%|████████▌ | 785/916 [00:32<00:05, 24.04batch/s]
# Validation round:  87%|████████▋ | 793/916 [00:32<00:05, 24.22batch/s]
# Validation round:  87%|████████▋ | 801/916 [00:32<00:04, 24.14batch/s]
# Validation round:  88%|████████▊ | 809/916 [00:33<00:04, 24.29batch/s]
# Validation round:  89%|████████▉ | 817/916 [00:33<00:04, 24.53batch/s]
# Validation round:  90%|█████████ | 825/916 [00:33<00:03, 24.61batch/s]
# Validation round:  91%|█████████ | 833/916 [00:34<00:03, 24.84batch/s]
# Validation round:  92%|█████████▏| 841/916 [00:34<00:03, 24.99batch/s]
# Validation round:  93%|█████████▎| 849/916 [00:34<00:02, 25.44batch/s]
# Validation round:  94%|█████████▎| 857/916 [00:34<00:02, 25.42batch/s]
# Validation round:  94%|█████████▍| 864/916 [00:35<00:01, 31.29batch/s]
# Validation round:  95%|█████████▍| 868/916 [00:35<00:02, 23.92batch/s]
# Validation round:  95%|█████████▌| 873/916 [00:35<00:01, 21.79batch/s]
# Validation round:  96%|█████████▌| 881/916 [00:35<00:01, 22.86batch/s]
# Validation round:  97%|█████████▋| 889/916 [00:36<00:01, 23.61batch/s]
# Validation round:  98%|█████████▊| 897/916 [00:36<00:00, 24.14batch/s]
# Validation round:  99%|█████████▉| 905/916 [00:36<00:00, 24.19batch/s]
# Validation round: 100%|█████████▉| 913/916 [00:37<00:00, 24.60batch/s]
#                                                                       INFO: Validation Dice Loss: 0.05495111827279022
# Epoch 1/8: 100%|██████████| 7329/7329 [03:39<00:00, 33.36img/s, loss (batch)=0.223]
# INFO: Checkpoint 1 saved !
# Epoch 2/8:  20%|█▉        | 1448/7329 [00:07<00:29, 201.93img/s, loss (batch)=0.208]
# Validation round:   0%|          | 0/916 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/916 [00:00<12:03,  1.27batch/s]
# Validation round:   1%|          | 7/916 [00:00<08:27,  1.79batch/s]
# Validation round:   1%|          | 9/916 [00:01<06:27,  2.34batch/s]
# Validation round:   2%|▏         | 17/916 [00:01<04:38,  3.23batch/s]
# Validation round:   3%|▎         | 25/916 [00:01<03:23,  4.38batch/s]
# Validation round:   4%|▎         | 33/916 [00:02<02:31,  5.82batch/s]
# Validation round:   4%|▍         | 41/916 [00:02<01:56,  7.54batch/s]
# Validation round:   5%|▌         | 49/916 [00:02<01:29,  9.68batch/s]
# Validation round:   6%|▌         | 57/916 [00:02<01:11, 12.00batch/s]
# Validation round:   7%|▋         | 65/916 [00:03<00:59, 14.34batch/s]
# ...
# Validation round:  31%|███       | 285/916 [00:11<00:27, 22.92batch/s]
# Validation round:  32%|███▏      | 293/916 [00:12<00:26, 23.12batch/s]
# Validation round:  33%|███▎      | 300/916 [00:12<00:21, 28.69batch/s]
# Validation round:  33%|███▎      | 304/916 [00:12<00:28, 21.51batch/s]
# Validation round:  34%|███▎      | 309/916 [00:12<00:30, 20.18batch/s]
# Validation round:  35%|███▍      | 317/916 [00:13<00:27, 21.41batch/s]
# Validation round:  93%|█████████▎| 853/916 [00:34<00:02, 22.35batch/s]
# Validation round:  94%|█████████▍| 860/916 [00:35<00:02, 27.79batch/s]
# Validation round:  94%|█████████▍| 864/916 [00:35<00:02, 25.16batch/s]
# Validation round:  95%|█████████▍| 869/916 [00:35<00:01, 23.73batch/s]
# Validation round:  96%|█████████▌| 877/916 [00:35<00:01, 25.62batch/s]
# Validation round:  97%|█████████▋| 885/916 [00:36<00:01, 25.64batch/s]
# Validation round:  97%|█████████▋| 893/916 [00:36<00:00, 26.67batch/s]
# Validation round:  98%|█████████▊| 901/916 [00:36<00:00, 27.59batch/s]
# Validation round:  99%|█████████▉| 909/916 [00:36<00:00, 28.38batch/s]
#                                                                       INFO: Validation Dice Loss: 0.05189611981561871
# Epoch 2/8:  60%|█████▉    | 4368/7329 [01:32<00:16, 182.95img/s, loss (batch)=0.15]
# Validation round:   0%|          | 0/916 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/916 [00:00<10:37,  1.43batch/s]
# Validation round:   1%|          | 8/916 [00:00<07:27,  2.03batch/s]
# Validation round:   1%|          | 10/916 [00:01<05:39,  2.67batch/s]
# Validation round:   2%|▏         | 15/916 [00:01<04:02,  3.71batch/s]
# Validation round:   2%|▏         | 18/916 [00:01<03:03,  4.89batch/s]
# Validation round:   2%|▏         | 21/916 [00:01<02:18,  6.45batch/s]
# Validation round:   3%|▎         | 26/916 [00:01<01:44,  8.48batch/s]
# Validation round:   3%|▎         | 29/916 [00:01<01:27, 10.12batch/s]
# Validation round:   4%|▎         | 34/916 [00:01<01:08, 12.80batch/s]
# Validation round:   4%|▍         | 37/916 [00:02<01:03, 13.79batch/s]
# Validation round:   5%|▍         | 43/916 [00:02<00:50, 17.35batch/s]
# Validation round:   5%|▌         | 46/916 [00:02<00:51, 16.75batch/s]
# Validation round:   6%|▌         | 51/916 [00:02<00:42, 20.31batch/s]
# Validation round:   6%|▌         | 54/916 [00:02<00:49, 17.50batch/s]
# Validation round:   7%|▋         | 60/916 [00:03<00:46, 18.22batch/s]
# Validation round:   7%|▋         | 68/916 [00:03<00:43, 19.32batch/s]
# Validation round:   8%|▊         | 76/916 [00:03<00:40, 20.69batch/s]
# Validation round:   9%|▉         | 82/916 [00:03<00:32, 25.60batch/s]
# Validation round:   9%|▉         | 86/916 [00:04<00:39, 21.09batch/s]
# Validation round:  10%|█         | 92/916 [00:04<00:39, 20.91batch/s]
# Validation round:  11%|█         | 100/916 [00:04<00:37, 21.86batch/s]
# Validation round:  12%|█▏        | 108/916 [00:05<00:35, 22.83batch/s]
# Validation round:  13%|█▎        | 116/916 [00:05<00:34, 23.37batch/s]
# Validation round:  14%|█▎        | 124/916 [00:05<00:33, 23.48batch/s]
# Validation round:  14%|█▍        | 132/916 [00:05<00:32, 23.94batch/s]
# Validation round:  15%|█▌        | 140/916 [00:06<00:32, 24.24batch/s]
# Validation round:  16%|█▌        | 148/916 [00:06<00:31, 24.05batch/s]
# Validation round:  17%|█▋        | 156/916 [00:06<00:31, 24.12batch/s]
# Validation round:  18%|█▊        | 164/916 [00:07<00:31, 23.87batch/s]
# Validation round:  83%|████████▎ | 756/916 [00:31<00:06, 24.87batch/s]
# Validation round:  83%|████████▎ | 764/916 [00:31<00:06, 24.76batch/s]
# Validation round:  84%|████████▍ | 772/916 [00:32<00:05, 25.09batch/s]
# Validation round:  85%|████████▌ | 780/916 [00:32<00:05, 25.09batch/s]
# Validation round:  86%|████████▌ | 788/916 [00:32<00:05, 24.87batch/s]
# Validation round:  87%|████████▋ | 796/916 [00:33<00:04, 24.96batch/s]
# Validation round:  88%|████████▊ | 804/916 [00:33<00:04, 24.43batch/s]
# Validation round:  89%|████████▊ | 812/916 [00:33<00:04, 24.58batch/s]
# Validation round:  90%|████████▉ | 820/916 [00:34<00:03, 24.86batch/s]
# Validation round:  90%|█████████ | 827/916 [00:34<00:02, 30.60batch/s]
# Validation round:  91%|█████████ | 831/916 [00:34<00:03, 23.41batch/s]
# Validation round:  91%|█████████▏| 836/916 [00:34<00:04, 16.62batch/s]
# Validation round:  92%|█████████▏| 844/916 [00:35<00:03, 18.43batch/s]
# Validation round:  93%|█████████▎| 852/916 [00:35<00:03, 19.79batch/s]
# Validation round:  94%|█████████▍| 860/916 [00:35<00:02, 21.31batch/s]
# Validation round:  95%|█████████▍| 868/916 [00:36<00:02, 22.09batch/s]
# Validation round:  96%|█████████▌| 876/916 [00:36<00:01, 22.82batch/s]
# Validation round:  97%|█████████▋| 884/916 [00:36<00:01, 23.16batch/s]
# Validation round:  97%|█████████▋| 892/916 [00:37<00:01, 23.85batch/s]
# Validation round:  98%|█████████▊| 900/916 [00:37<00:00, 23.74batch/s]
# Validation round:  99%|█████████▉| 908/916 [00:37<00:00, 24.18batch/s]
# Validation round: 100%|██████████| 916/916 [00:38<00:00, 24.42batch/s]
#                                                                       INFO: Validation Dice Loss: 0.05122542013637884
# Epoch 2/8:  67%|██████▋   | 4904/7329 [02:13<00:17, 142.43img/s, loss (batch)=0.17]

# %%
net2 = SuperNet(input_ch=1, out_ch=15, use_bn=True, superblock_size=128, depth=4)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net2.to(device=device)
train_scores2, val_scores2, train_var_2, val_var_2 = train_net(net=net2,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
net3 = SuperNet(input_ch=1, out_ch=15, use_bn=True, superblock_size=200, depth=4)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net3.to(device=device)
train_scores3, val_scores3, train_var_3, val_var_3 = train_net(net=net3,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
net4 = SuperNet(input_ch=1, out_ch=15, use_bn=True, superblock_size=256, depth=4)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net4.to(device=device)
train_scores4, val_scores4, train_var_4, val_var_4 = train_net(net=net4,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
net5 = AESuperNet(input_ch=1, out_ch=15, use_bn=True, superblock_size=64, depth=4)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net5.to(device=device)
train_scores5, val_scores5, train_var_5, val_var_5 = train_net(net=net5,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
net6 = AESuperNet(input_ch=1, out_ch=15, use_bn=True, superblock_size=128, depth=4)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net6.to(device=device)
train_scores6, val_scores6, train_var_6, val_var_6 = train_net(net=net6,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
net7 = AESuperNet(input_ch=1, out_ch=15, use_bn=True, superblock_size=200, depth=4)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net7.to(device=device)
train_scores7, val_scores7, train_var_7, val_var_7 = train_net(net=net7,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
net8 = AESuperNet(input_ch=1, out_ch=15, use_bn=True, superblock_size=256, depth=4)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net8.to(device=device)
train_scores8, val_scores8, train_var_8, val_var_8 = train_net(net=net8,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
print("configuring combined plots")
domain = len(train_scores1)
x_values = [i+1 for i in range(domain)]
             
a1 = plt.subplot(1,4,1)
a1.set_ylim([0, 0.5])
plt.title("Complex SLN 64 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores1, train_var_1)]
ziptraindown = [a - b for a, b in zip(train_scores1, train_var_1)]
zipvalup = [a + b for a, b in zip(val_scores1, val_var_1)]
zipvaldown = [a - b for a, b in zip(val_scores1, val_var_1)]

plt.plot(x_values, train_scores1, color="blue", label="train")
a1.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores1, color="orange", label="val")
a1.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a2 = plt.subplot(1,4,2)
a2.set_ylim([0, 0.5])
plt.title("Complex SLN 128 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores2, train_var_2)]
ziptraindown = [a - b for a, b in zip(train_scores2, train_var_2)]
zipvalup = [a + b for a, b in zip(val_scores2, val_var_2)]
zipvaldown = [a - b for a, b in zip(val_scores2, val_var_2)]

plt.plot(x_values, train_scores2, color="blue", label="train")
a2.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores2, color="orange", label="val")
a2.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a3 = plt.subplot(1,4,3)
a3.set_ylim([0, 0.5])
plt.title("Complex SLN 200 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores3, train_var_3)]
ziptraindown = [a - b for a, b in zip(train_scores3, train_var_3)]
zipvalup = [a + b for a, b in zip(val_scores3, val_var_3)]
zipvaldown = [a - b for a, b in zip(val_scores3, val_var_3)]

plt.plot(x_values, train_scores3, color="blue", label="train")
a3.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores3, color="orange", label="val")
a3.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a4 = plt.subplot(1,4,4)
a4.set_ylim([0, 0.5])
plt.title("Complex SLN 256 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores4, train_var_4)]
ziptraindown = [a - b for a, b in zip(train_scores4, train_var_4)]
zipvalup = [a + b for a, b in zip(val_scores4, val_var_4)]
zipvaldown = [a - b for a, b in zip(val_scores4, val_var_4)]

plt.plot(x_values, train_scores4, color="blue", label="train")
a4.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores4, color="orange", label="val")
a4.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

a5 = plt.subplot(1,4,1)
a5.set_ylim([0, 0.5])
plt.title("AE SLN 64 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores5, train_var_5)]
ziptraindown = [a - b for a, b in zip(train_scores5, train_var_5)]
zipvalup = [a + b for a, b in zip(val_scores5, val_var_5)]
zipvaldown = [a - b for a, b in zip(val_scores5, val_var_5)]

plt.plot(x_values, train_scores5, color="blue", label="train")
a5.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores5, color="orange", label="val")
a5.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a6 = plt.subplot(1,4,2)
a6.set_ylim([0, 0.5])
plt.title("AE SLN 128 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores6, train_var_6)]
ziptraindown = [a - b for a, b in zip(train_scores6, train_var_6)]
zipvalup = [a + b for a, b in zip(val_scores6, val_var_6)]
zipvaldown = [a - b for a, b in zip(val_scores6, val_var_6)]

plt.plot(x_values, train_scores6, color="blue", label="train")
a6.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores6, color="orange", label="val")
a6.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a7 = plt.subplot(1,4,3)
a7.set_ylim([0, 0.5])
plt.title("AE SLN 200 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores7, train_var_7)]
ziptraindown = [a - b for a, b in zip(train_scores7, train_var_7)]
zipvalup = [a + b for a, b in zip(val_scores7, val_var_7)]
zipvaldown = [a - b for a, b in zip(val_scores7, val_var_7)]

plt.plot(x_values, train_scores7, color="blue", label="train")
a7.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores7, color="orange", label="val")
a7.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a8 = plt.subplot(1,4,4)
a8.set_ylim([0, 0.5])
plt.title("AE SLN 256 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores8, train_var_8)]
ziptraindown = [a - b for a, b in zip(train_scores8, train_var_8)]
zipvalup = [a + b for a, b in zip(val_scores8, val_var_8)]
zipvaldown = [a - b for a, b in zip(val_scores8, val_var_8)]

plt.plot(x_values, train_scores8, color="blue", label="train")
a8.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores8, color="orange", label="val")
a8.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

plt.close()
