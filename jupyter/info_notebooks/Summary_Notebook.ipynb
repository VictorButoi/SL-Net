# %%
import sys
sys.path.append("../../")
from superlayer.models import UNet, SLN_UNet
from torchsummary import summary
import torch
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
"""
Setup vanilla UNet
"""

enc_nf = [128, 128, 128, 128]
dec_nf = [128, 128, 128, 128]

model1 = UNet(input_ch=1, out_ch=6, enc_nf=enc_nf, dec_nf=dec_nf).to(device)
summary(model1, input_size=(1, 160, 192))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1        [-1, 128, 160, 192]           1,280
#     InstanceNorm2d-2        [-1, 128, 160, 192]               0
#               ReLU-3        [-1, 128, 160, 192]               0
#       simple_block-4        [-1, 128, 160, 192]               0
#          MaxPool2d-5          [-1, 128, 80, 96]               0
#             Conv2d-6          [-1, 128, 80, 96]         147,584
#     InstanceNorm2d-7          [-1, 128, 80, 96]               0
#               ReLU-8          [-1, 128, 80, 96]               0
#       simple_block-9          [-1, 128, 80, 96]               0
#         MaxPool2d-10          [-1, 128, 40, 48]               0
#            Conv2d-11          [-1, 128, 40, 48]         147,584
#    InstanceNorm2d-12          [-1, 128, 40, 48]               0
#              ReLU-13          [-1, 128, 40, 48]               0
#      simple_block-14          [-1, 128, 40, 48]               0
#         MaxPool2d-15          [-1, 128, 20, 24]               0
#            Conv2d-16          [-1, 128, 20, 24]         147,584
#    InstanceNorm2d-17          [-1, 128, 20, 24]               0
#              ReLU-18          [-1, 128, 20, 24]               0
#      simple_block-19          [-1, 128, 20, 24]               0
#         MaxPool2d-20          [-1, 128, 10, 12]               0
#            Conv2d-21          [-1, 128, 10, 12]         147,584
#    InstanceNorm2d-22          [-1, 128, 10, 12]               0
#              ReLU-23          [-1, 128, 10, 12]               0
#      simple_block-24          [-1, 128, 10, 12]               0
#            Conv2d-25          [-1, 128, 20, 24]         295,040
#    InstanceNorm2d-26          [-1, 128, 20, 24]               0
#              ReLU-27          [-1, 128, 20, 24]               0
#      simple_block-28          [-1, 128, 20, 24]               0
#            Conv2d-29          [-1, 128, 40, 48]         295,040
#    InstanceNorm2d-30          [-1, 128, 40, 48]               0
#              ReLU-31          [-1, 128, 40, 48]               0
#      simple_block-32          [-1, 128, 40, 48]               0
#            Conv2d-33          [-1, 128, 80, 96]         295,040
#    InstanceNorm2d-34          [-1, 128, 80, 96]               0
#              ReLU-35          [-1, 128, 80, 96]               0
#      simple_block-36          [-1, 128, 80, 96]               0
#            Conv2d-37        [-1, 128, 160, 192]         295,040
#    InstanceNorm2d-38        [-1, 128, 160, 192]               0
#              ReLU-39        [-1, 128, 160, 192]               0
#      simple_block-40        [-1, 128, 160, 192]               0
#            Conv2d-41          [-1, 6, 160, 192]           6,918
#           Softmax-42          [-1, 6, 160, 192]               0
# ================================================================
# Total params: 1,778,694
# Trainable params: 1,778,694
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 331.99
# Params size (MB): 6.79
# Estimated Total Size (MB): 338.89
# ----------------------------------------------------------------

# %%
model2 = SLN_UNet(input_ch=1, out_ch=6, superblock_size=256, depth=4, W=None, b=None, train_block=True).to(device)
summary(model2, input_size=(1, 160, 192))
print(model2.W.shape)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#          MaxPool2d-1            [-1, 1, 80, 96]               0
#             Conv2d-2          [-1, 128, 80, 96]           1,280
#     InstanceNorm2d-3          [-1, 128, 80, 96]               0
#               ReLU-4          [-1, 128, 80, 96]               0
#       simple_block-5          [-1, 128, 80, 96]               0
#          MaxPool2d-6          [-1, 128, 40, 48]               0
#     InstanceNorm2d-7          [-1, 128, 40, 48]               0
#               ReLU-8          [-1, 128, 40, 48]               0
#       simple_block-9          [-1, 128, 40, 48]               0
#         MaxPool2d-10          [-1, 128, 20, 24]               0
#    InstanceNorm2d-11          [-1, 128, 20, 24]               0
#              ReLU-12          [-1, 128, 20, 24]               0
#      simple_block-13          [-1, 128, 20, 24]               0
#         MaxPool2d-14          [-1, 128, 10, 12]               0
#    InstanceNorm2d-15          [-1, 128, 10, 12]               0
#              ReLU-16          [-1, 128, 10, 12]               0
#      simple_block-17          [-1, 128, 10, 12]               0
#          Upsample-18          [-1, 128, 20, 24]               0
#    InstanceNorm2d-19          [-1, 128, 20, 24]               0
#              ReLU-20          [-1, 128, 20, 24]               0
#      simple_block-21          [-1, 128, 20, 24]               0
#          Upsample-22          [-1, 128, 40, 48]               0
#    InstanceNorm2d-23          [-1, 128, 40, 48]               0
#              ReLU-24          [-1, 128, 40, 48]               0
#      simple_block-25          [-1, 128, 40, 48]               0
#          Upsample-26          [-1, 128, 80, 96]               0
#    InstanceNorm2d-27          [-1, 128, 80, 96]               0
#              ReLU-28          [-1, 128, 80, 96]               0
#      simple_block-29          [-1, 128, 80, 96]               0
#          Upsample-30        [-1, 128, 160, 192]               0
#            Conv2d-31          [-1, 6, 160, 192]           6,972
#           Softmax-32          [-1, 6, 160, 192]               0
# ================================================================
# Total params: 8,252
# Trainable params: 8,252
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 112.09
# Params size (MB): 0.03
# Estimated Total Size (MB): 112.24
# ----------------------------------------------------------------
# torch.Size([128, 256, 3, 3])

# %%
model = AEnet(input_ch=1, out_ch=15, use_bn=True, enc_nf=enc_nf, dec_nf=dec_nf).to(device)
summary(model, input_size=(1, 160, 192))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 160, 192]             640
#     InstanceNorm2d-2         [-1, 64, 160, 192]               0
#               ReLU-3         [-1, 64, 160, 192]               0
#       simple_block-4         [-1, 64, 160, 192]               0
#          MaxPool2d-5           [-1, 64, 80, 96]               0
#             Conv2d-6           [-1, 64, 80, 96]          36,928
#     InstanceNorm2d-7           [-1, 64, 80, 96]               0
#               ReLU-8           [-1, 64, 80, 96]               0
#       simple_block-9           [-1, 64, 80, 96]               0
#         MaxPool2d-10           [-1, 64, 40, 48]               0
#            Conv2d-11           [-1, 64, 40, 48]          36,928
#    InstanceNorm2d-12           [-1, 64, 40, 48]               0
#              ReLU-13           [-1, 64, 40, 48]               0
#      simple_block-14           [-1, 64, 40, 48]               0
#         MaxPool2d-15           [-1, 64, 20, 24]               0
#            Conv2d-16           [-1, 64, 20, 24]          36,928
#    InstanceNorm2d-17           [-1, 64, 20, 24]               0
#              ReLU-18           [-1, 64, 20, 24]               0
#      simple_block-19           [-1, 64, 20, 24]               0
#         MaxPool2d-20           [-1, 64, 10, 12]               0
#            Conv2d-21           [-1, 64, 10, 12]          36,928
#    InstanceNorm2d-22           [-1, 64, 10, 12]               0
#              ReLU-23           [-1, 64, 10, 12]               0
#      simple_block-24           [-1, 64, 10, 12]               0
#            Conv2d-25           [-1, 64, 20, 24]          36,928
#    InstanceNorm2d-26           [-1, 64, 20, 24]               0
#              ReLU-27           [-1, 64, 20, 24]               0
#      simple_block-28           [-1, 64, 20, 24]               0
#            Conv2d-29           [-1, 64, 40, 48]          36,928
#    InstanceNorm2d-30           [-1, 64, 40, 48]               0
#              ReLU-31           [-1, 64, 40, 48]               0
#      simple_block-32           [-1, 64, 40, 48]               0
#            Conv2d-33           [-1, 64, 80, 96]          36,928
#    InstanceNorm2d-34           [-1, 64, 80, 96]               0
#              ReLU-35           [-1, 64, 80, 96]               0
#      simple_block-36           [-1, 64, 80, 96]               0
#            Conv2d-37         [-1, 64, 160, 192]          36,928
#    InstanceNorm2d-38         [-1, 64, 160, 192]               0
#              ReLU-39         [-1, 64, 160, 192]               0
#      simple_block-40         [-1, 64, 160, 192]               0
#            Conv2d-41         [-1, 15, 160, 192]           8,655
#           Softmax-42         [-1, 15, 160, 192]               0
# ================================================================
# Total params: 304,719
# Trainable params: 304,719
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 171.62
# Params size (MB): 1.16
# Estimated Total Size (MB): 172.90
# ----------------------------------------------------------------

# %%
model = SL_AEnet(input_ch=1, out_ch=15, use_bn=True, superblock_size=64, depth=4).to(device)
summary(model, input_size=(1, 160, 192))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 160, 192]             640
#     InstanceNorm2d-2         [-1, 64, 160, 192]               0
#               ReLU-3         [-1, 64, 160, 192]               0
#       simple_block-4         [-1, 64, 160, 192]               0
#          MaxPool2d-5           [-1, 64, 80, 96]               0
#             Conv2d-6           [-1, 64, 80, 96]          36,928
#     InstanceNorm2d-7           [-1, 64, 80, 96]               0
#               ReLU-8           [-1, 64, 80, 96]               0
#       simple_block-9           [-1, 64, 80, 96]               0
#         MaxPool2d-10           [-1, 64, 40, 48]               0
#            Conv2d-11           [-1, 64, 40, 48]          36,928
#    InstanceNorm2d-12           [-1, 64, 40, 48]               0
#              ReLU-13           [-1, 64, 40, 48]               0
#      simple_block-14           [-1, 64, 40, 48]               0
#         MaxPool2d-15           [-1, 64, 20, 24]               0
#            Conv2d-16           [-1, 64, 20, 24]          36,928
#    InstanceNorm2d-17           [-1, 64, 20, 24]               0
#              ReLU-18           [-1, 64, 20, 24]               0
#      simple_block-19           [-1, 64, 20, 24]               0
#         MaxPool2d-20           [-1, 64, 10, 12]               0
#            Conv2d-21           [-1, 64, 10, 12]          36,928
#    InstanceNorm2d-22           [-1, 64, 10, 12]               0
#              ReLU-23           [-1, 64, 10, 12]               0
#      simple_block-24           [-1, 64, 10, 12]               0
#            Conv2d-25           [-1, 64, 20, 24]          36,928
#    InstanceNorm2d-26           [-1, 64, 20, 24]               0
#              ReLU-27           [-1, 64, 20, 24]               0
#      simple_block-28           [-1, 64, 20, 24]               0
#            Conv2d-29           [-1, 64, 40, 48]          36,928
#    InstanceNorm2d-30           [-1, 64, 40, 48]               0
#              ReLU-31           [-1, 64, 40, 48]               0
#      simple_block-32           [-1, 64, 40, 48]               0
#            Conv2d-33           [-1, 64, 80, 96]          36,928
#    InstanceNorm2d-34           [-1, 64, 80, 96]               0
#              ReLU-35           [-1, 64, 80, 96]               0
#      simple_block-36           [-1, 64, 80, 96]               0
#            Conv2d-37         [-1, 64, 160, 192]          36,928
#    InstanceNorm2d-38         [-1, 64, 160, 192]               0
#              ReLU-39         [-1, 64, 160, 192]               0
#      simple_block-40         [-1, 64, 160, 192]               0
#            Conv2d-41         [-1, 15, 160, 192]           8,655
#           Softmax-42         [-1, 15, 160, 192]               0
# ================================================================
# Total params: 304,719
# Trainable params: 304,719
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 171.62
# Params size (MB): 1.16
# Estimated Total Size (MB): 172.90
# ----------------------------------------------------------------

# %%
model = SuperNet(input_ch=1, out_ch=15, use_bn=True, superblock_size=64, depth=4).to(device)
summary(model, input_size=(1, 160, 192))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 160, 192]             640
#     InstanceNorm2d-2         [-1, 64, 160, 192]               0
#               ReLU-3         [-1, 64, 160, 192]               0
#       simple_block-4         [-1, 64, 160, 192]               0
#          MaxPool2d-5           [-1, 64, 80, 96]               0
#     InstanceNorm2d-6           [-1, 64, 80, 96]               0
#               ReLU-7           [-1, 64, 80, 96]               0
#       simple_block-8           [-1, 64, 80, 96]               0
#          MaxPool2d-9           [-1, 64, 40, 48]               0
#    InstanceNorm2d-10           [-1, 64, 40, 48]               0
#              ReLU-11           [-1, 64, 40, 48]               0
#      simple_block-12           [-1, 64, 40, 48]               0
#         MaxPool2d-13           [-1, 64, 20, 24]               0
#    InstanceNorm2d-14           [-1, 64, 20, 24]               0
#              ReLU-15           [-1, 64, 20, 24]               0
#      simple_block-16           [-1, 64, 20, 24]               0
#         MaxPool2d-17           [-1, 64, 10, 12]               0
#    InstanceNorm2d-18           [-1, 64, 10, 12]               0
#              ReLU-19           [-1, 64, 10, 12]               0
#      simple_block-20           [-1, 64, 10, 12]               0
#    InstanceNorm2d-21           [-1, 64, 20, 24]               0
#              ReLU-22           [-1, 64, 20, 24]               0
#      simple_block-23           [-1, 64, 20, 24]               0
#    InstanceNorm2d-24           [-1, 64, 40, 48]               0
#              ReLU-25           [-1, 64, 40, 48]               0
#      simple_block-26           [-1, 64, 40, 48]               0
#    InstanceNorm2d-27           [-1, 64, 80, 96]               0
#              ReLU-28           [-1, 64, 80, 96]               0
#      simple_block-29           [-1, 64, 80, 96]               0
#    InstanceNorm2d-30         [-1, 64, 160, 192]               0
#              ReLU-31         [-1, 64, 160, 192]               0
#      simple_block-32         [-1, 64, 160, 192]               0
#            Conv2d-33         [-1, 15, 160, 192]           8,655
#           Softmax-34         [-1, 15, 160, 192]               0
# ================================================================
# Total params: 9,295
# Trainable params: 9,295
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 146.72
# Params size (MB): 0.04
# Estimated Total Size (MB): 146.87
# ----------------------------------------------------------------

# %%
# Prepare the vm1 or vm2 model and send to device
nf_enc = [64, 64, 64, 64]
nf_dec = [64, 64, 64, 64, 64, 64, 64]

atlas_file = '/home/vib9/src/voxelmorph/data/atlas_norm.npz'

atlas_vol = np.load(atlas_file)['vol'][np.newaxis, ..., np.newaxis][:,:,:,100,:]
vol_size = atlas_vol.shape[1:-1]

model1 = cvpr2018_net(vol_size, nf_enc, nf_dec).unet_model
summary(model1, input_size=(2, 160, 192))
# Out:
# torch.Size([2, 64, 3, 3])
# torch.Size([2])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 80, 96]           2,112
#          LeakyReLU-2           [-1, 64, 80, 96]               0
#         conv_block-3           [-1, 64, 80, 96]               0
#             Conv2d-4           [-1, 64, 40, 48]          65,600
#          LeakyReLU-5           [-1, 64, 40, 48]               0
#         conv_block-6           [-1, 64, 40, 48]               0
#             Conv2d-7           [-1, 64, 20, 24]          65,600
#          LeakyReLU-8           [-1, 64, 20, 24]               0
#         conv_block-9           [-1, 64, 20, 24]               0
#            Conv2d-10           [-1, 64, 10, 12]          65,600
#         LeakyReLU-11           [-1, 64, 10, 12]               0
#        conv_block-12           [-1, 64, 10, 12]               0
#            Conv2d-13           [-1, 64, 10, 12]          36,928
#         LeakyReLU-14           [-1, 64, 10, 12]               0
#        conv_block-15           [-1, 64, 10, 12]               0
#          Upsample-16           [-1, 64, 20, 24]               0
#            Conv2d-17           [-1, 64, 20, 24]          73,792
#         LeakyReLU-18           [-1, 64, 20, 24]               0
#        conv_block-19           [-1, 64, 20, 24]               0
#          Upsample-20           [-1, 64, 40, 48]               0
#            Conv2d-21           [-1, 64, 40, 48]          73,792
#         LeakyReLU-22           [-1, 64, 40, 48]               0
#        conv_block-23           [-1, 64, 40, 48]               0
#          Upsample-24           [-1, 64, 80, 96]               0
#            Conv2d-25           [-1, 64, 80, 96]          73,792
#         LeakyReLU-26           [-1, 64, 80, 96]               0
#        conv_block-27           [-1, 64, 80, 96]               0
#            Conv2d-28           [-1, 64, 80, 96]          36,928
#         LeakyReLU-29           [-1, 64, 80, 96]               0
#        conv_block-30           [-1, 64, 80, 96]               0
#          Upsample-31         [-1, 64, 160, 192]               0
#            Conv2d-32         [-1, 64, 160, 192]          38,080
#         LeakyReLU-33         [-1, 64, 160, 192]               0
#        conv_block-34         [-1, 64, 160, 192]               0
#            Conv2d-35         [-1, 64, 160, 192]          36,928
#         LeakyReLU-36         [-1, 64, 160, 192]               0
#        conv_block-37         [-1, 64, 160, 192]               0
# ================================================================
# Total params: 569,152
# Trainable params: 569,152
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.23
# Forward/backward pass size (MB): 151.05
# Params size (MB): 2.17
# Estimated Total Size (MB): 153.46
# ----------------------------------------------------------------

# %%
nf_enc = [64, 64, 64, 64]
nf_dec = [64, 64, 64, 64, 64, 64, 32]


atlas_file = '/home/vib9/src/voxelmorph/data/atlas_norm.npz'

atlas_vol = np.load(atlas_file)['vol'][np.newaxis, ..., np.newaxis][:,:,:,100,:]
vol_size = atlas_vol.shape[1:-1]

model4 = cvpr2018_net(vol_size, nf_enc, nf_dec, superblock_size=64).unet_model
summary(model4, input_size=(2, 160, 192))
# Out:
# torch.Size([2, 32, 3, 3])
# torch.Size([2])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#          MaxPool2d-1            [-1, 2, 80, 96]               0
#             Conv2d-2           [-1, 32, 80, 96]             608
#          LeakyReLU-3           [-1, 32, 80, 96]               0
#         conv_block-4           [-1, 32, 80, 96]               0
#          MaxPool2d-5           [-1, 32, 40, 48]               0
#             Conv2d-6           [-1, 32, 40, 48]           9,248
#          LeakyReLU-7           [-1, 32, 40, 48]               0
#         conv_block-8           [-1, 32, 40, 48]               0
#          MaxPool2d-9           [-1, 32, 20, 24]               0
#            Conv2d-10           [-1, 32, 20, 24]           9,248
#         LeakyReLU-11           [-1, 32, 20, 24]               0
#        conv_block-12           [-1, 32, 20, 24]               0
#         MaxPool2d-13           [-1, 32, 10, 12]               0
#            Conv2d-14           [-1, 32, 10, 12]           9,248
#         LeakyReLU-15           [-1, 32, 10, 12]               0
#        conv_block-16           [-1, 32, 10, 12]               0
#          Upsample-17           [-1, 32, 20, 24]               0
#            Conv2d-18           [-1, 32, 20, 24]          18,464
#         LeakyReLU-19           [-1, 32, 20, 24]               0
#        conv_block-20           [-1, 32, 20, 24]               0
#          Upsample-21           [-1, 32, 40, 48]               0
#            Conv2d-22           [-1, 32, 40, 48]          18,464
#         LeakyReLU-23           [-1, 32, 40, 48]               0
#        conv_block-24           [-1, 32, 40, 48]               0
#          Upsample-25           [-1, 32, 80, 96]               0
#            Conv2d-26           [-1, 32, 80, 96]          18,464
#         LeakyReLU-27           [-1, 32, 80, 96]               0
#        conv_block-28           [-1, 32, 80, 96]               0
#            Conv2d-29           [-1, 32, 80, 96]           9,248
#         LeakyReLU-30           [-1, 32, 80, 96]               0
#        conv_block-31           [-1, 32, 80, 96]               0
#            Conv2d-32           [-1, 32, 80, 96]           9,248
#         LeakyReLU-33           [-1, 32, 80, 96]               0
#        conv_block-34           [-1, 32, 80, 96]               0
#          Upsample-35         [-1, 32, 160, 192]               0
#            Conv2d-36         [-1, 32, 160, 192]           9,824
#         LeakyReLU-37         [-1, 32, 160, 192]               0
#        conv_block-38         [-1, 32, 160, 192]               0
#            Conv2d-39         [-1, 32, 160, 192]           9,248
#         LeakyReLU-40         [-1, 32, 160, 192]               0
#        conv_block-41         [-1, 32, 160, 192]               0
# ================================================================
# Total params: 121,312
# Trainable params: 121,312
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.23
# Forward/backward pass size (MB): 81.80
# Params size (MB): 0.46
# Estimated Total Size (MB): 82.49
# ----------------------------------------------------------------
