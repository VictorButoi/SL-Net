# %%
import argparse
import logging
import os
import sys

import numpy as np
from tqdm import tqdm
from matplotlib import pyplot as plt

import torch
import torch.nn as nn
from torch import optim
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import DataLoader, random_split

sys.path.append("..")
sys.path.append("../scripts/")
import superlayer.utils

from scripts import eval_net, train_net, get_args

from superlayer.models import SUnet
from superlayer.utils import BrainD, dice_coeff, one_hot, plot_img_array, plot_side_by_side

# %%
net1_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/SLN_64.npy")
net5_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/AE_64.npy")[:32,:,:,:]
net6_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/AE_128.npy")[:64,:,:,:]
net7_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/AE_200.npy")[:100,:,:,:]
net8_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/AE_256.npy")[:128,:,:,:]

# %%
dir_img = '/home/gid-dalcaav/projects/neuron/data/t1_mix/proc/resize256-crop_x32-slice100/train/vols/'
dir_mask = '/home/gid-dalcaav/projects/neuron/data/t1_mix/proc/resize256-crop_x32-slice100/train/asegs/'

dir_train = '/home/vib9/src/SL-Net/jupyter/partitions/train.txt'
dir_val = '/home/vib9/src/SL-Net/jupyter/partitions/val.txt'

dir_checkpoint_1 = 'checkpoints_1/'
dir_checkpoint_2 = 'checkpoints_2/'

# %%
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
args = get_args()
device = torch.device('cuda')
logging.info(f'Using device {device}')
# Out:
# INFO: Using device cuda

# %%
target_label_numbers = [0,2,3,4,10,16,17,28,31,41,42,43,49,53,63]
val_percent = 0.1
batch_size = args.batchsize
lr = args.lr
img_scale = args.scale
writer = SummaryWriter(comment=f'LR_{lr}_BS_{batch_size}_SCALE_{img_scale}')

# %%
enc_nf = [32, 32, 32, 32]
dec_nf = [32, 32, 32, 32]
net5 = SUnet(input_ch=1, out_ch=15, use_bn=True, enc_nf=enc_nf, dec_nf=dec_nf, ignore_last=False, W=net5_W)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net5.to(device=device)
train_scores5, val_scores5, train_var_5, val_var_5 = train_net(net=net5,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)
# Out:
# (32, 64, 3, 3)
# INFO: Network:
# 	1 input channels
# 	15 output channels (classes)
#
# INFO: Creating dataset with 7329 examples
# INFO: Creating dataset with 7329 examples
# INFO: Starting training:
#         Epochs:          8
#         Batch size:      8
#         Learning rate:   0.001
#         Training size:   7329
#         Validation size: 7329
#         Checkpoints:     True
#         Device:          cuda
#         Images scaling:  1
#
# Epoch 1/8:  20%|█▉        | 1456/7329 [00:08<00:29, 200.50img/s, loss (batch)=0.425]
# Validation round:   0%|          | 0/916 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/916 [00:00<10:32,  1.45batch/s]
# Validation round:   1%|          | 6/916 [00:00<07:25,  2.04batch/s]
# Validation round:   1%|          | 9/916 [00:00<05:26,  2.78batch/s]
# Validation round:   1%|▏         | 12/916 [00:01<03:58,  3.79batch/s]
# Validation round:   2%|▏         | 17/916 [00:01<02:56,  5.10batch/s]
# Validation round:   2%|▏         | 20/916 [00:01<02:16,  6.57batch/s]
# Validation round:   3%|▎         | 25/916 [00:01<01:42,  8.68batch/s]
# Validation round:   3%|▎         | 28/916 [00:01<01:29,  9.87batch/s]
# Validation round:   4%|▍         | 36/916 [00:02<01:17, 11.39batch/s]
# Validation round:   5%|▍         | 44/916 [00:02<01:04, 13.47batch/s]
# Validation round:   6%|▌         | 52/916 [00:02<00:54, 15.84batch/s]
# Validation round:   7%|▋         | 60/916 [00:03<00:47, 18.20batch/s]
# Validation round:   7%|▋         | 68/916 [00:03<00:41, 20.46batch/s]
# Validation round:   8%|▊         | 76/916 [00:03<00:38, 21.93batch/s]
# Validation round:   9%|▉         | 84/916 [00:04<00:35, 23.53batch/s]
# Validation round:  10%|█         | 92/916 [00:04<00:32, 25.06batch/s]
# Validation round:  10%|█         | 95/916 [00:04<00:34, 24.11batch/s]
# Validation round:  11%|█         | 100/916 [00:04<00:30, 26.89batch/s]
# Validation round:  11%|█         | 103/916 [00:04<00:40, 19.94batch/s]
# Validation round:  12%|█▏        | 110/916 [00:05<00:40, 19.85batch/s]
# Validation round:  13%|█▎        | 118/916 [00:05<00:38, 20.59batch/s]
# Validation round:  14%|█▍        | 126/916 [00:05<00:37, 21.35batch/s]
# Validation round:  15%|█▍        | 134/916 [00:06<00:35, 21.73batch/s]
# Validation round:  16%|█▌        | 142/916 [00:06<00:35, 21.56batch/s]
# Validation round:  16%|█▋        | 150/916 [00:06<00:35, 21.44batch/s]
# Validation round:  17%|█▋        | 158/916 [00:07<00:34, 22.01batch/s]
# Validation round:  18%|█▊        | 166/916 [00:07<00:33, 22.18batch/s]
# Validation round:  19%|█▉        | 174/916 [00:07<00:32, 22.66batch/s]
# Validation round:  20%|█▉        | 182/916 [00:08<00:32, 22.49batch/s]
# Validation round:  21%|██        | 190/916 [00:08<00:32, 22.52batch/s]
# Validation round:  22%|██▏       | 198/916 [00:09<00:32, 22.00batch/s]
# Validation round:  22%|██▏       | 206/916 [00:09<00:32, 22.02batch/s]
# Validation round:  23%|██▎       | 214/916 [00:09<00:31, 22.37batch/s]
# Validation round:  24%|██▍       | 222/916 [00:10<00:30, 22.71batch/s]
# Validation round:  25%|██▌       | 230/916 [00:10<00:30, 22.17batch/s]
# Validation round:  26%|██▌       | 238/916 [00:10<00:30, 22.38batch/s]
# Validation round:  27%|██▋       | 246/916 [00:11<00:29, 22.75batch/s]
# Epoch 1/8:  20%|█▉        | 1464/7329 [00:19<00:29, 200.50img/s, loss (batch)=0.425]
# Validation round:  29%|██▊       | 262/916 [00:11<00:28, 22.58batch/s]
# Validation round:  29%|██▉       | 270/916 [00:12<00:28, 22.96batch/s]
# Validation round:  30%|███       | 278/916 [00:12<00:27, 23.20batch/s]
# Validation round:  31%|███       | 286/916 [00:12<00:26, 23.33batch/s]
# Validation round:  32%|███▏      | 294/916 [00:13<00:26, 23.16batch/s]
# Validation round:  33%|███▎      | 302/916 [00:13<00:26, 23.35batch/s]
# Validation round:  34%|███▍      | 310/916 [00:13<00:25, 23.59batch/s]
# Validation round:  35%|███▍      | 318/916 [00:14<00:25, 23.33batch/s]
# Validation round:  36%|███▌      | 326/916 [00:14<00:25, 23.33batch/s]
# Validation round:  36%|███▋      | 334/916 [00:14<00:25, 23.18batch/s]
# Validation round:  37%|███▋      | 342/916 [00:15<00:25, 22.78batch/s]
# Validation round:  38%|███▊      | 350/916 [00:15<00:25, 22.42batch/s]
# Validation round:  39%|███▉      | 358/916 [00:16<00:24, 22.35batch/s]
# Validation round:  40%|███▉      | 366/916 [00:16<00:24, 22.56batch/s]
# Validation round:  41%|████      | 373/916 [00:16<00:19, 28.06batch/s]
# Validation round:  41%|████      | 377/916 [00:16<00:27, 19.63batch/s]
# Validation round:  42%|████▏     | 382/916 [00:17<00:29, 18.05batch/s]
# Validation round:  42%|████▏     | 389/916 [00:17<00:22, 23.22batch/s]
# Validation round:  43%|████▎     | 393/916 [00:17<00:27, 19.32batch/s]
# Validation round:  43%|████▎     | 398/916 [00:17<00:27, 18.67batch/s]
# Validation round:  44%|████▍     | 406/916 [00:18<00:25, 19.67batch/s]
# Validation round:  45%|████▌     | 413/916 [00:18<00:20, 24.88batch/s]
# Validation round:  46%|████▌     | 417/916 [00:18<00:25, 19.79batch/s]
# Validation round:  46%|████▌     | 422/916 [00:18<00:26, 18.64batch/s]
# Validation round:  47%|████▋     | 430/916 [00:19<00:23, 20.26batch/s]
# Validation round:  48%|████▊     | 437/916 [00:19<00:18, 25.68batch/s]
# Validation round:  48%|████▊     | 441/916 [00:19<00:22, 21.07batch/s]
# Validation round:  49%|████▊     | 446/916 [00:19<00:24, 19.45batch/s]
# Validation round:  50%|████▉     | 454/916 [00:20<00:22, 20.38batch/s]
# Validation round:  50%|█████     | 462/916 [00:20<00:21, 21.09batch/s]
# Validation round:  51%|█████▏    | 470/916 [00:21<00:20, 21.36batch/s]
# Validation round:  52%|█████▏    | 478/916 [00:21<00:20, 21.59batch/s]
# Validation round:  53%|█████▎    | 485/916 [00:21<00:16, 26.80batch/s]
# Validation round:  53%|█████▎    | 489/916 [00:21<00:20, 20.47batch/s]
# Validation round:  54%|█████▍    | 494/916 [00:22<00:22, 19.02batch/s]
# Validation round:  55%|█████▍    | 501/916 [00:22<00:17, 24.10batch/s]
# Validation round:  55%|█████▌    | 505/916 [00:22<00:21, 19.53batch/s]
# Validation round:  56%|█████▌    | 510/916 [00:22<00:22, 17.88batch/s]
# Validation round:  57%|█████▋    | 518/916 [00:23<00:20, 19.51batch/s]
# Validation round:  57%|█████▋    | 526/916 [00:23<00:18, 20.63batch/s]
# Validation round:  58%|█████▊    | 534/916 [00:23<00:17, 21.36batch/s]
# Validation round:  59%|█████▉    | 541/916 [00:23<00:13, 26.95batch/s]
# Validation round:  59%|█████▉    | 545/916 [00:24<00:16, 22.22batch/s]
# Validation round:  60%|██████    | 550/916 [00:24<00:18, 20.26batch/s]
# Validation round:  61%|██████    | 558/916 [00:24<00:17, 20.93batch/s]
# Validation round:  62%|██████▏   | 566/916 [00:25<00:16, 21.15batch/s]
# Validation round:  63%|██████▎   | 574/916 [00:25<00:15, 21.98batch/s]
# Validation round:  64%|██████▎   | 582/916 [00:25<00:15, 21.96batch/s]
# Validation round:  64%|██████▍   | 590/916 [00:26<00:14, 22.33batch/s]
# Validation round:  65%|██████▌   | 598/916 [00:26<00:14, 22.39batch/s]
# Validation round:  66%|██████▌   | 606/916 [00:26<00:13, 22.37batch/s]
# Validation round:  67%|██████▋   | 613/916 [00:27<00:10, 28.08batch/s]
# Validation round:  67%|██████▋   | 617/916 [00:27<00:14, 20.85batch/s]
# Validation round:  68%|██████▊   | 622/916 [00:27<00:15, 18.85batch/s]
# Validation round:  69%|██████▉   | 630/916 [00:27<00:13, 20.61batch/s]
# Validation round:  70%|██████▉   | 638/916 [00:28<00:13, 21.13batch/s]
# Validation round:  71%|███████   | 646/916 [00:28<00:12, 21.75batch/s]
# Validation round:  71%|███████▏  | 654/916 [00:29<00:11, 22.03batch/s]
# Validation round:  72%|███████▏  | 662/916 [00:29<00:11, 21.94batch/s]
# Validation round:  73%|███████▎  | 670/916 [00:29<00:11, 22.00batch/s]
# Validation round:  74%|███████▍  | 677/916 [00:29<00:08, 27.44batch/s]
# Validation round:  74%|███████▍  | 681/916 [00:30<00:11, 20.75batch/s]
# Validation round:  75%|███████▍  | 686/916 [00:30<00:11, 19.17batch/s]
# Validation round:  76%|███████▌  | 693/916 [00:30<00:09, 24.31batch/s]
# Validation round:  76%|███████▌  | 697/916 [00:30<00:11, 19.61batch/s]
# Validation round:  77%|███████▋  | 702/916 [00:31<00:12, 17.73batch/s]
# Validation round:  78%|███████▊  | 710/916 [00:31<00:10, 18.81batch/s]
# Validation round:  78%|███████▊  | 718/916 [00:31<00:09, 20.02batch/s]
# Validation round:  79%|███████▉  | 726/916 [00:32<00:09, 20.92batch/s]
# Validation round:  80%|████████  | 734/916 [00:32<00:08, 21.55batch/s]
# Validation round:  81%|████████  | 741/916 [00:32<00:06, 26.95batch/s]
# Validation round:  81%|████████▏ | 745/916 [00:33<00:08, 21.05batch/s]
# Validation round:  82%|████████▏ | 750/916 [00:33<00:08, 19.31batch/s]
# Validation round:  83%|████████▎ | 758/916 [00:33<00:07, 20.66batch/s]
# Validation round:  84%|████████▎ | 765/916 [00:33<00:05, 26.05batch/s]
# Validation round:  84%|████████▍ | 769/916 [00:34<00:06, 21.24batch/s]
# Validation round:  84%|████████▍ | 774/916 [00:34<00:07, 19.15batch/s]
# Validation round:  85%|████████▌ | 782/916 [00:34<00:06, 19.73batch/s]
# Validation round:  86%|████████▌ | 790/916 [00:35<00:06, 20.88batch/s]
# Validation round:  87%|████████▋ | 798/916 [00:35<00:05, 21.42batch/s]
# Validation round:  88%|████████▊ | 806/916 [00:35<00:05, 21.71batch/s]
# Validation round:  89%|████████▉ | 814/916 [00:36<00:04, 22.23batch/s]
# Validation round:  90%|████████▉ | 822/916 [00:36<00:04, 21.79batch/s]
# Validation round:  91%|█████████ | 830/916 [00:36<00:03, 22.12batch/s]
# Validation round:  91%|█████████▏| 838/916 [00:37<00:03, 22.32batch/s]
# Validation round:  92%|█████████▏| 846/916 [00:37<00:03, 22.26batch/s]
# Validation round:  93%|█████████▎| 854/916 [00:37<00:02, 21.75batch/s]
# Validation round:  94%|█████████▍| 862/916 [00:38<00:02, 22.35batch/s]
# Validation round:  95%|█████████▍| 870/916 [00:38<00:02, 22.67batch/s]
# Validation round:  96%|█████████▌| 878/916 [00:38<00:01, 23.18batch/s]
# Validation round:  97%|█████████▋| 886/916 [00:39<00:01, 23.06batch/s]
# Validation round:  98%|█████████▊| 894/916 [00:39<00:00, 23.49batch/s]
# Validation round:  98%|█████████▊| 902/916 [00:39<00:00, 23.65batch/s]
# Validation round:  99%|█████████▉| 910/916 [00:40<00:00, 24.45batch/s]
#                                                                       INFO: Validation Dice Loss: 0.21262427121726185
# Epoch 1/8:  40%|███▉      | 2920/7329 [00:55<00:25, 175.95img/s, loss (batch)=0.385]
# Validation round:   0%|          | 0/916 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/916 [00:00<11:04,  1.38batch/s]
# Validation round:   1%|          | 8/916 [00:00<07:45,  1.95batch/s]
# Validation round:   1%|          | 10/916 [00:01<05:51,  2.58batch/s]
# Validation round:   1%|▏         | 12/916 [00:01<04:26,  3.39batch/s]
# Validation round:   2%|▏         | 17/916 [00:01<03:12,  4.68batch/s]
# Validation round:   2%|▏         | 20/916 [00:01<02:31,  5.91batch/s]
# Validation round:   3%|▎         | 26/916 [00:01<01:50,  8.02batch/s]
# Validation round:   3%|▎         | 29/916 [00:01<01:36,  9.22batch/s]
# Validation round:   4%|▎         | 33/916 [00:01<01:14, 11.92batch/s]
# Validation round:   4%|▍         | 36/916 [00:02<01:08, 12.94batch/s]
# Validation round:   4%|▍         | 41/916 [00:02<00:53, 16.36batch/s]
# Validation round:   5%|▍         | 45/916 [00:02<00:52, 16.58batch/s]
# Validation round:   5%|▌         | 49/916 [00:02<00:43, 19.91batch/s]
# Validation round:   6%|▌         | 52/916 [00:02<00:46, 18.63batch/s]
# Validation round:   6%|▌         | 57/916 [00:02<00:40, 21.08batch/s]
# Validation round:   7%|▋         | 60/916 [00:03<00:39, 21.56batch/s]
# Validation round:   7%|▋         | 65/916 [00:03<00:37, 22.69batch/s]
# Validation round:   8%|▊         | 69/916 [00:03<00:32, 25.82batch/s]
# Validation round:   8%|▊         | 73/916 [00:03<00:39, 21.50batch/s]
# Validation round:   9%|▉         | 81/916 [00:03<00:37, 22.24batch/s]
# Validation round:  10%|▉         | 88/916 [00:04<00:30, 27.13batch/s]
# Validation round:  10%|█         | 92/916 [00:04<00:38, 21.68batch/s]
# Validation round:  11%|█         | 97/916 [00:04<00:39, 20.79batch/s]
# Validation round:  11%|█▏        | 104/916 [00:04<00:31, 26.01batch/s]
# Validation round:  12%|█▏        | 108/916 [00:05<00:38, 20.99batch/s]
# Validation round:  12%|█▏        | 113/916 [00:05<00:38, 21.05batch/s]
# Validation round:  13%|█▎        | 119/916 [00:05<00:31, 25.64batch/s]
# Validation round:  13%|█▎        | 123/916 [00:05<00:35, 22.30batch/s]
# Validation round:  14%|█▍        | 128/916 [00:05<00:30, 26.23batch/s]
# Validation round:  14%|█▍        | 132/916 [00:05<00:35, 22.02batch/s]
# Validation round:  15%|█▍        | 136/916 [00:06<00:31, 24.39batch/s]
# Validation round:  15%|█▌        | 139/916 [00:06<00:33, 23.10batch/s]
# Validation round:  16%|█▌        | 143/916 [00:06<00:30, 25.08batch/s]
# Validation round:  16%|█▌        | 146/916 [00:06<00:34, 22.22batch/s]
# Validation round:  16%|█▋        | 151/916 [00:06<00:30, 25.18batch/s]
# Validation round:  17%|█▋        | 154/916 [00:06<00:32, 23.49batch/s]
# Validation round:  17%|█▋        | 159/916 [00:06<00:29, 25.56batch/s]
# Validation round:  18%|█▊        | 162/916 [00:07<00:31, 23.62batch/s]
# Validation round:  18%|█▊        | 167/916 [00:07<00:28, 25.85batch/s]
# Validation round:  19%|█▊        | 170/916 [00:07<00:31, 23.70batch/s]
# Validation round:  19%|█▉        | 175/916 [00:07<00:28, 25.57batch/s]
# Validation round:  19%|█▉        | 178/916 [00:07<00:30, 23.90batch/s]
# Validation round:  20%|█▉        | 183/916 [00:07<00:28, 25.75batch/s]
# Validation round:  20%|██        | 186/916 [00:08<00:31, 23.14batch/s]
# Validation round:  21%|██        | 191/916 [00:08<00:28, 25.39batch/s]
# Validation round:  21%|██        | 194/916 [00:08<00:31, 23.06batch/s]
# Validation round:  22%|██▏       | 199/916 [00:08<00:27, 26.15batch/s]
# Validation round:  22%|██▏       | 202/916 [00:08<00:31, 22.44batch/s]
# Validation round:  23%|██▎       | 207/916 [00:08<00:28, 24.63batch/s]
# Validation round:  23%|██▎       | 210/916 [00:08<00:32, 22.06batch/s]
# Validation round:  23%|██▎       | 215/916 [00:09<00:28, 24.25batch/s]
# Validation round:  24%|██▍       | 218/916 [00:09<00:29, 23.66batch/s]
# Validation round:  24%|██▍       | 223/916 [00:09<00:27, 24.95batch/s]
# Validation round:  25%|██▍       | 226/916 [00:09<00:27, 25.03batch/s]
# Validation round:  25%|██▌       | 231/916 [00:09<00:27, 25.11batch/s]
# Validation round:  26%|██▌       | 234/916 [00:09<00:26, 25.90batch/s]
# Validation round:  26%|██▌       | 239/916 [00:10<00:27, 24.71batch/s]
# Validation round:  26%|██▋       | 242/916 [00:10<00:25, 25.96batch/s]
# Validation round:  27%|██▋       | 247/916 [00:10<00:27, 24.72batch/s]
# Validation round:  27%|██▋       | 250/916 [00:10<00:26, 25.36batch/s]
# Validation round:  28%|██▊       | 255/916 [00:10<00:26, 24.81batch/s]
# Validation round:  28%|██▊       | 258/916 [00:10<00:25, 25.32batch/s]
# Validation round:  29%|██▊       | 263/916 [00:11<00:27, 24.04batch/s]
# Validation round:  29%|██▉       | 268/916 [00:11<00:23, 27.58batch/s]
# Validation round:  30%|██▉       | 271/916 [00:11<00:30, 21.14batch/s]
# Validation round:  30%|███       | 275/916 [00:11<00:26, 24.46batch/s]
# Validation round:  30%|███       | 279/916 [00:11<00:28, 22.74batch/s]
# Validation round:  31%|███       | 282/916 [00:11<00:26, 23.49batch/s]
# Validation round:  31%|███▏      | 287/916 [00:12<00:27, 22.79batch/s]
# Validation round:  32%|███▏      | 292/916 [00:12<00:23, 26.57batch/s]
# Validation round:  32%|███▏      | 296/916 [00:12<00:27, 22.84batch/s]
# Validation round:  33%|███▎      | 303/916 [00:12<00:26, 23.54batch/s]
# Validation round:  33%|███▎      | 306/916 [00:12<00:24, 24.99batch/s]
# Validation round:  34%|███▍      | 311/916 [00:13<00:25, 23.31batch/s]
# Validation round:  34%|███▍      | 316/916 [00:13<00:21, 27.37batch/s]
# Validation round:  35%|███▍      | 320/916 [00:13<00:27, 21.69batch/s]
# Validation round:  36%|███▌      | 327/916 [00:13<00:25, 23.15batch/s]
# Validation round:  36%|███▌      | 330/916 [00:13<00:24, 23.71batch/s]
# Epoch 1/8:  40%|███▉      | 2928/7329 [01:10<00:25, 175.95img/s, loss (batch)=0.385]
# Validation round:  37%|███▋      | 338/916 [00:14<00:23, 24.09batch/s]
# Validation round:  37%|███▋      | 343/916 [00:14<00:24, 23.43batch/s]
# Validation round:  38%|███▊      | 346/916 [00:14<00:22, 25.04batch/s]
# Validation round:  38%|███▊      | 351/916 [00:14<00:22, 24.68batch/s]
# Validation round:  39%|███▉      | 355/916 [00:14<00:20, 27.46batch/s]
# Validation round:  39%|███▉      | 359/916 [00:15<00:24, 22.74batch/s]
# Validation round:  40%|███▉      | 366/916 [00:15<00:19, 28.40batch/s]
# Validation round:  40%|████      | 370/916 [00:15<00:25, 21.64batch/s]
# Validation round:  41%|████      | 375/916 [00:15<00:25, 20.99batch/s]
# Validation round:  42%|████▏     | 382/916 [00:15<00:20, 26.43batch/s]
# Validation round:  42%|████▏     | 386/916 [00:16<00:25, 20.58batch/s]
# Validation round:  43%|████▎     | 391/916 [00:16<00:26, 20.05batch/s]
# Validation round:  44%|████▎     | 399/916 [00:16<00:23, 22.03batch/s]
# Validation round:  44%|████▍     | 404/916 [00:16<00:19, 26.43batch/s]
# Validation round:  45%|████▍     | 408/916 [00:16<00:23, 21.55batch/s]
# Validation round:  45%|████▌     | 415/916 [00:17<00:23, 21.59batch/s]
# Validation round:  46%|████▌     | 423/916 [00:17<00:21, 22.43batch/s]
# Validation round:  47%|████▋     | 431/916 [00:17<00:20, 23.10batch/s]
# Validation round:  48%|████▊     | 439/916 [00:18<00:19, 23.88batch/s]
# Validation round:  49%|████▉     | 447/916 [00:18<00:19, 23.84batch/s]
# Validation round:  50%|████▉     | 455/916 [00:18<00:19, 24.07batch/s]
# Validation round:  51%|█████     | 463/916 [00:19<00:18, 24.66batch/s]
# Validation round:  51%|█████▏    | 471/916 [00:19<00:18, 24.51batch/s]
# Validation round:  52%|█████▏    | 479/916 [00:19<00:17, 24.39batch/s]
# Validation round:  53%|█████▎    | 487/916 [00:20<00:17, 24.04batch/s]
# Validation round:  54%|█████▍    | 495/916 [00:20<00:17, 24.66batch/s]
# Validation round:  55%|█████▍    | 503/916 [00:20<00:16, 24.86batch/s]

# %%
enc_nf = [64, 64, 64, 64]
dec_nf = [64, 64, 64, 64]
net6 = SUnet(input_ch=1, out_ch=15, use_bn=True, enc_nf=enc_nf, dec_nf=dec_nf, ignore_last=False, W=net6_W)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net6.to(device=device)
train_scores6, val_scores6, train_var_6, val_var_6 = train_net(net=net6,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
enc_nf = [100, 100, 100, 100]
dec_nf = [100, 100, 100, 100]
net7 = SUnet(input_ch=1, out_ch=15, use_bn=True, enc_nf=enc_nf, dec_nf=dec_nf, ignore_last=False, W=net7_W)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net7.to(device=device)
train_scores7, val_scores7, train_var_7, val_var_7 = train_net(net=net7,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
enc_nf = [128, 128, 128, 128]
dec_nf = [128, 128, 128, 128]
net8 = SUnet(input_ch=1, out_ch=15, use_bn=True, enc_nf=enc_nf, dec_nf=dec_nf, ignore_last=False, W=net8_W)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net8.to(device=device)
train_scores8, val_scores8, train_var_8, val_var_8 = train_net(net=net8,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
print("configuring combined plots")
domain = len(train_scores5)
x_values = [i+1 for i in range(domain)]

a5 = plt.subplot(1,2,1)
a5.set_ylim([0, 0.5])
plt.title("AE SLN 64 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores5, train_var_5)]
ziptraindown = [a - b for a, b in zip(train_scores5, train_var_5)]
zipvalup = [a + b for a, b in zip(val_scores5, val_var_5)]
zipvaldown = [a - b for a, b in zip(val_scores5, val_var_5)]

plt.plot(x_values, train_scores5, color="blue", label="train")
a5.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores5, color="orange", label="val")
a5.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a6 = plt.subplot(1,2,2)
a6.set_ylim([0, 0.5])
plt.title("AE SLN 128 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores6, train_var_6)]
ziptraindown = [a - b for a, b in zip(train_scores6, train_var_6)]
zipvalup = [a + b for a, b in zip(val_scores6, val_var_6)]
zipvaldown = [a - b for a, b in zip(val_scores6, val_var_6)]

plt.plot(x_values, train_scores6, color="blue", label="train")
a6.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores6, color="orange", label="val")
a6.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

plt.show()

a7 = plt.subplot(1,2,1)
a7.set_ylim([0, 0.5])
plt.title("AE SLN 200 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores7, train_var_7)]
ziptraindown = [a - b for a, b in zip(train_scores7, train_var_7)]
zipvalup = [a + b for a, b in zip(val_scores7, val_var_7)]
zipvaldown = [a - b for a, b in zip(val_scores7, val_var_7)]

plt.plot(x_values, train_scores7, color="blue", label="train")
a7.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores7, color="orange", label="val")
a7.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a8 = plt.subplot(1,2,2)
a8.set_ylim([0, 0.5])
plt.title("AE SLN 256 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores8, train_var_8)]
ziptraindown = [a - b for a, b in zip(train_scores8, train_var_8)]
zipvalup = [a + b for a, b in zip(val_scores8, val_var_8)]
zipvaldown = [a - b for a, b in zip(val_scores8, val_var_8)]

plt.plot(x_values, train_scores8, color="blue", label="train")
a8.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores8, color="orange", label="val")
a8.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

# %%
net1_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/SLN_64.npy")
net5_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/AE_64.npy")[32:,:,:,:]
net6_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/AE_128.npy")[64:,:,:,:]
net7_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/AE_200.npy")[100:,:,:,:]
net8_W = np.load("/home/vib9/src/SL-Net/superlayer/models/superblocks/AE_256.npy")[128:,:,:,:]

# %%
enc_nf = [32, 32, 32, 32]
dec_nf = [32, 32, 32, 32]
net9 = SUnet(input_ch=1, out_ch=15, use_bn=True, enc_nf=enc_nf, dec_nf=dec_nf, ignore_last=False, W=net5_W)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net9.to(device=device)
train_scores9, val_scores9, train_var_9, val_var_9 = train_net(net=net9,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
enc_nf = [64, 64, 64, 64]
dec_nf = [64, 64, 64, 64]
net10 = SUnet(input_ch=1, out_ch=15, use_bn=True, enc_nf=enc_nf, dec_nf=dec_nf, ignore_last=False, W=net6_W)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net10.to(device=device)
train_scores10, val_scores10, train_var_10, val_var_10 = train_net(net=net10,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
enc_nf = [100, 100, 100, 100]
dec_nf = [100, 100, 100, 100]
net11 = SUnet(input_ch=1, out_ch=15, use_bn=True, enc_nf=enc_nf, dec_nf=dec_nf, ignore_last=False, W=net7_W)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net11.to(device=device)
train_scores11, val_scores11, train_var_11, val_var_11 = train_net(net=net11,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
enc_nf = [128, 128, 128, 128]
dec_nf = [128, 128, 128, 128]
net12 = SUnet(input_ch=1, out_ch=15, use_bn=True, enc_nf=enc_nf, dec_nf=dec_nf, ignore_last=False, W=net8_W)

logging.info(f'Network:\n'
             f'\t{1} input channels\n'
             f'\t{15} output channels (classes)\n')

net12.to(device=device)
train_scores12, val_scores12, train_var_12, val_var_12 = train_net(net=net12,
                                                                epochs=8,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                writer=writer,
                                                                train_path=dir_train,
                                                                val_path=dir_val)

# %%
print("configuring combined plots")
domain = len(train_scores1)
x_values = [i+1 for i in range(domain)]

a9 = plt.subplot(1,2,1)
a9.set_ylim([0, 0.5])
plt.title("AE SLN 64 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores9, train_var_9)]
ziptraindown = [a - b for a, b in zip(train_scores9, train_var_9)]
zipvalup = [a + b for a, b in zip(val_scores9, val_var_9)]
zipvaldown = [a - b for a, b in zip(val_scores9, val_var_9)]

plt.plot(x_values, train_scores9, color="blue", label="train")
a9.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores9, color="orange", label="val")
a9.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a10 = plt.subplot(1,2,2)
a10.set_ylim([0, 0.5])
plt.title("AE SLN 128 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores10, train_var_10)]
ziptraindown = [a - b for a, b in zip(train_scores10, train_var_10)]
zipvalup = [a + b for a, b in zip(val_scores10, val_var_10)]
zipvaldown = [a - b for a, b in zip(val_scores10, val_var_10)]

plt.plot(x_values, train_scores10, color="blue", label="train")
a10.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores10, color="orange", label="val")
a10.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

plt.show()

a11 = plt.subplot(1,2,1)
a11.set_ylim([0, 0.5])
plt.title("AE SLN 200 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores11, train_var_11)]
ziptraindown = [a - b for a, b in zip(train_scores11, train_var_11)]
zipvalup = [a + b for a, b in zip(val_scores11, val_var_11)]
zipvaldown = [a - b for a, b in zip(val_scores11, val_var_11)]

plt.plot(x_values, train_scores11, color="blue", label="train")
a11.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores11, color="orange", label="val")
a11.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()

a12 = plt.subplot(1,2,2)
a12.set_ylim([0, 0.5])
plt.title("AE SLN 256 Superblock")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")

ziptrainup = [a + b for a, b in zip(train_scores12, train_var_12)]
ziptraindown = [a - b for a, b in zip(train_scores12, train_var_12)]
zipvalup = [a + b for a, b in zip(val_scores12, val_var_12)]
zipvaldown = [a - b for a, b in zip(val_scores12, val_var_12)]

plt.plot(x_values, train_scores12, color="blue", label="train")
a12.fill_between(x_values, ziptrainup, ziptraindown, facecolor='lightskyblue', alpha=0.5)
plt.plot(x_values, val_scores12, color="orange", label="val")
a12.fill_between(x_values, zipvalup, zipvaldown, facecolor='navajowhite', alpha=0.5)

plt.legend()
plt.grid()
