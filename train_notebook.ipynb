# %%
import argparse
import logging
import os
import sys

import numpy as np
import torch
import torch.nn as nn
from torch import optim
from tqdm import tqdm

import utils.help as help
from eval import eval_net
from unet import UNet
from unet import TiedUNet

from torch.utils.tensorboard import SummaryWriter
from utils.dataset import BrainD
from torch.utils.data import DataLoader, random_split

from dice_loss import dice_coeff
from dice_loss import one_hot

from train import train_net 
from train import get_args

from matplotlib import pyplot as plt

# %%
dir_img = '/home/gid-dalcaav/projects/neuron/data/t1_mix/proc/resize256-crop_x32-slice100/train/vols/'
dir_mask = '/home/gid-dalcaav/projects/neuron/data/t1_mix/proc/resize256-crop_x32-slice100/train/asegs/'
dir_checkpoint_1 = 'checkpoints_1/'
dir_checkpoint_2 = 'checkpoints_2/'

np.set_printoptions(threshold=sys.maxsize)
torch.set_printoptions(threshold=10_000)

# %%
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
args = get_args()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
logging.info(f'Using device {device}')
# Out:
# INFO: Using device cuda

# %%
target_label_numbers = [0,2,3,4,10,16,17,28,31,41,42,43,49,53,63]
val_percent = 0.1
batch_size = args.batchsize
lr = args.lr
img_scale = args.scale

dataset = BrainD(dir_img, dir_mask, label_numbers=target_label_numbers)
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - 2 * n_val
n_test = n_val
train, val, test = random_split(dataset, [n_train, n_val, n_test])

train_loader = DataLoader(train, batch_size=8, shuffle=True, num_workers=8, pin_memory=True)
val_loader = DataLoader(val, batch_size=8, shuffle=False, num_workers=8, pin_memory=True, drop_last=True)

writer = SummaryWriter(comment=f'LR_{lr}_BS_{batch_size}_SCALE_{img_scale}')
# Out:
# INFO: Creating dataset with 7329 examples

# %%
one_example = next(iter(train_loader))

image = one_example['image'][0]
mask = one_example['mask'][0]

print(image.shape)
print(mask.shape)

sq_img = image.squeeze(0).squeeze(0)
sq_msk = mask.squeeze(0).squeeze(0)
# Out:
# torch.Size([1, 160, 192])
# torch.Size([1, 160, 192])

# %%
print(sq_img.shape)
plt.imshow(sq_img)
# Out:
# torch.Size([160, 192])

# %%
print(sq_msk.shape)
plt.imshow(sq_msk)
# Out:
# torch.Size([160, 192])

# %%
net2 = TiedUNet(n_channels=1, n_classes=15, bilinear=True)

logging.info(f'Network:\n'
             f'\t{net2.n_channels} input channels\n'
             f'\t{net2.n_classes} output channels (classes)\n'
             f'\t{"Bilinear" if net2.bilinear else "Transposed conv"} upscaling')

net2.to(device=device)
train_scores2, val_scores2, train_var_2, val_var_2 = train_net(net=net2,
                                                                epochs=args.epochs,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=2,
                                                                target_label_numbers=target_label_numbers,
                                                                dataset=dataset,
                                                                train_loader=train_loader,
                                                                val_loader=val_loader,
                                                                writer=writer)
# Out:
# INFO: Network:
# 	1 input channels
# 	15 output channels (classes)
# 	Bilinear upscaling
# INFO: Starting training:
#         Epochs:          1
#         Batch size:      8
#         Learning rate:   0.001
#         Training size:   6597
#         Validation size: 732
#         Checkpoints:     True
#         Device:          cuda
#         Images scaling:  1
#
# Epoch 1/1:   3%|▎         | 180/6597 [00:03<01:35, 67.18img/s, loss (batch)=0.144]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<02:58,  2.05batch/s]
# Validation round:   2%|▏         | 9/366 [00:00<02:03,  2.89batch/s]
# Validation round:   5%|▍         | 18/366 [00:00<01:25,  4.07batch/s]
# Validation round:   8%|▊         | 29/366 [00:00<00:58,  5.73batch/s]
# Validation round:  11%|█         | 40/366 [00:00<00:40,  7.99batch/s]
# Validation round:  13%|█▎        | 48/366 [00:01<00:29, 10.95batch/s]
# Validation round:  16%|█▌        | 59/366 [00:01<00:20, 14.97batch/s]
# Validation round:  19%|█▉        | 70/366 [00:01<00:14, 20.14batch/s]
# Validation round:  22%|██▏       | 81/366 [00:01<00:10, 26.56batch/s]
# Validation round:  25%|██▍       | 91/366 [00:01<00:08, 33.28batch/s]
# Validation round:  28%|██▊       | 101/366 [00:01<00:06, 41.33batch/s]
# Validation round:  31%|███       | 112/366 [00:01<00:05, 50.43batch/s]
# Validation round:  33%|███▎      | 122/366 [00:01<00:04, 57.28batch/s]
# Validation round:  36%|███▌      | 132/366 [00:01<00:03, 63.74batch/s]
# Validation round:  39%|███▉      | 142/366 [00:02<00:03, 69.56batch/s]
# Validation round:  41%|████▏     | 151/366 [00:02<00:02, 74.27batch/s]
# Validation round:  44%|████▍     | 162/366 [00:02<00:02, 76.77batch/s]
# Validation round:  48%|████▊     | 174/366 [00:02<00:02, 84.90batch/s]
# Validation round:  50%|█████     | 184/366 [00:02<00:02, 88.19batch/s]
# Validation round:  53%|█████▎    | 194/366 [00:02<00:01, 89.19batch/s]
# Validation round:  56%|█████▌    | 204/366 [00:02<00:01, 84.58batch/s]
# Validation round:  59%|█████▊    | 215/366 [00:02<00:01, 89.50batch/s]
# Validation round:  61%|██████▏   | 225/366 [00:02<00:01, 90.97batch/s]
# Validation round:  64%|██████▍   | 235/366 [00:03<00:01, 86.33batch/s]
# Validation round:  67%|██████▋   | 244/366 [00:03<00:01, 84.83batch/s]
# Validation round:  69%|██████▉   | 254/366 [00:03<00:01, 87.92batch/s]
# Validation round:  73%|███████▎  | 266/366 [00:03<00:01, 94.35batch/s]
# Validation round:  75%|███████▌  | 276/366 [00:03<00:01, 88.79batch/s]
# Validation round:  78%|███████▊  | 286/366 [00:03<00:00, 87.81batch/s]
# Validation round:  81%|████████  | 295/366 [00:03<00:00, 85.59batch/s]
# Validation round:  84%|████████▎ | 306/366 [00:03<00:00, 90.49batch/s]
# Validation round:  86%|████████▋ | 316/366 [00:03<00:00, 87.00batch/s]
# Validation round:  89%|████████▉ | 325/366 [00:04<00:00, 79.96batch/s]
# Validation round:  91%|█████████▏| 334/366 [00:04<00:00, 79.02batch/s]
# Validation round:  94%|█████████▎| 343/366 [00:04<00:00, 80.63batch/s]
# Validation round:  96%|█████████▌| 352/366 [00:04<00:00, 80.29batch/s]
# Validation round:  99%|█████████▊| 361/366 [00:04<00:00, 82.65batch/s]
#                                                                       INFO: Validation Dice Loss: 0.27434538207093223
# Epoch 1/1:   5%|▌         | 362/6597 [00:10<01:32, 67.73img/s, loss (batch)=0.131]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:03,  1.99batch/s]
# Validation round:   3%|▎         | 11/366 [00:00<02:06,  2.81batch/s]
# Validation round:   6%|▌         | 22/366 [00:00<01:26,  3.97batch/s]
# Validation round:   9%|▊         | 32/366 [00:00<00:59,  5.58batch/s]
# Validation round:  11%|█         | 41/366 [00:00<00:41,  7.75batch/s]
# Validation round:  14%|█▍        | 51/366 [00:01<00:29, 10.70batch/s]
# Validation round:  17%|█▋        | 63/366 [00:01<00:20, 14.62batch/s]
# Validation round:  20%|██        | 74/366 [00:01<00:14, 19.73batch/s]
# Validation round:  23%|██▎       | 84/366 [00:01<00:10, 25.83batch/s]
# Validation round:  26%|██▌       | 94/366 [00:01<00:08, 33.12batch/s]
# Validation round:  28%|██▊       | 104/366 [00:01<00:06, 40.83batch/s]
# Validation round:  31%|███       | 114/366 [00:01<00:05, 49.37batch/s]
# Validation round:  34%|███▍      | 124/366 [00:01<00:04, 54.97batch/s]
# Validation round:  36%|███▋      | 133/366 [00:01<00:03, 60.53batch/s]
# Validation round:  39%|███▉      | 143/366 [00:02<00:03, 67.35batch/s]
# Validation round:  42%|████▏     | 155/366 [00:02<00:02, 76.34batch/s]
# Validation round:  45%|████▌     | 166/366 [00:02<00:02, 82.81batch/s]
# Validation round:  48%|████▊     | 176/366 [00:02<00:02, 86.40batch/s]
# Validation round:  51%|█████     | 187/366 [00:02<00:01, 91.35batch/s]
# Validation round:  54%|█████▍    | 198/366 [00:02<00:01, 94.31batch/s]
# Validation round:  57%|█████▋    | 209/366 [00:02<00:01, 94.73batch/s]
# Validation round:  60%|██████    | 221/366 [00:02<00:01, 99.67batch/s]
# Validation round:  63%|██████▎   | 232/366 [00:02<00:01, 94.90batch/s]
# Validation round:  66%|██████▌   | 242/366 [00:03<00:01, 95.05batch/s]
# Validation round:  69%|██████▉   | 254/366 [00:03<00:01, 99.43batch/s]
# Validation round:  72%|███████▏  | 265/366 [00:03<00:01, 98.31batch/s]
# Validation round:  75%|███████▌  | 276/366 [00:03<00:00, 100.17batch/s]
# Validation round:  78%|███████▊  | 287/366 [00:03<00:00, 95.65batch/s]
# Validation round:  81%|████████  | 297/366 [00:03<00:00, 95.15batch/s]
# Validation round:  84%|████████▍ | 307/366 [00:03<00:00, 96.38batch/s]
# Validation round:  87%|████████▋ | 317/366 [00:03<00:00, 94.48batch/s]
# Validation round:  89%|████████▉ | 327/366 [00:03<00:00, 95.72batch/s]
# Validation round:  92%|█████████▏| 337/366 [00:03<00:00, 94.83batch/s]
# Validation round:  95%|█████████▍| 347/366 [00:04<00:00, 95.65batch/s]
# Validation round:  98%|█████████▊| 357/366 [00:04<00:00, 91.92batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26363737327479275
# Epoch 1/1:   8%|▊         | 546/6597 [00:18<01:24, 71.23img/s, loss (batch)=0.142]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<02:55,  2.08batch/s]
# Validation round:   3%|▎         | 11/366 [00:00<02:00,  2.94batch/s]
# Validation round:   6%|▋         | 23/366 [00:00<01:22,  4.16batch/s]
# Validation round:   9%|▉         | 33/366 [00:00<00:57,  5.83batch/s]
# Validation round:  11%|█▏        | 42/366 [00:00<00:40,  8.07batch/s]
# Validation round:  14%|█▍        | 52/366 [00:01<00:28, 11.13batch/s]
# Validation round:  17%|█▋        | 63/366 [00:01<00:19, 15.21batch/s]
# Validation round:  20%|█▉        | 72/366 [00:01<00:14, 20.25batch/s]
# Validation round:  22%|██▏       | 82/366 [00:01<00:10, 26.28batch/s]
# Validation round:  25%|██▌       | 93/366 [00:01<00:08, 34.00batch/s]
# Validation round:  28%|██▊       | 103/366 [00:01<00:06, 41.73batch/s]
# Validation round:  31%|███       | 113/366 [00:01<00:05, 50.19batch/s]
# Validation round:  34%|███▎      | 123/366 [00:01<00:04, 57.23batch/s]
# Validation round:  36%|███▋      | 133/366 [00:01<00:03, 65.17batch/s]
# Validation round:  39%|███▉      | 143/366 [00:01<00:03, 71.52batch/s]
# Validation round:  42%|████▏     | 153/366 [00:02<00:02, 76.43batch/s]
# Validation round:  45%|████▍     | 163/366 [00:02<00:02, 80.01batch/s]
# Validation round:  47%|████▋     | 173/366 [00:02<00:02, 83.16batch/s]
# Validation round:  50%|█████     | 183/366 [00:02<00:02, 87.55batch/s]
# Validation round:  53%|█████▎    | 193/366 [00:02<00:01, 89.75batch/s]
# Validation round:  55%|█████▌    | 203/366 [00:02<00:01, 87.51batch/s]
# Validation round:  58%|█████▊    | 213/366 [00:02<00:01, 88.48batch/s]
# Validation round:  61%|██████    | 223/366 [00:02<00:01, 89.92batch/s]
# Validation round:  64%|██████▎   | 233/366 [00:02<00:01, 90.57batch/s]
# Validation round:  66%|██████▋   | 243/366 [00:03<00:01, 88.07batch/s]
# Validation round:  69%|██████▉   | 253/366 [00:03<00:01, 90.62batch/s]
# Validation round:  72%|███████▏  | 263/366 [00:03<00:01, 92.02batch/s]
# Validation round:  75%|███████▍  | 273/366 [00:03<00:01, 92.22batch/s]
# Validation round:  77%|███████▋  | 283/366 [00:03<00:00, 86.81batch/s]
# Validation round:  80%|████████  | 293/366 [00:03<00:00, 90.31batch/s]
# Validation round:  83%|████████▎ | 303/366 [00:03<00:00, 91.72batch/s]
# Validation round:  86%|████████▌ | 314/366 [00:03<00:00, 89.93batch/s]
# Validation round:  89%|████████▊ | 324/366 [00:03<00:00, 92.10batch/s]
# Validation round:  92%|█████████▏| 335/366 [00:04<00:00, 94.82batch/s]
# Validation round:  94%|█████████▍| 345/366 [00:04<00:00, 90.71batch/s]
# Validation round:  97%|█████████▋| 355/366 [00:04<00:00, 88.08batch/s]
# Validation round: 100%|█████████▉| 365/366 [00:04<00:00, 91.05batch/s]
#                                                                       INFO: Validation Dice Loss: 0.25694213547016104
# Epoch 1/1:  11%|█         | 728/6597 [00:25<01:24, 69.36img/s, loss (batch)=0.132]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:14,  1.88batch/s]
# Validation round:   3%|▎         | 12/366 [00:00<02:12,  2.67batch/s]
# Validation round:   7%|▋         | 24/366 [00:00<01:30,  3.77batch/s]
# Validation round:   9%|▉         | 34/366 [00:00<01:02,  5.29batch/s]
# Validation round:  12%|█▏        | 44/366 [00:00<00:43,  7.39batch/s]
# Validation round:  15%|█▌        | 55/366 [00:01<00:30, 10.25batch/s]
# Validation round:  18%|█▊        | 65/366 [00:01<00:21, 13.99batch/s]
# Validation round:  20%|██        | 74/366 [00:01<00:15, 18.69batch/s]
# Validation round:  23%|██▎       | 83/366 [00:01<00:11, 24.40batch/s]
# Validation round:  25%|██▌       | 92/366 [00:01<00:08, 30.77batch/s]
# Validation round:  28%|██▊       | 103/366 [00:01<00:06, 38.88batch/s]
# Validation round:  31%|███       | 112/366 [00:01<00:05, 45.68batch/s]
# Validation round:  34%|███▎      | 123/366 [00:01<00:04, 52.14batch/s]
# Validation round:  36%|███▌      | 132/366 [00:01<00:04, 56.11batch/s]
# Validation round:  39%|███▉      | 142/366 [00:02<00:03, 63.89batch/s]
# Validation round:  42%|████▏     | 153/366 [00:02<00:02, 72.19batch/s]
# Validation round:  44%|████▍     | 162/366 [00:02<00:02, 73.84batch/s]
# Validation round:  47%|████▋     | 172/366 [00:02<00:02, 79.53batch/s]
# Validation round:  49%|████▉     | 181/366 [00:02<00:02, 81.77batch/s]
# Validation round:  52%|█████▏    | 192/366 [00:02<00:01, 88.50batch/s]
# Validation round:  55%|█████▌    | 202/366 [00:02<00:01, 84.68batch/s]
# Validation round:  58%|█████▊    | 212/366 [00:02<00:01, 88.29batch/s]
# Validation round:  61%|██████    | 223/366 [00:02<00:01, 91.72batch/s]
# Validation round:  64%|██████▍   | 234/366 [00:03<00:01, 89.06batch/s]
# Validation round:  67%|██████▋   | 244/366 [00:03<00:01, 89.01batch/s]
# Validation round:  69%|██████▉   | 254/366 [00:03<00:01, 91.63batch/s]
# Validation round:  73%|███████▎  | 266/366 [00:03<00:01, 93.66batch/s]
# Validation round:  75%|███████▌  | 276/366 [00:03<00:00, 92.93batch/s]
# Validation round:  78%|███████▊  | 286/366 [00:03<00:00, 91.78batch/s]
# Validation round:  81%|████████▏ | 298/366 [00:03<00:00, 90.38batch/s]
# Validation round:  84%|████████▍ | 309/366 [00:03<00:00, 95.09batch/s]
# Validation round:  87%|████████▋ | 319/366 [00:04<00:00, 93.81batch/s]
# Validation round:  90%|█████████ | 330/366 [00:04<00:00, 88.36batch/s]
# Validation round:  93%|█████████▎| 340/366 [00:04<00:00, 91.24batch/s]
# Validation round:  96%|█████████▌| 351/366 [00:04<00:00, 94.84batch/s]
# Validation round:  99%|█████████▊| 361/366 [00:04<00:00, 95.94batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2755896060681734
# Epoch 1/1:  14%|█▍        | 908/6597 [00:32<01:19, 71.19img/s, loss (batch)=0.143]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:21,  1.81batch/s]
# Validation round:   2%|▏         | 9/366 [00:00<02:19,  2.56batch/s]
# Validation round:   5%|▌         | 19/366 [00:00<01:35,  3.62batch/s]
# Validation round:   8%|▊         | 29/366 [00:00<01:06,  5.08batch/s]
# Validation round:  11%|█         | 40/366 [00:00<00:45,  7.11batch/s]
# Validation round:  13%|█▎        | 49/366 [00:01<00:32,  9.83batch/s]
# Validation round:  16%|█▋        | 60/366 [00:01<00:22, 13.52batch/s]
# Validation round:  19%|█▉        | 71/366 [00:01<00:16, 18.33batch/s]
# Validation round:  22%|██▏       | 82/366 [00:01<00:11, 24.32batch/s]
# Validation round:  25%|██▌       | 92/366 [00:01<00:08, 31.25batch/s]
# Validation round:  28%|██▊       | 102/366 [00:01<00:06, 38.58batch/s]
# Validation round:  31%|███       | 112/366 [00:01<00:05, 46.35batch/s]
# Validation round:  33%|███▎      | 122/366 [00:01<00:04, 54.35batch/s]
# Validation round:  36%|███▌      | 132/366 [00:01<00:03, 62.52batch/s]
# Validation round:  39%|███▉      | 142/366 [00:02<00:03, 68.16batch/s]
# Validation round:  42%|████▏     | 152/366 [00:02<00:02, 73.89batch/s]
# Validation round:  44%|████▍     | 162/366 [00:02<00:02, 73.32batch/s]
# Validation round:  47%|████▋     | 171/366 [00:02<00:02, 77.60batch/s]
# Validation round:  49%|████▉     | 181/366 [00:02<00:02, 82.89batch/s]
# Validation round:  52%|█████▏    | 191/366 [00:02<00:02, 76.25batch/s]
# Validation round:  55%|█████▌    | 202/366 [00:02<00:01, 82.55batch/s]
# Validation round:  58%|█████▊    | 213/366 [00:02<00:01, 87.59batch/s]
# Validation round:  61%|██████    | 223/366 [00:02<00:01, 87.81batch/s]
# Validation round:  64%|██████▎   | 233/366 [00:03<00:01, 90.00batch/s]
# Validation round:  66%|██████▋   | 243/366 [00:03<00:01, 90.28batch/s]
# Validation round:  69%|██████▉   | 253/366 [00:03<00:01, 91.36batch/s]
# Validation round:  72%|███████▏  | 263/366 [00:03<00:01, 92.49batch/s]
# Validation round:  75%|███████▍  | 273/366 [00:03<00:01, 89.20batch/s]
# Validation round:  77%|███████▋  | 283/366 [00:03<00:00, 91.52batch/s]
# Validation round:  80%|████████  | 293/366 [00:03<00:00, 91.65batch/s]
# Validation round:  83%|████████▎ | 303/366 [00:03<00:00, 93.48batch/s]
# Validation round:  86%|████████▌ | 313/366 [00:03<00:00, 92.20batch/s]
# Validation round:  88%|████████▊ | 323/366 [00:04<00:00, 88.21batch/s]
# Validation round:  91%|█████████ | 332/366 [00:04<00:00, 77.12batch/s]
# Validation round:  94%|█████████▎| 343/366 [00:04<00:00, 84.35batch/s]
# Validation round:  96%|█████████▋| 353/366 [00:04<00:00, 85.15batch/s]
# Validation round:  99%|█████████▉| 362/366 [00:04<00:00, 85.51batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2667205556819999
# Epoch 1/1:  17%|█▋        | 1090/6597 [00:40<01:22, 66.36img/s, loss (batch)=0.105]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:17,  1.84batch/s]
# Validation round:   3%|▎         | 10/366 [00:00<02:16,  2.61batch/s]
# Validation round:   5%|▌         | 19/366 [00:00<01:34,  3.68batch/s]
# Validation round:   8%|▊         | 28/366 [00:00<01:05,  5.16batch/s]
# Validation round:  11%|█         | 39/366 [00:00<00:45,  7.21batch/s]
# Validation round:  13%|█▎        | 48/366 [00:01<00:31,  9.95batch/s]
# Validation round:  16%|█▌        | 57/366 [00:01<00:22, 13.53batch/s]
# Validation round:  18%|█▊        | 65/366 [00:01<00:16, 18.02batch/s]
# Validation round:  20%|█▉        | 73/366 [00:01<00:12, 23.43batch/s]
# Validation round:  23%|██▎       | 85/366 [00:01<00:09, 30.68batch/s]
# Validation round:  26%|██▌       | 96/366 [00:01<00:06, 39.10batch/s]
# Validation round:  29%|██▉       | 106/366 [00:01<00:05, 46.43batch/s]
# Validation round:  32%|███▏      | 118/366 [00:01<00:04, 56.43batch/s]
# Validation round:  35%|███▌      | 129/366 [00:01<00:03, 64.01batch/s]
# Validation round:  38%|███▊      | 139/366 [00:02<00:03, 71.68batch/s]
# Validation round:  41%|████      | 149/366 [00:02<00:02, 77.77batch/s]
# Validation round:  43%|████▎     | 159/366 [00:02<00:02, 82.46batch/s]
# Validation round:  46%|████▌     | 169/366 [00:02<00:02, 86.39batch/s]
# Validation round:  50%|████▉     | 182/366 [00:02<00:01, 94.69batch/s]
# Validation round:  53%|█████▎    | 193/366 [00:02<00:01, 88.96batch/s]
# Validation round:  56%|█████▌    | 204/366 [00:02<00:01, 94.03batch/s]
# Validation round:  59%|█████▊    | 215/366 [00:02<00:01, 93.64batch/s]
# Validation round:  61%|██████▏   | 225/366 [00:02<00:01, 87.66batch/s]
# Validation round:  64%|██████▍   | 235/366 [00:03<00:01, 90.46batch/s]
# Validation round:  67%|██████▋   | 245/366 [00:03<00:01, 90.39batch/s]
# Validation round:  70%|██████▉   | 255/366 [00:03<00:01, 92.50batch/s]
# Validation round:  72%|███████▏  | 265/366 [00:03<00:01, 92.66batch/s]
# Validation round:  75%|███████▌  | 275/366 [00:03<00:00, 91.13batch/s]
# Validation round:  78%|███████▊  | 286/366 [00:03<00:00, 94.33batch/s]
# Validation round:  81%|████████  | 296/366 [00:03<00:00, 93.21batch/s]
# Validation round:  84%|████████▎ | 306/366 [00:03<00:00, 90.67batch/s]
# Validation round:  86%|████████▋ | 316/366 [00:03<00:00, 85.93batch/s]
# Validation round:  89%|████████▉ | 326/366 [00:04<00:00, 88.79batch/s]
# Validation round:  92%|█████████▏| 335/366 [00:04<00:00, 86.89batch/s]
# Validation round:  94%|█████████▍| 345/366 [00:04<00:00, 82.51batch/s]
# Validation round:  98%|█████████▊| 357/366 [00:04<00:00, 90.01batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2642194561131014
# Epoch 1/1:  19%|█▉        | 1272/6597 [00:47<01:15, 70.75img/s, loss (batch)=0.0891]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:08,  1.94batch/s]
# Validation round:   3%|▎         | 10/366 [00:00<02:09,  2.74batch/s]
# Validation round:   6%|▌         | 21/366 [00:00<01:29,  3.87batch/s]
# Validation round:   9%|▊         | 32/366 [00:00<01:01,  5.44batch/s]
# Validation round:  11%|█▏        | 42/366 [00:00<00:42,  7.54batch/s]
# Validation round:  14%|█▍        | 52/366 [00:01<00:30, 10.42batch/s]
# Validation round:  17%|█▋        | 63/366 [00:01<00:21, 14.25batch/s]
# Validation round:  20%|█▉        | 73/366 [00:01<00:15, 19.15batch/s]
# Validation round:  23%|██▎       | 83/366 [00:01<00:11, 25.17batch/s]
# Validation round:  26%|██▌       | 95/366 [00:01<00:08, 32.90batch/s]
# Validation round:  29%|██▊       | 105/366 [00:01<00:06, 38.79batch/s]
# Validation round:  31%|███▏      | 115/366 [00:01<00:05, 47.27batch/s]
# Validation round:  34%|███▍      | 125/366 [00:01<00:04, 55.40batch/s]
# Validation round:  37%|███▋      | 136/366 [00:01<00:03, 64.13batch/s]
# Validation round:  40%|████      | 147/366 [00:02<00:03, 72.51batch/s]
# Validation round:  43%|████▎     | 157/366 [00:02<00:02, 77.94batch/s]
# Validation round:  46%|████▌     | 168/366 [00:02<00:02, 83.90batch/s]
# Validation round:  49%|████▊     | 178/366 [00:02<00:02, 85.31batch/s]
# Validation round:  51%|█████▏    | 188/366 [00:02<00:02, 88.62batch/s]
# Validation round:  54%|█████▍    | 198/366 [00:02<00:01, 86.82batch/s]
# Validation round:  57%|█████▋    | 208/366 [00:02<00:01, 87.83batch/s]
# Validation round:  60%|█████▉    | 218/366 [00:02<00:01, 90.12batch/s]
# Validation round:  62%|██████▏   | 228/366 [00:02<00:01, 89.61batch/s]
# Validation round:  65%|██████▌   | 238/366 [00:03<00:01, 90.91batch/s]
# Validation round:  68%|██████▊   | 248/366 [00:03<00:01, 91.22batch/s]
# Validation round:  70%|███████   | 258/366 [00:03<00:01, 90.28batch/s]
# Validation round:  73%|███████▎  | 268/366 [00:03<00:01, 91.22batch/s]
# Validation round:  76%|███████▌  | 278/366 [00:03<00:00, 88.24batch/s]
# Validation round:  78%|███████▊  | 287/366 [00:03<00:00, 87.84batch/s]
# Validation round:  81%|████████  | 296/366 [00:03<00:00, 87.16batch/s]
# Validation round:  84%|████████▎ | 306/366 [00:03<00:00, 90.27batch/s]
# Validation round:  86%|████████▋ | 316/366 [00:03<00:00, 86.43batch/s]
# Validation round:  89%|████████▉ | 325/366 [00:04<00:00, 81.46batch/s]
# Validation round:  91%|█████████▏| 334/366 [00:04<00:00, 82.81batch/s]
# Validation round:  94%|█████████▍| 344/366 [00:04<00:00, 85.46batch/s]
# Validation round:  96%|█████████▋| 353/366 [00:04<00:00, 85.80batch/s]
# Validation round:  99%|█████████▉| 364/366 [00:04<00:00, 87.42batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26319240872325794
# Epoch 1/1:  22%|██▏       | 1456/6597 [00:55<01:10, 73.41img/s, loss (batch)=0.0982]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:12,  1.89batch/s]
# Validation round:   4%|▍         | 14/366 [00:00<02:11,  2.69batch/s]
# Validation round:   7%|▋         | 25/366 [00:00<01:30,  3.79batch/s]
# Validation round:  10%|▉         | 36/366 [00:00<01:01,  5.33batch/s]
# Validation round:  12%|█▏        | 44/366 [00:00<00:43,  7.40batch/s]
# Validation round:  15%|█▌        | 55/366 [00:01<00:30, 10.26batch/s]
# Validation round:  18%|█▊        | 66/366 [00:01<00:21, 14.09batch/s]
# Validation round:  21%|██        | 77/366 [00:01<00:15, 19.07batch/s]
# Validation round:  24%|██▍       | 87/366 [00:01<00:11, 25.05batch/s]
# Validation round:  27%|██▋       | 97/366 [00:01<00:08, 31.72batch/s]
# Validation round:  29%|██▉       | 107/366 [00:01<00:06, 38.87batch/s]
# Validation round:  32%|███▏      | 117/366 [00:01<00:05, 47.45batch/s]
# Validation round:  35%|███▍      | 127/366 [00:01<00:04, 56.30batch/s]
# Validation round:  38%|███▊      | 138/366 [00:01<00:03, 65.04batch/s]
# Validation round:  41%|████      | 149/366 [00:02<00:02, 73.29batch/s]
# Validation round:  44%|████▍     | 161/366 [00:02<00:02, 81.66batch/s]
# Validation round:  47%|████▋     | 172/366 [00:02<00:02, 85.57batch/s]
# Validation round:  50%|█████     | 183/366 [00:02<00:01, 91.57batch/s]
# Validation round:  53%|█████▎    | 194/366 [00:02<00:01, 92.56batch/s]
# Validation round:  56%|█████▌    | 205/366 [00:02<00:01, 95.22batch/s]
# Validation round:  59%|█████▉    | 216/366 [00:02<00:01, 94.59batch/s]
# Validation round:  62%|██████▏   | 226/366 [00:02<00:01, 90.43batch/s]
# Validation round:  64%|██████▍   | 236/366 [00:02<00:01, 92.73batch/s]
# Validation round:  67%|██████▋   | 246/366 [00:03<00:01, 92.11batch/s]
# Validation round:  70%|██████▉   | 256/366 [00:03<00:01, 90.71batch/s]
# Validation round:  73%|███████▎  | 266/366 [00:03<00:01, 85.46batch/s]
# Validation round:  76%|███████▌  | 278/366 [00:03<00:00, 91.89batch/s]
# Validation round:  79%|███████▊  | 288/366 [00:03<00:00, 93.86batch/s]
# Validation round:  81%|████████▏ | 298/366 [00:03<00:00, 90.97batch/s]
# Validation round:  84%|████████▍ | 309/366 [00:03<00:00, 94.27batch/s]
# Validation round:  87%|████████▋ | 319/366 [00:03<00:00, 93.28batch/s]
# Validation round:  90%|████████▉ | 329/366 [00:03<00:00, 89.48batch/s]
# Validation round:  93%|█████████▎| 339/366 [00:04<00:00, 86.89batch/s]
# Validation round:  95%|█████████▌| 348/366 [00:04<00:00, 87.53batch/s]
# Validation round:  98%|█████████▊| 358/366 [00:04<00:00, 89.59batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26329083219577704
# Epoch 1/1:  25%|██▍       | 1636/6597 [01:02<01:09, 71.18img/s, loss (batch)=0.105]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<02:57,  2.05batch/s]
# Validation round:   3%|▎         | 12/366 [00:00<02:01,  2.91batch/s]
# Validation round:   6%|▌         | 22/366 [00:00<01:23,  4.10batch/s]
# Validation round:   9%|▊         | 32/366 [00:00<00:58,  5.76batch/s]
# Validation round:  12%|█▏        | 43/366 [00:00<00:40,  8.03batch/s]
# Validation round:  14%|█▍        | 53/366 [00:01<00:28, 11.05batch/s]
# Validation round:  17%|█▋        | 64/366 [00:01<00:20, 15.09batch/s]
# Validation round:  20%|█▉        | 73/366 [00:01<00:14, 20.00batch/s]
# Validation round:  22%|██▏       | 82/366 [00:01<00:10, 25.92batch/s]
# Validation round:  25%|██▍       | 91/366 [00:01<00:08, 32.76batch/s]
# Validation round:  27%|██▋       | 100/366 [00:01<00:07, 37.32batch/s]
# Validation round:  30%|███       | 110/366 [00:01<00:05, 45.67batch/s]
# Validation round:  33%|███▎      | 120/366 [00:01<00:04, 54.51batch/s]
# Validation round:  35%|███▌      | 129/366 [00:01<00:03, 60.42batch/s]
# Validation round:  38%|███▊      | 138/366 [00:02<00:03, 65.98batch/s]
# Validation round:  40%|████      | 148/366 [00:02<00:02, 73.12batch/s]
# Validation round:  44%|████▎     | 160/366 [00:02<00:02, 81.76batch/s]
# Validation round:  46%|████▋     | 170/366 [00:02<00:02, 78.47batch/s]
# Validation round:  49%|████▉     | 181/366 [00:02<00:02, 84.29batch/s]
# Validation round:  52%|█████▏    | 191/366 [00:02<00:01, 88.03batch/s]
# Validation round:  55%|█████▍    | 201/366 [00:02<00:01, 90.33batch/s]
# Validation round:  58%|█████▊    | 211/366 [00:02<00:01, 92.53batch/s]
# Validation round:  60%|██████    | 221/366 [00:02<00:01, 87.60batch/s]
# Validation round:  64%|██████▎   | 233/366 [00:03<00:01, 94.84batch/s]
# Validation round:  66%|██████▋   | 243/366 [00:03<00:01, 90.68batch/s]
# Validation round:  69%|██████▉   | 253/366 [00:03<00:01, 87.88batch/s]
# Validation round:  72%|███████▏  | 263/366 [00:03<00:01, 88.26batch/s]
# Validation round:  75%|███████▍  | 274/366 [00:03<00:01, 90.33batch/s]
# Validation round:  78%|███████▊  | 285/366 [00:03<00:00, 94.90batch/s]
# Validation round:  81%|████████  | 295/366 [00:03<00:00, 94.52batch/s]
# Validation round:  84%|████████▎ | 306/366 [00:03<00:00, 91.25batch/s]
# Validation round:  86%|████████▋ | 316/366 [00:03<00:00, 87.97batch/s]
# Validation round:  89%|████████▉ | 326/366 [00:04<00:00, 90.32batch/s]
# Validation round:  92%|█████████▏| 338/366 [00:04<00:00, 90.18batch/s]
# Validation round:  95%|█████████▌| 348/366 [00:04<00:00, 92.04batch/s]
# Validation round:  98%|█████████▊| 358/366 [00:04<00:00, 93.15batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26171790169236436
# Epoch 1/1:  28%|██▊       | 1818/6597 [01:10<01:09, 69.05img/s, loss (batch)=0.0857]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:06,  1.95batch/s]
# Validation round:   3%|▎         | 12/366 [00:00<02:07,  2.77batch/s]
# Validation round:   6%|▌         | 22/366 [00:00<01:28,  3.91batch/s]
# Validation round:   9%|▉         | 33/366 [00:00<01:00,  5.47batch/s]
# Validation round:  12%|█▏        | 45/366 [00:00<00:41,  7.66batch/s]
# Validation round:  15%|█▌        | 55/366 [00:01<00:29, 10.58batch/s]
# Validation round:  18%|█▊        | 65/366 [00:01<00:20, 14.37batch/s]
# Validation round:  20%|██        | 74/366 [00:01<00:15, 19.21batch/s]
# Validation round:  23%|██▎       | 85/366 [00:01<00:11, 25.42batch/s]
# Validation round:  26%|██▌       | 95/366 [00:01<00:08, 32.32batch/s]
# Validation round:  29%|██▊       | 105/366 [00:01<00:06, 40.25batch/s]
# Validation round:  31%|███▏      | 115/366 [00:01<00:05, 47.89batch/s]
# Validation round:  34%|███▍      | 125/366 [00:01<00:04, 56.65batch/s]
# Validation round:  37%|███▋      | 135/366 [00:01<00:03, 65.02batch/s]
# Validation round:  40%|███▉      | 145/366 [00:02<00:03, 70.66batch/s]
# Validation round:  42%|████▏     | 155/366 [00:02<00:02, 70.38batch/s]
# Validation round:  45%|████▌     | 165/366 [00:02<00:02, 77.16batch/s]
# Validation round:  48%|████▊     | 175/366 [00:02<00:02, 81.57batch/s]
# Validation round:  51%|█████     | 185/366 [00:02<00:02, 81.39batch/s]
# Validation round:  53%|█████▎    | 195/366 [00:02<00:02, 83.27batch/s]
# Validation round:  56%|█████▌    | 204/366 [00:02<00:01, 84.54batch/s]
# Validation round:  58%|█████▊    | 214/366 [00:02<00:01, 87.17batch/s]
# Validation round:  61%|██████    | 223/366 [00:02<00:01, 86.90batch/s]
# Validation round:  64%|██████▎   | 233/366 [00:03<00:01, 88.95batch/s]
# Validation round:  66%|██████▋   | 243/366 [00:03<00:01, 84.05batch/s]
# Validation round:  69%|██████▉   | 252/366 [00:03<00:01, 85.51batch/s]
# Validation round:  71%|███████▏  | 261/366 [00:03<00:01, 84.89batch/s]
# Validation round:  74%|███████▍  | 272/366 [00:03<00:01, 89.44batch/s]
# Validation round:  77%|███████▋  | 282/366 [00:03<00:00, 92.10batch/s]
# Validation round:  80%|███████▉  | 292/366 [00:03<00:00, 78.40batch/s]
# Validation round:  82%|████████▏ | 301/366 [00:03<00:00, 81.28batch/s]
# Validation round:  85%|████████▌ | 312/366 [00:03<00:00, 87.63batch/s]
# Validation round:  88%|████████▊ | 322/366 [00:04<00:00, 84.12batch/s]
# Validation round:  90%|█████████ | 331/366 [00:04<00:00, 79.84batch/s]
# Validation round:  93%|█████████▎| 342/366 [00:04<00:00, 85.46batch/s]
# Validation round:  96%|█████████▌| 352/366 [00:04<00:00, 87.80batch/s]
# Validation round:  99%|█████████▉| 363/366 [00:04<00:00, 91.67batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26366253571757853
# Epoch 1/1:  30%|███       | 2002/6597 [01:17<01:03, 72.08img/s, loss (batch)=0.11]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:03,  1.99batch/s]
# Validation round:   3%|▎         | 12/366 [00:00<02:05,  2.82batch/s]
# Validation round:   6%|▌         | 22/366 [00:00<01:26,  3.97batch/s]
# Validation round:   9%|▉         | 33/366 [00:00<00:59,  5.59batch/s]
# Validation round:  12%|█▏        | 43/366 [00:00<00:41,  7.79batch/s]
# Validation round:  14%|█▍        | 53/366 [00:01<00:29, 10.76batch/s]
# Validation round:  18%|█▊        | 65/366 [00:01<00:20, 14.69batch/s]
# Validation round:  20%|██        | 75/366 [00:01<00:14, 19.68batch/s]
# Validation round:  23%|██▎       | 85/366 [00:01<00:10, 25.68batch/s]
# Validation round:  26%|██▌       | 94/366 [00:01<00:08, 32.49batch/s]
# Validation round:  29%|██▊       | 105/366 [00:01<00:06, 39.83batch/s]
# Validation round:  31%|███▏      | 115/366 [00:01<00:05, 48.41batch/s]
# Validation round:  34%|███▍      | 125/366 [00:01<00:04, 56.99batch/s]
# Validation round:  37%|███▋      | 136/366 [00:01<00:03, 66.03batch/s]
# Validation round:  40%|███▉      | 146/366 [00:02<00:03, 72.42batch/s]
# Validation round:  43%|████▎     | 157/366 [00:02<00:02, 80.19batch/s]
# Validation round:  46%|████▌     | 167/366 [00:02<00:02, 84.84batch/s]
# Validation round:  48%|████▊     | 177/366 [00:02<00:02, 87.63batch/s]
# Validation round:  51%|█████▏    | 188/366 [00:02<00:01, 92.43batch/s]
# Validation round:  54%|█████▍    | 199/366 [00:02<00:01, 95.60batch/s]
# Validation round:  57%|█████▋    | 210/366 [00:02<00:01, 94.74batch/s]
# Validation round:  60%|██████    | 221/366 [00:02<00:01, 98.01batch/s]
# Validation round:  63%|██████▎   | 232/366 [00:02<00:01, 94.33batch/s]
# Validation round:  66%|██████▌   | 242/366 [00:02<00:01, 91.80batch/s]
# Validation round:  69%|██████▉   | 252/366 [00:03<00:01, 93.79batch/s]
# Validation round:  72%|███████▏  | 262/366 [00:03<00:01, 88.33batch/s]
# Validation round:  74%|███████▍  | 272/366 [00:03<00:01, 91.12batch/s]
# Validation round:  77%|███████▋  | 282/366 [00:03<00:00, 91.90batch/s]
# Validation round:  80%|███████▉  | 292/366 [00:03<00:00, 93.34batch/s]
# Validation round:  83%|████████▎ | 302/366 [00:03<00:00, 92.33batch/s]
# Validation round:  85%|████████▌ | 312/366 [00:03<00:00, 93.46batch/s]
# Validation round:  88%|████████▊ | 322/366 [00:03<00:00, 91.78batch/s]
# Validation round:  91%|█████████ | 332/366 [00:03<00:00, 91.43batch/s]
# Validation round:  93%|█████████▎| 342/366 [00:04<00:00, 78.14batch/s]
# Validation round:  96%|█████████▋| 353/366 [00:04<00:00, 84.41batch/s]
# Validation round: 100%|█████████▉| 365/366 [00:04<00:00, 92.30batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26384552938690603
# Epoch 1/1:  33%|███▎      | 2182/6597 [01:25<01:00, 72.92img/s, loss (batch)=0.121]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:20,  1.82batch/s]
# Validation round:   2%|▏         | 9/366 [00:00<02:18,  2.58batch/s]
# Validation round:   5%|▌         | 20/366 [00:00<01:34,  3.64batch/s]
# Validation round:   9%|▊         | 32/366 [00:00<01:05,  5.13batch/s]
# Validation round:  12%|█▏        | 43/366 [00:00<00:44,  7.18batch/s]
# Validation round:  14%|█▍        | 53/366 [00:01<00:31,  9.92batch/s]
# Validation round:  17%|█▋        | 62/366 [00:01<00:22, 13.44batch/s]
# Validation round:  19%|█▉        | 71/366 [00:01<00:16, 17.89batch/s]
# Validation round:  22%|██▏       | 80/366 [00:01<00:12, 23.39batch/s]
# Validation round:  25%|██▍       | 91/366 [00:01<00:08, 30.59batch/s]
# Validation round:  28%|██▊       | 101/366 [00:01<00:06, 38.02batch/s]
# Validation round:  30%|███       | 111/366 [00:01<00:05, 46.40batch/s]
# Validation round:  33%|███▎      | 121/366 [00:01<00:04, 54.71batch/s]
# Validation round:  36%|███▌      | 131/366 [00:01<00:03, 61.86batch/s]
# Validation round:  39%|███▊      | 141/366 [00:02<00:03, 65.99batch/s]
# Validation round:  41%|████      | 150/366 [00:02<00:03, 71.26batch/s]
# Validation round:  44%|████▎     | 160/366 [00:02<00:02, 76.76batch/s]
# Validation round:  46%|████▌     | 169/366 [00:02<00:02, 79.97batch/s]
# Validation round:  49%|████▉     | 181/366 [00:02<00:02, 80.02batch/s]
# Validation round:  53%|█████▎    | 193/366 [00:02<00:01, 88.43batch/s]
# Validation round:  56%|█████▌    | 205/366 [00:02<00:01, 89.66batch/s]
# Validation round:  59%|█████▊    | 215/366 [00:02<00:01, 91.74batch/s]
# Validation round:  61%|██████▏   | 225/366 [00:02<00:01, 93.05batch/s]
# Validation round:  64%|██████▍   | 235/366 [00:03<00:01, 94.85batch/s]
# Validation round:  67%|██████▋   | 245/366 [00:03<00:01, 92.92batch/s]
# Validation round:  70%|██████▉   | 255/366 [00:03<00:01, 93.74batch/s]
# Validation round:  72%|███████▏  | 265/366 [00:03<00:01, 89.79batch/s]
# Validation round:  75%|███████▌  | 275/366 [00:03<00:01, 90.35batch/s]
# Validation round:  78%|███████▊  | 285/366 [00:03<00:00, 84.15batch/s]
# Validation round:  81%|████████  | 295/366 [00:03<00:00, 86.91batch/s]
# Validation round:  83%|████████▎ | 304/366 [00:03<00:00, 87.27batch/s]
# Validation round:  86%|████████▌ | 314/366 [00:03<00:00, 89.93batch/s]
# Validation round:  89%|████████▉ | 325/366 [00:04<00:00, 93.27batch/s]
# Validation round:  92%|█████████▏| 335/366 [00:04<00:00, 90.36batch/s]
# Validation round:  94%|█████████▍| 345/366 [00:04<00:00, 91.65batch/s]
# Validation round:  97%|█████████▋| 355/366 [00:04<00:00, 93.43batch/s]
# Validation round: 100%|█████████▉| 365/366 [00:04<00:00, 88.53batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2637973066236152
# Epoch 1/1:  36%|███▌      | 2364/6597 [01:32<01:00, 69.53img/s, loss (batch)=0.109]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:04,  1.98batch/s]
# Validation round:   3%|▎         | 10/366 [00:00<02:07,  2.80batch/s]
# Validation round:   5%|▌         | 20/366 [00:00<01:27,  3.95batch/s]
# Validation round:   9%|▊         | 32/366 [00:00<01:00,  5.56batch/s]
# Validation round:  11%|█         | 41/366 [00:00<00:42,  7.70batch/s]
# Validation round:  14%|█▍        | 51/366 [00:01<00:29, 10.64batch/s]
# Validation round:  17%|█▋        | 61/366 [00:01<00:21, 14.51batch/s]
# Validation round:  19%|█▉        | 71/366 [00:01<00:15, 19.48batch/s]
# Validation round:  22%|██▏       | 81/366 [00:01<00:11, 25.42batch/s]
# Validation round:  25%|██▍       | 90/366 [00:01<00:08, 31.83batch/s]
# Validation round:  27%|██▋       | 100/366 [00:01<00:06, 39.63batch/s]
# Validation round:  31%|███       | 112/366 [00:01<00:05, 49.18batch/s]
# Validation round:  33%|███▎      | 122/366 [00:01<00:04, 54.95batch/s]
# Validation round:  36%|███▌      | 131/366 [00:01<00:03, 61.58batch/s]
# Validation round:  39%|███▊      | 141/366 [00:02<00:03, 68.51batch/s]
# Validation round:  41%|████▏     | 151/366 [00:02<00:02, 75.10batch/s]
# Validation round:  44%|████▍     | 161/366 [00:02<00:02, 78.10batch/s]
# Validation round:  47%|████▋     | 171/366 [00:02<00:02, 82.60batch/s]
# Validation round:  49%|████▉     | 181/366 [00:02<00:02, 83.31batch/s]
# Validation round:  52%|█████▏    | 191/366 [00:02<00:02, 87.46batch/s]
# Validation round:  55%|█████▍    | 201/366 [00:02<00:02, 77.07batch/s]
# Validation round:  57%|█████▋    | 210/366 [00:02<00:01, 79.71batch/s]
# Validation round:  60%|██████    | 220/366 [00:02<00:01, 83.80batch/s]
# Validation round:  63%|██████▎   | 229/366 [00:03<00:01, 80.20batch/s]
# Validation round:  65%|██████▌   | 238/366 [00:03<00:01, 82.48batch/s]
# Validation round:  68%|██████▊   | 248/366 [00:03<00:01, 86.04batch/s]
# Validation round:  71%|███████   | 259/366 [00:03<00:01, 91.21batch/s]
# Validation round:  73%|███████▎  | 269/366 [00:03<00:01, 88.18batch/s]
# Validation round:  76%|███████▌  | 278/366 [00:03<00:01, 87.65batch/s]
# Validation round:  78%|███████▊  | 287/366 [00:03<00:00, 85.64batch/s]
# Validation round:  81%|████████  | 296/366 [00:03<00:00, 85.71batch/s]
# Validation round:  83%|████████▎ | 305/366 [00:03<00:00, 80.31batch/s]
# Validation round:  86%|████████▌ | 315/366 [00:04<00:00, 84.61batch/s]
# Validation round:  89%|████████▊ | 324/366 [00:04<00:00, 85.52batch/s]
# Validation round:  91%|█████████ | 333/366 [00:04<00:00, 84.74batch/s]
# Validation round:  93%|█████████▎| 342/366 [00:04<00:00, 86.05batch/s]
# Validation round:  96%|█████████▌| 352/366 [00:04<00:00, 88.02batch/s]
# Validation round:  99%|█████████▊| 361/366 [00:04<00:00, 84.60batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2641301659938416
# Epoch 1/1:  39%|███▊      | 2546/6597 [01:40<00:57, 70.81img/s, loss (batch)=0.104]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<02:55,  2.08batch/s]
# Validation round:   3%|▎         | 11/366 [00:00<02:00,  2.95batch/s]
# Validation round:   5%|▌         | 20/366 [00:00<01:23,  4.15batch/s]
# Validation round:   8%|▊         | 29/366 [00:00<00:58,  5.77batch/s]
# Validation round:  11%|█         | 41/366 [00:00<00:40,  8.07batch/s]
# Validation round:  14%|█▍        | 51/366 [00:01<00:28, 11.11batch/s]
# Validation round:  17%|█▋        | 62/366 [00:01<00:20, 15.16batch/s]
# Validation round:  20%|█▉        | 73/366 [00:01<00:14, 20.45batch/s]
# Validation round:  23%|██▎       | 83/366 [00:01<00:10, 26.83batch/s]
# Validation round:  25%|██▌       | 93/366 [00:01<00:07, 34.28batch/s]
# Validation round:  28%|██▊       | 103/366 [00:01<00:06, 42.09batch/s]
# Validation round:  31%|███▏      | 115/366 [00:01<00:04, 50.40batch/s]
# Validation round:  34%|███▍      | 126/366 [00:01<00:03, 60.03batch/s]
# Validation round:  37%|███▋      | 136/366 [00:01<00:03, 66.46batch/s]
# Validation round:  40%|████      | 147/366 [00:02<00:02, 73.25batch/s]
# Validation round:  43%|████▎     | 157/366 [00:02<00:02, 78.53batch/s]
# Validation round:  46%|████▌     | 167/366 [00:02<00:02, 82.76batch/s]
# Validation round:  49%|████▊     | 178/366 [00:02<00:02, 87.98batch/s]
# Validation round:  51%|█████▏    | 188/366 [00:02<00:02, 84.29batch/s]
# Validation round:  54%|█████▍    | 199/366 [00:02<00:01, 89.11batch/s]
# Validation round:  57%|█████▋    | 209/366 [00:02<00:01, 89.54batch/s]
# Validation round:  60%|█████▉    | 219/366 [00:02<00:01, 87.29batch/s]
# Validation round:  63%|██████▎   | 229/366 [00:02<00:01, 86.63batch/s]
# Validation round:  65%|██████▌   | 239/366 [00:03<00:01, 89.85batch/s]
# Validation round:  68%|██████▊   | 249/366 [00:03<00:01, 91.58batch/s]
# Validation round:  71%|███████   | 259/366 [00:03<00:01, 90.14batch/s]
# Validation round:  73%|███████▎  | 269/366 [00:03<00:01, 91.51batch/s]
# Validation round:  76%|███████▌  | 279/366 [00:03<00:00, 90.30batch/s]
# Validation round:  79%|███████▉  | 289/366 [00:03<00:00, 92.57batch/s]
# Validation round:  82%|████████▏ | 299/366 [00:03<00:00, 92.15batch/s]
# Validation round:  85%|████████▍ | 310/366 [00:03<00:00, 96.28batch/s]
# Validation round:  87%|████████▋ | 320/366 [00:03<00:00, 90.61batch/s]
# Validation round:  90%|█████████ | 330/366 [00:04<00:00, 91.22batch/s]
# Validation round:  93%|█████████▎| 341/366 [00:04<00:00, 94.28batch/s]
# Validation round:  96%|█████████▌| 351/366 [00:04<00:00, 92.39batch/s]
# Validation round:  99%|█████████▉| 362/366 [00:04<00:00, 95.25batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26420602096560225
# Epoch 1/1:  41%|████▏     | 2730/6597 [01:47<00:53, 71.89img/s, loss (batch)=0.0818]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:16,  1.86batch/s]
# Validation round:   4%|▎         | 13/366 [00:00<02:13,  2.64batch/s]
# Validation round:   6%|▌         | 22/366 [00:00<01:32,  3.72batch/s]
# Validation round:   9%|▉         | 33/366 [00:00<01:03,  5.22batch/s]
# Validation round:  11%|█▏        | 42/366 [00:00<00:44,  7.27batch/s]
# Validation round:  14%|█▎        | 50/366 [00:01<00:31, 10.00batch/s]
# Validation round:  16%|█▋        | 60/366 [00:01<00:22, 13.64batch/s]
# Validation round:  19%|█▉        | 70/366 [00:01<00:16, 18.34batch/s]
# Validation round:  22%|██▏       | 80/366 [00:01<00:11, 24.22batch/s]
# Validation round:  24%|██▍       | 89/366 [00:01<00:08, 30.94batch/s]
# Validation round:  27%|██▋       | 100/366 [00:01<00:06, 39.30batch/s]
# Validation round:  30%|███       | 111/366 [00:01<00:05, 48.49batch/s]
# Validation round:  33%|███▎      | 121/366 [00:01<00:04, 56.46batch/s]
# Validation round:  36%|███▌      | 131/366 [00:01<00:03, 63.46batch/s]
# Validation round:  39%|███▊      | 141/366 [00:02<00:03, 70.63batch/s]
# Validation round:  42%|████▏     | 152/366 [00:02<00:02, 78.37batch/s]
# Validation round:  44%|████▍     | 162/366 [00:02<00:02, 83.63batch/s]
# Validation round:  47%|████▋     | 173/366 [00:02<00:02, 84.48batch/s]
# Validation round:  50%|█████     | 184/366 [00:02<00:02, 90.51batch/s]
# Validation round:  53%|█████▎    | 194/366 [00:02<00:01, 89.43batch/s]
# Validation round:  56%|█████▌    | 204/366 [00:02<00:01, 89.24batch/s]
# Validation round:  59%|█████▊    | 215/366 [00:02<00:01, 94.08batch/s]
# Validation round:  61%|██████▏   | 225/366 [00:02<00:01, 91.62batch/s]
# Validation round:  64%|██████▍   | 235/366 [00:03<00:01, 90.50batch/s]
# Validation round:  67%|██████▋   | 246/366 [00:03<00:01, 95.26batch/s]
# Validation round:  70%|██████▉   | 256/366 [00:03<00:01, 91.12batch/s]
# Validation round:  73%|███████▎  | 266/366 [00:03<00:01, 92.52batch/s]
# Validation round:  75%|███████▌  | 276/366 [00:03<00:01, 89.91batch/s]
# Validation round:  78%|███████▊  | 286/366 [00:03<00:00, 90.84batch/s]
# Validation round:  81%|████████  | 296/366 [00:03<00:00, 93.23batch/s]
# Validation round:  84%|████████▍ | 308/366 [00:03<00:00, 96.68batch/s]
# Validation round:  87%|████████▋ | 318/366 [00:03<00:00, 95.70batch/s]
# Validation round:  90%|████████▉ | 328/366 [00:04<00:00, 86.19batch/s]
# Validation round:  92%|█████████▏| 337/366 [00:04<00:00, 78.46batch/s]
# Validation round:  95%|█████████▍| 347/366 [00:04<00:00, 83.30batch/s]
# Validation round:  97%|█████████▋| 356/366 [00:04<00:00, 85.00batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2639988467015855
# Epoch 1/1:  44%|████▍     | 2910/6597 [01:54<00:51, 71.95img/s, loss (batch)=0.111]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<02:51,  2.13batch/s]
# Validation round:   3%|▎         | 11/366 [00:00<01:57,  3.02batch/s]
# Validation round:   6%|▌         | 21/366 [00:00<01:21,  4.26batch/s]
# Validation round:   8%|▊         | 31/366 [00:00<00:56,  5.97batch/s]
# Validation round:  11%|█         | 41/366 [00:00<00:39,  8.23batch/s]
# Validation round:  14%|█▎        | 50/366 [00:01<00:28, 11.28batch/s]
# Validation round:  16%|█▌        | 59/366 [00:01<00:20, 15.27batch/s]
# Validation round:  19%|█▊        | 68/366 [00:01<00:14, 20.23batch/s]
# Validation round:  21%|██        | 76/366 [00:01<00:11, 25.76batch/s]
# Validation round:  24%|██▍       | 89/366 [00:01<00:08, 33.13batch/s]
# Validation round:  27%|██▋       | 99/366 [00:01<00:06, 41.22batch/s]
# Validation round:  30%|██▉       | 108/366 [00:01<00:05, 48.69batch/s]
# Validation round:  32%|███▏      | 118/366 [00:01<00:04, 57.31batch/s]
# Validation round:  35%|███▌      | 129/366 [00:01<00:03, 63.97batch/s]
# Validation round:  38%|███▊      | 139/366 [00:02<00:03, 71.46batch/s]
# Validation round:  41%|████      | 150/366 [00:02<00:02, 78.56batch/s]
# Validation round:  44%|████▍     | 161/366 [00:02<00:02, 85.12batch/s]
# Validation round:  47%|████▋     | 171/366 [00:02<00:02, 88.74batch/s]
# Validation round:  49%|████▉     | 181/366 [00:02<00:02, 91.08batch/s]
# Validation round:  52%|█████▏    | 191/366 [00:02<00:02, 81.54batch/s]
# Validation round:  55%|█████▍    | 201/366 [00:02<00:01, 86.30batch/s]
# Validation round:  58%|█████▊    | 211/366 [00:02<00:01, 86.56batch/s]
# Validation round:  61%|██████    | 222/366 [00:02<00:01, 91.28batch/s]
# Validation round:  63%|██████▎   | 232/366 [00:03<00:01, 86.97batch/s]
# Validation round:  66%|██████▌   | 241/366 [00:03<00:01, 87.07batch/s]
# Validation round:  69%|██████▊   | 251/366 [00:03<00:01, 90.37batch/s]
# Validation round:  72%|███████▏  | 262/366 [00:03<00:01, 94.11batch/s]
# Validation round:  74%|███████▍  | 272/366 [00:03<00:01, 88.44batch/s]
# Validation round:  77%|███████▋  | 282/366 [00:03<00:00, 87.27batch/s]
# Validation round:  80%|███████▉  | 292/366 [00:03<00:00, 90.57batch/s]
# Validation round:  83%|████████▎ | 303/366 [00:03<00:00, 92.65batch/s]
# Validation round:  86%|████████▌ | 313/366 [00:03<00:00, 85.47batch/s]
# Validation round:  88%|████████▊ | 323/366 [00:04<00:00, 88.73batch/s]
# Validation round:  91%|█████████ | 333/366 [00:04<00:00, 91.10batch/s]
# Validation round:  94%|█████████▎| 343/366 [00:04<00:00, 84.71batch/s]
# Validation round:  96%|█████████▌| 352/366 [00:04<00:00, 84.14batch/s]
# Validation round:  99%|█████████▉| 364/366 [00:04<00:00, 91.03batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26385684954664096
# Epoch 1/1:  47%|████▋     | 3092/6597 [02:02<00:48, 71.75img/s, loss (batch)=0.0927]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:05,  1.97batch/s]
# Validation round:   3%|▎         | 11/366 [00:00<02:07,  2.79batch/s]
# Validation round:   6%|▌         | 21/366 [00:00<01:27,  3.94batch/s]
# Validation round:   9%|▊         | 32/366 [00:00<01:00,  5.54batch/s]
# Validation round:  11%|█▏        | 42/366 [00:00<00:42,  7.68batch/s]
# Validation round:  14%|█▍        | 52/366 [00:01<00:29, 10.62batch/s]
# Validation round:  17%|█▋        | 63/366 [00:01<00:20, 14.55batch/s]
# Validation round:  20%|██        | 74/366 [00:01<00:15, 19.40batch/s]
# Validation round:  23%|██▎       | 83/366 [00:01<00:11, 25.33batch/s]
# Validation round:  25%|██▌       | 93/366 [00:01<00:08, 32.41batch/s]
# Validation round:  29%|██▊       | 105/366 [00:01<00:06, 41.48batch/s]
# Validation round:  31%|███▏      | 115/366 [00:01<00:05, 47.61batch/s]
# Validation round:  34%|███▍      | 125/366 [00:01<00:04, 56.18batch/s]
# Validation round:  37%|███▋      | 136/366 [00:01<00:03, 65.60batch/s]
# Validation round:  40%|███▉      | 146/366 [00:02<00:03, 68.72batch/s]
# Validation round:  43%|████▎     | 158/366 [00:02<00:02, 77.59batch/s]
# Validation round:  46%|████▌     | 169/366 [00:02<00:02, 83.75batch/s]
# Validation round:  49%|████▉     | 179/366 [00:02<00:02, 86.90batch/s]
# Validation round:  52%|█████▏    | 189/366 [00:02<00:01, 88.79batch/s]
# Validation round:  54%|█████▍    | 199/366 [00:02<00:01, 90.09batch/s]
# Validation round:  57%|█████▋    | 209/366 [00:02<00:01, 83.18batch/s]
# Validation round:  60%|██████    | 220/366 [00:02<00:01, 88.18batch/s]
# Validation round:  63%|██████▎   | 231/366 [00:02<00:01, 91.64batch/s]
# Validation round:  66%|██████▌   | 241/366 [00:03<00:01, 87.80batch/s]
# Validation round:  69%|██████▊   | 251/366 [00:03<00:01, 82.49batch/s]
# Validation round:  71%|███████▏  | 261/366 [00:03<00:01, 85.97batch/s]
# Validation round:  74%|███████▍  | 272/366 [00:03<00:01, 91.33batch/s]
# Validation round:  77%|███████▋  | 282/366 [00:03<00:00, 89.38batch/s]
# Validation round:  80%|████████  | 293/366 [00:03<00:00, 93.35batch/s]
# ...
# Validation round:  33%|███▎      | 121/366 [00:01<00:04, 56.00batch/s]
# Validation round:  36%|███▌      | 132/366 [00:01<00:03, 64.89batch/s]
# Validation round:  39%|███▉      | 142/366 [00:02<00:03, 71.44batch/s]
# Validation round:  42%|████▏     | 152/366 [00:02<00:02, 78.10batch/s]
# Validation round:  44%|████▍     | 162/366 [00:02<00:02, 79.08batch/s]
# Validation round:  47%|████▋     | 173/366 [00:02<00:02, 85.65batch/s]
# Validation round:  50%|█████     | 183/366 [00:02<00:02, 84.89batch/s]
# Validation round:  53%|█████▎    | 193/366 [00:02<00:02, 83.38batch/s]
# Validation round:  55%|█████▌    | 202/366 [00:02<00:02, 81.91batch/s]
# Validation round:  58%|█████▊    | 213/366 [00:02<00:01, 87.05batch/s]
# Validation round:  61%|██████    | 223/366 [00:02<00:01, 87.67batch/s]
# Validation round:  64%|██████▎   | 233/366 [00:03<00:01, 82.44batch/s]
# Validation round:  66%|██████▋   | 243/366 [00:03<00:01, 86.34batch/s]
# Validation round:  69%|██████▉   | 252/366 [00:03<00:01, 85.54batch/s]
# Validation round:  72%|███████▏  | 263/366 [00:03<00:01, 90.57batch/s]
# Validation round:  75%|███████▍  | 273/366 [00:03<00:01, 88.24batch/s]
# Validation round:  77%|███████▋  | 283/366 [00:03<00:00, 90.37batch/s]
# Validation round:  80%|████████  | 293/366 [00:03<00:00, 91.56batch/s]
# Validation round:  83%|████████▎ | 303/366 [00:03<00:00, 91.88batch/s]
# Validation round:  86%|████████▌ | 313/366 [00:03<00:00, 84.18batch/s]
# Validation round:  89%|████████▊ | 324/366 [00:04<00:00, 89.01batch/s]
# Validation round:  91%|█████████▏| 334/366 [00:04<00:00, 88.24batch/s]
# Validation round:  94%|█████████▎| 343/366 [00:04<00:00, 87.24batch/s]
# Validation round:  96%|█████████▋| 353/366 [00:04<00:00, 87.66batch/s]
# Validation round:  99%|█████████▉| 364/366 [00:04<00:00, 91.70batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2641856896747005
# Epoch 1/1:  52%|█████▏    | 3458/6597 [02:17<00:45, 69.24img/s, loss (batch)=0.098]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:07,  1.94batch/s]
# Validation round:   3%|▎         | 11/366 [00:00<02:08,  2.75batch/s]
# Validation round:   6%|▌         | 21/366 [00:00<01:28,  3.89batch/s]
# Validation round:   8%|▊         | 30/366 [00:00<01:01,  5.45batch/s]
# Validation round:  11%|█         | 40/366 [00:00<00:42,  7.59batch/s]
# Validation round:  14%|█▎        | 50/366 [00:01<00:30, 10.49batch/s]
# Validation round:  16%|█▋        | 60/366 [00:01<00:21, 14.20batch/s]
# Validation round:  20%|█▉        | 72/366 [00:01<00:15, 19.23batch/s]
# Validation round:  22%|██▏       | 82/366 [00:01<00:11, 25.34batch/s]
# Validation round:  25%|██▌       | 92/366 [00:01<00:08, 32.20batch/s]
# Validation round:  28%|██▊       | 102/366 [00:01<00:06, 40.29batch/s]
# Validation round:  31%|███       | 112/366 [00:01<00:05, 48.16batch/s]
# Validation round:  34%|███▎      | 123/366 [00:01<00:04, 57.33batch/s]
# Validation round:  36%|███▋      | 133/366 [00:01<00:03, 63.22batch/s]
# Validation round:  39%|███▉      | 143/366 [00:02<00:03, 70.74batch/s]
# Validation round:  42%|████▏     | 153/366 [00:02<00:02, 75.95batch/s]
# Validation round:  45%|████▍     | 164/366 [00:02<00:02, 79.49batch/s]
# Validation round:  48%|████▊     | 174/366 [00:02<00:02, 84.65batch/s]
# Validation round:  50%|█████     | 184/366 [00:02<00:02, 87.50batch/s]
# Validation round:  53%|█████▎    | 194/366 [00:02<00:02, 85.81batch/s]
# Validation round:  56%|█████▌    | 204/366 [00:02<00:01, 86.24batch/s]
# Validation round:  58%|█████▊    | 213/366 [00:02<00:01, 87.31batch/s]
# Validation round:  61%|██████    | 223/366 [00:02<00:01, 89.56batch/s]
# Validation round:  64%|██████▎   | 233/366 [00:03<00:01, 90.52batch/s]
# Validation round:  67%|██████▋   | 244/366 [00:03<00:01, 88.97batch/s]
# Validation round:  69%|██████▉   | 253/366 [00:03<00:01, 88.03batch/s]
# Validation round:  72%|███████▏  | 263/366 [00:03<00:01, 89.86batch/s]
# Validation round:  75%|███████▍  | 273/366 [00:03<00:01, 90.97batch/s]
# Validation round:  77%|███████▋  | 283/366 [00:03<00:00, 93.03batch/s]
# Validation round:  80%|████████  | 293/366 [00:03<00:00, 89.04batch/s]
# Validation round:  83%|████████▎ | 302/366 [00:03<00:00, 87.40batch/s]
# Validation round:  85%|████████▍ | 311/366 [00:03<00:00, 88.00batch/s]
# Validation round:  87%|████████▋ | 320/366 [00:03<00:00, 88.32batch/s]
# Validation round:  90%|█████████ | 331/366 [00:04<00:00, 91.93batch/s]
# Validation round:  93%|█████████▎| 341/366 [00:04<00:00, 80.69batch/s]
# Validation round:  96%|█████████▌| 352/366 [00:04<00:00, 85.64batch/s]
# Validation round:  99%|█████████▉| 363/366 [00:04<00:00, 90.92batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2638179856897052
# Epoch 1/1:  55%|█████▌    | 3638/6597 [02:24<00:43, 67.90img/s, loss (batch)=0.123]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:26,  1.77batch/s]
# Validation round:   3%|▎         | 10/366 [00:00<02:22,  2.50batch/s]
# Validation round:   6%|▌         | 22/366 [00:00<01:37,  3.54batch/s]
# Validation round:   9%|▊         | 32/366 [00:00<01:07,  4.98batch/s]
# Validation round:  12%|█▏        | 43/366 [00:00<00:46,  6.97batch/s]
# Validation round:  15%|█▍        | 54/366 [00:01<00:32,  9.67batch/s]
# Validation round:  18%|█▊        | 65/366 [00:01<00:22, 13.29batch/s]
# Validation round:  20%|██        | 75/366 [00:01<00:16, 17.85batch/s]
# Validation round:  23%|██▎       | 85/366 [00:01<00:11, 23.56batch/s]
# Validation round:  26%|██▌       | 95/366 [00:01<00:08, 30.41batch/s]
# Validation round:  29%|██▉       | 107/366 [00:01<00:06, 38.86batch/s]
# Validation round:  32%|███▏      | 118/366 [00:01<00:05, 47.79batch/s]
# Validation round:  36%|███▌      | 130/366 [00:01<00:04, 57.78batch/s]
# Validation round:  39%|███▊      | 141/366 [00:01<00:03, 66.95batch/s]
# Validation round:  42%|████▏     | 153/366 [00:02<00:02, 76.28batch/s]
# Validation round:  45%|████▍     | 164/366 [00:02<00:02, 80.17batch/s]
# Validation round:  48%|████▊     | 175/366 [00:02<00:02, 84.22batch/s]
# Validation round:  51%|█████     | 186/366 [00:02<00:02, 84.94batch/s]
# Validation round:  54%|█████▎    | 196/366 [00:02<00:01, 88.18batch/s]
# Validation round:  56%|█████▋    | 206/366 [00:02<00:01, 89.68batch/s]
# Validation round:  59%|█████▉    | 216/366 [00:02<00:01, 90.59batch/s]
# Validation round:  62%|██████▏   | 226/366 [00:02<00:01, 88.53batch/s]
# Validation round:  65%|██████▍   | 237/366 [00:02<00:01, 91.90batch/s]
# Validation round:  67%|██████▋   | 247/366 [00:03<00:01, 92.75batch/s]
# Validation round:  70%|███████   | 257/366 [00:03<00:01, 94.20batch/s]
# Validation round:  73%|███████▎  | 267/366 [00:03<00:01, 93.38batch/s]
# Validation round:  76%|███████▌  | 277/366 [00:03<00:00, 90.41batch/s]
# Validation round:  78%|███████▊  | 287/366 [00:03<00:00, 87.10batch/s]
# Validation round:  81%|████████  | 297/366 [00:03<00:00, 89.74batch/s]
# Validation round:  84%|████████▍ | 307/366 [00:03<00:00, 85.98batch/s]
# Validation round:  86%|████████▋ | 316/366 [00:03<00:00, 86.06batch/s]
# Validation round:  89%|████████▉ | 326/366 [00:03<00:00, 88.80batch/s]
# Validation round:  92%|█████████▏| 335/366 [00:04<00:00, 89.14batch/s]
# Validation round:  94%|█████████▍| 345/366 [00:04<00:00, 90.23batch/s]
# Validation round:  97%|█████████▋| 355/366 [00:04<00:00, 88.03batch/s]
# Validation round: 100%|██████████| 366/366 [00:04<00:00, 91.93batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2636636756156963
# Epoch 1/1:  58%|█████▊    | 3820/6597 [02:32<00:38, 73.06img/s, loss (batch)=0.116]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:24,  1.78batch/s]
# Validation round:   3%|▎         | 12/366 [00:00<02:19,  2.53batch/s]
# Validation round:   6%|▌         | 22/366 [00:00<01:36,  3.58batch/s]
# Validation round:   8%|▊         | 31/366 [00:00<01:06,  5.02batch/s]
# Validation round:  11%|█         | 39/366 [00:00<00:46,  6.98batch/s]
# Validation round:  14%|█▎        | 50/366 [00:01<00:32,  9.69batch/s]
# Validation round:  17%|█▋        | 62/366 [00:01<00:22, 13.35batch/s]
# Validation round:  19%|█▉        | 71/366 [00:01<00:16, 17.78batch/s]
# Validation round:  22%|██▏       | 82/366 [00:01<00:11, 23.74batch/s]
# Validation round:  25%|██▌       | 92/366 [00:01<00:09, 30.17batch/s]
# Validation round:  28%|██▊       | 102/366 [00:01<00:06, 37.85batch/s]
# Validation round:  31%|███       | 112/366 [00:01<00:05, 46.39batch/s]
# Validation round:  33%|███▎      | 122/366 [00:01<00:04, 54.26batch/s]
# Validation round:  36%|███▌      | 132/366 [00:01<00:03, 60.63batch/s]
# Validation round:  39%|███▊      | 141/366 [00:02<00:03, 66.95batch/s]
# Validation round:  41%|████▏     | 151/366 [00:02<00:02, 73.35batch/s]
# Validation round:  44%|████▍     | 162/366 [00:02<00:02, 77.38batch/s]
# Validation round:  47%|████▋     | 172/366 [00:02<00:02, 82.70batch/s]
# Validation round:  50%|████▉     | 182/366 [00:02<00:02, 85.11batch/s]
# Validation round:  52%|█████▏    | 192/366 [00:02<00:02, 82.48batch/s]
# Validation round:  55%|█████▌    | 202/366 [00:02<00:02, 80.40batch/s]
# Validation round:  58%|█████▊    | 211/366 [00:02<00:01, 81.38batch/s]
# Validation round:  60%|██████    | 221/366 [00:02<00:01, 84.60batch/s]
# Validation round:  63%|██████▎   | 231/366 [00:03<00:01, 86.92batch/s]
# Validation round:  66%|██████▌   | 242/366 [00:03<00:01, 87.81batch/s]
# Validation round:  69%|██████▊   | 251/366 [00:03<00:01, 86.91batch/s]
# Validation round:  72%|███████▏  | 262/366 [00:03<00:01, 92.28batch/s]
# Validation round:  74%|███████▍  | 272/366 [00:03<00:01, 93.00batch/s]
# Validation round:  77%|███████▋  | 282/366 [00:03<00:00, 90.39batch/s]
# Validation round:  80%|███████▉  | 292/366 [00:03<00:00, 90.43batch/s]
# Validation round:  83%|████████▎ | 302/366 [00:03<00:00, 90.62batch/s]
# Validation round:  85%|████████▌ | 312/366 [00:03<00:00, 90.61batch/s]
# Validation round:  88%|████████▊ | 322/366 [00:04<00:00, 90.03batch/s]
# Validation round:  91%|█████████ | 332/366 [00:04<00:00, 87.80batch/s]
# Validation round:  93%|█████████▎| 341/366 [00:04<00:00, 86.66batch/s]
# Validation round:  96%|█████████▌| 351/366 [00:04<00:00, 88.84batch/s]
# Validation round:  99%|█████████▉| 362/366 [00:04<00:00, 88.97batch/s]
#                                                                       INFO: Validation Dice Loss: 0.2642402049622249
# Epoch 1/1:  61%|██████    | 4002/6597 [02:39<00:36, 71.07img/s, loss (batch)=0.104]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:02,  2.00batch/s]
# Validation round:   3%|▎         | 12/366 [00:00<02:05,  2.83batch/s]
# Validation round:   6%|▌         | 22/366 [00:00<01:26,  3.99batch/s]
# Validation round:   9%|▊         | 32/366 [00:00<00:59,  5.61batch/s]
# Validation round:  11%|█         | 41/366 [00:00<00:42,  7.72batch/s]
# Validation round:  14%|█▎        | 50/366 [00:01<00:29, 10.63batch/s]
# Validation round:  17%|█▋        | 61/366 [00:01<00:20, 14.56batch/s]
# Validation round:  19%|█▉        | 70/366 [00:01<00:15, 19.17batch/s]
# Validation round:  22%|██▏       | 80/366 [00:01<00:11, 25.20batch/s]
# Validation round:  25%|██▍       | 91/366 [00:01<00:08, 32.55batch/s]
# Validation round:  27%|██▋       | 100/366 [00:01<00:06, 39.78batch/s]
# Validation round:  31%|███       | 112/366 [00:01<00:05, 49.14batch/s]
# Validation round:  34%|███▎      | 123/366 [00:01<00:04, 58.69batch/s]
# Validation round:  37%|███▋      | 134/366 [00:01<00:03, 67.75batch/s]
# Validation round:  40%|███▉      | 145/366 [00:02<00:02, 73.92batch/s]
# Validation round:  43%|████▎     | 156/366 [00:02<00:02, 81.38batch/s]
# Validation round:  46%|████▌     | 167/366 [00:02<00:02, 82.30batch/s]
# Validation round:  49%|████▉     | 179/366 [00:02<00:02, 89.32batch/s]
# Validation round:  52%|█████▏    | 191/366 [00:02<00:01, 95.09batch/s]
# Validation round:  55%|█████▌    | 202/366 [00:02<00:01, 95.32batch/s]
# Validation round:  58%|█████▊    | 214/366 [00:02<00:01, 100.18batch/s]
# Validation round:  61%|██████▏   | 225/366 [00:02<00:01, 98.38batch/s]
# Validation round:  64%|██████▍   | 236/366 [00:02<00:01, 98.15batch/s]
# Validation round:  67%|██████▋   | 247/366 [00:03<00:01, 97.96batch/s]
# Validation round:  70%|███████   | 257/366 [00:03<00:01, 95.06batch/s]
# Validation round:  73%|███████▎  | 268/366 [00:03<00:00, 98.45batch/s]
# Validation round:  76%|███████▌  | 278/366 [00:03<00:00, 90.15batch/s]
# Validation round:  79%|███████▊  | 288/366 [00:03<00:00, 92.36batch/s]
# Validation round:  81%|████████▏ | 298/366 [00:03<00:00, 89.71batch/s]
# Validation round:  84%|████████▍ | 308/366 [00:03<00:00, 87.05batch/s]
# Validation round:  87%|████████▋ | 317/366 [00:03<00:00, 83.34batch/s]
# Validation round:  89%|████████▉ | 327/366 [00:03<00:00, 86.55batch/s]
# Validation round:  92%|█████████▏| 336/366 [00:04<00:00, 83.68batch/s]
# Validation round:  95%|█████████▍| 347/366 [00:04<00:00, 90.09batch/s]
# Validation round:  98%|█████████▊| 357/366 [00:04<00:00, 84.29batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26422725471316794
# Epoch 1/1:  63%|██████▎   | 4186/6597 [02:47<00:36, 65.62img/s, loss (batch)=0.113]
# Validation round:   0%|          | 0/366 [00:00<?, ?batch/s]
# Validation round:   0%|          | 1/366 [00:00<03:05,  1.97batch/s]
# Validation round:   3%|▎         | 11/366 [00:00<02:07,  2.79batch/s]
# Validation round:   6%|▌         | 21/366 [00:00<01:27,  3.94batch/s]
# Validation round:   9%|▊         | 32/366 [00:00<01:00,  5.54batch/s]
# Validation round:  12%|█▏        | 44/366 [00:00<00:41,  7.75batch/s]
# Validation round:  15%|█▌        | 56/366 [00:01<00:28, 10.75batch/s]
# Validation round:  18%|█▊        | 66/366 [00:01<00:20, 14.56batch/s]
# Validation round:  21%|██        | 77/366 [00:01<00:14, 19.63batch/s]
# Validation round:  24%|██▍       | 87/366 [00:01<00:10, 25.45batch/s]
# Validation round:  27%|██▋       | 99/366 [00:01<00:08, 33.08batch/s]
# Validation round:  30%|███       | 110/366 [00:01<00:06, 41.53batch/s]
# Validation round:  33%|███▎      | 121/366 [00:01<00:04, 51.01batch/s]
# Validation round:  36%|███▋      | 133/366 [00:01<00:03, 61.16batch/s]
# Validation round:  39%|███▉      | 144/366 [00:01<00:03, 66.00batch/s]
# Validation round:  42%|████▏     | 155/366 [00:02<00:02, 74.10batch/s]
# Validation round:  45%|████▌     | 165/366 [00:02<00:02, 77.97batch/s]
# Validation round:  48%|████▊     | 175/366 [00:02<00:02, 82.82batch/s]
# Validation round:  51%|█████     | 185/366 [00:02<00:02, 85.84batch/s]
# Validation round:  54%|█████▍    | 197/366 [00:02<00:01, 92.64batch/s]
# Validation round:  57%|█████▋    | 208/366 [00:02<00:01, 90.55batch/s]
# Validation round:  60%|█████▉    | 218/366 [00:02<00:01, 91.47batch/s]
# Validation round:  62%|██████▏   | 228/366 [00:02<00:01, 89.97batch/s]
# Validation round:  65%|██████▌   | 239/366 [00:02<00:01, 94.23batch/s]
# Validation round:  68%|██████▊   | 249/366 [00:03<00:01, 95.27batch/s]
# Validation round:  71%|███████▏  | 261/366 [00:03<00:01, 99.53batch/s]
# Validation round:  74%|███████▍  | 272/366 [00:03<00:00, 95.27batch/s]
# Validation round:  77%|███████▋  | 283/366 [00:03<00:00, 97.34batch/s]
# Validation round:  80%|████████  | 293/366 [00:03<00:00, 96.42batch/s]
# Validation round:  83%|████████▎ | 304/366 [00:03<00:00, 99.04batch/s]
# Validation round:  86%|████████▌ | 315/366 [00:03<00:00, 100.51batch/s]
# Validation round:  89%|████████▉ | 327/366 [00:03<00:00, 99.30batch/s]
# Validation round:  92%|█████████▏| 337/366 [00:03<00:00, 93.15batch/s]
# Validation round:  95%|█████████▍| 347/366 [00:04<00:00, 86.31batch/s]
# Validation round:  98%|█████████▊| 357/366 [00:04<00:00, 88.80batch/s]
#                                                                       INFO: Validation Dice Loss: 0.26404255050453335
# Epoch 1/1:  66%|██████▌   | 4366/6597 [02:54<00:31, 71.36img/s, loss (batch)=0.13]

# %%
net1 = UNet(n_channels=1, n_classes=15, bilinear=True)

logging.info(f'Network:\n'
             f'\t{net1.n_channels} input channels\n'
             f'\t{net1.n_classes} output channels (classes)\n'
             f'\t{"Bilinear" if net1.bilinear else "Transposed conv"} upscaling')

net1.to(device=device)
train_scores1, val_scores1, train_var_1, val_var_1 = train_net(net=net1,
                                                                epochs=args.epochs,
                                                                batch_size=args.batchsize,
                                                                lr=args.lr,
                                                                device=device,
                                                                img_scale=args.scale,
                                                                val_percent=args.val / 100,
                                                                checkpoint=1,
                                                                target_label_numbers=target_label_numbers,
                                                                dataset=dataset,
                                                                train_loader=train_loader,
                                                                val_loader=val_loader,
                                                                writer=writer)
# Out:
# INFO: Network:
# 	1 input channels
# 	15 output channels (classes)
# 	Bilinear upscaling
# INFO: Starting training:
#         Epochs:          1
#         Batch size:      8
#         Learning rate:   0.001
#         Training size:   6597
#         Validation size: 732
#         Checkpoints:     True
#         Device:          cuda
#         Images scaling:  1
#
# Epoch 1/1:  11%|█         | 728/6597 [00:15<02:09, 45.39img/s, loss (batch)=0.141]
# Validation round:   0%|          | 0/91 [00:00<?, ?batch/s]
# Validation round:   1%|          | 1/91 [00:01<02:36,  1.74s/batch]
# Validation round:   4%|▍         | 4/91 [00:01<01:47,  1.23s/batch]
# Validation round:   8%|▊         | 7/91 [00:01<01:13,  1.14batch/s]
# Validation round:  10%|▉         | 9/91 [00:02<00:57,  1.41batch/s]
# Validation round:  12%|█▏        | 11/91 [00:02<00:41,  1.93batch/s]
# Validation round:  15%|█▌        | 14/91 [00:02<00:28,  2.68batch/s]
# Validation round:  19%|█▊        | 17/91 [00:03<00:26,  2.82batch/s]
# Validation round:  21%|██        | 19/91 [00:03<00:19,  3.67batch/s]
# Validation round:  24%|██▍       | 22/91 [00:04<00:13,  4.97batch/s]
# Validation round:  27%|██▋       | 25/91 [00:04<00:14,  4.51batch/s]
# Validation round:  31%|███       | 28/91 [00:04<00:10,  6.03batch/s]
# Validation round:  34%|███▍      | 31/91 [00:05<00:07,  7.91batch/s]
# Validation round:  37%|███▋      | 34/91 [00:06<00:10,  5.50batch/s]
# Validation round:  41%|████      | 37/91 [00:06<00:07,  7.27batch/s]
# Validation round:  44%|████▍     | 40/91 [00:06<00:05,  9.36batch/s]
# Validation round:  47%|████▋     | 43/91 [00:07<00:09,  5.00batch/s]
# Validation round:  51%|█████     | 46/91 [00:07<00:06,  6.64batch/s]
# Validation round:  54%|█████▍    | 49/91 [00:08<00:08,  5.23batch/s]
# Validation round:  57%|█████▋    | 52/91 [00:08<00:06,  5.96batch/s]
# Validation round:  60%|██████    | 55/91 [00:08<00:04,  7.81batch/s]
# Validation round:  63%|██████▎   | 57/91 [00:09<00:06,  5.35batch/s]
# Validation round:  66%|██████▌   | 60/91 [00:09<00:04,  6.31batch/s]
# Epoch 1/1:  11%|█         | 728/6597 [00:30<02:09, 45.39img/s, loss (batch)=0.141]
# Validation round:  71%|███████▏  | 65/91 [00:10<00:05,  4.87batch/s]
# Validation round:  75%|███████▍  | 68/91 [00:11<00:04,  5.63batch/s]
# Validation round:  78%|███████▊  | 71/91 [00:11<00:02,  7.41batch/s]
# Validation round:  80%|████████  | 73/91 [00:11<00:03,  4.83batch/s]
# Validation round:  84%|████████▎ | 76/91 [00:12<00:02,  5.43batch/s]
# Validation round:  87%|████████▋ | 79/91 [00:12<00:01,  7.18batch/s]
# Validation round:  89%|████████▉ | 81/91 [00:13<00:02,  4.85batch/s]
# Validation round:  92%|█████████▏| 84/91 [00:13<00:01,  6.42batch/s]
# Validation round:  96%|█████████▌| 87/91 [00:13<00:00,  8.33batch/s]
# Validation round:  98%|█████████▊| 89/91 [00:13<00:00,  8.18batch/s]
#                                                                     INFO: Validation Dice Loss: 0.060606623007045994
# Epoch 1/1:  22%|██▏       | 1456/6597 [00:46<01:22, 62.15img/s, loss (batch)=0.112]
# Validation round:   0%|          | 0/91 [00:00<?, ?batch/s]
# Validation round:   1%|          | 1/91 [00:00<01:06,  1.35batch/s]
# Validation round:   4%|▍         | 4/91 [00:00<00:46,  1.88batch/s]
# Validation round:   8%|▊         | 7/91 [00:00<00:32,  2.61batch/s]
# Validation round:  11%|█         | 10/91 [00:01<00:22,  3.57batch/s]
# Validation round:  14%|█▍        | 13/91 [00:01<00:16,  4.84batch/s]
# Validation round:  18%|█▊        | 16/91 [00:01<00:11,  6.43batch/s]
# Validation round:  21%|██        | 19/91 [00:01<00:08,  8.14batch/s]
# Validation round:  24%|██▍       | 22/91 [00:01<00:06, 10.35batch/s]
# Validation round:  27%|██▋       | 25/91 [00:01<00:05, 12.71batch/s]
# Validation round:  31%|███       | 28/91 [00:01<00:04, 15.20batch/s]
# Validation round:  34%|███▍      | 31/91 [00:01<00:03, 17.67batch/s]
# Validation round:  37%|███▋      | 34/91 [00:01<00:02, 19.79batch/s]
# Validation round:  41%|████      | 37/91 [00:02<00:02, 21.67batch/s]
# Validation round:  44%|████▍     | 40/91 [00:02<00:02, 23.30batch/s]
# Validation round:  47%|████▋     | 43/91 [00:02<00:02, 19.52batch/s]
# Validation round:  51%|█████     | 46/91 [00:02<00:02, 21.51batch/s]
# Validation round:  54%|█████▍    | 49/91 [00:02<00:02, 20.16batch/s]
# Validation round:  57%|█████▋    | 52/91 [00:02<00:01, 22.10batch/s]
# Validation round:  60%|██████    | 55/91 [00:02<00:01, 23.56batch/s]
# Validation round:  64%|██████▎   | 58/91 [00:03<00:01, 23.75batch/s]
# Validation round:  67%|██████▋   | 61/91 [00:03<00:01, 24.89batch/s]
# Validation round:  70%|███████   | 64/91 [00:03<00:01, 25.71batch/s]
# Validation round:  74%|███████▎  | 67/91 [00:03<00:00, 24.01batch/s]
# Validation round:  77%|███████▋  | 70/91 [00:03<00:00, 25.08batch/s]
# Validation round:  80%|████████  | 73/91 [00:03<00:00, 24.02batch/s]
# Validation round:  84%|████████▎ | 76/91 [00:03<00:00, 25.15batch/s]
# Validation round:  87%|████████▋ | 79/91 [00:03<00:00, 25.78batch/s]
# Validation round:  90%|█████████ | 82/91 [00:03<00:00, 25.47batch/s]
# Validation round:  93%|█████████▎| 85/91 [00:04<00:00, 26.32batch/s]
# Validation round:  97%|█████████▋| 88/91 [00:04<00:00, 26.93batch/s]
# Validation round: 100%|██████████| 91/91 [00:04<00:00, 25.76batch/s]
#                                                                     INFO: Validation Dice Loss: 0.05498595412943389
# Epoch 1/1:  33%|███▎      | 2184/6597 [01:07<02:10, 33.69img/s, loss (batch)=0.112]
# Validation round:   0%|          | 0/91 [00:00<?, ?batch/s]
# Validation round:   1%|          | 1/91 [00:00<01:04,  1.40batch/s]
# Validation round:   4%|▍         | 4/91 [00:00<00:44,  1.96batch/s]
# Validation round:   8%|▊         | 7/91 [00:00<00:30,  2.71batch/s]
# Validation round:  11%|█         | 10/91 [00:01<00:21,  3.71batch/s]
# Validation round:  14%|█▍        | 13/91 [00:01<00:15,  4.99batch/s]
# Validation round:  18%|█▊        | 16/91 [00:01<00:11,  6.61batch/s]
# Validation round:  21%|██        | 19/91 [00:01<00:08,  8.58batch/s]
# Validation round:  24%|██▍       | 22/91 [00:01<00:06, 10.84batch/s]
# Validation round:  27%|██▋       | 25/91 [00:01<00:04, 13.27batch/s]
# Validation round:  31%|███       | 28/91 [00:01<00:03, 15.78batch/s]
# Validation round:  34%|███▍      | 31/91 [00:01<00:03, 18.16batch/s]
# Validation round:  37%|███▋      | 34/91 [00:01<00:02, 20.32batch/s]
# Validation round:  41%|████      | 37/91 [00:02<00:02, 22.18batch/s]
# Validation round:  44%|████▍     | 40/91 [00:02<00:02, 23.58batch/s]
# Validation round:  47%|████▋     | 43/91 [00:02<00:01, 24.64batch/s]
# Validation round:  51%|█████     | 46/91 [00:02<00:01, 25.55batch/s]
# Validation round:  54%|█████▍    | 49/91 [00:02<00:01, 25.99batch/s]
# Validation round:  57%|█████▋    | 52/91 [00:02<00:01, 26.43batch/s]
# Validation round:  60%|██████    | 55/91 [00:02<00:01, 26.95batch/s]
# Validation round:  64%|██████▎   | 58/91 [00:02<00:01, 27.12batch/s]
# Validation round:  67%|██████▋   | 61/91 [00:02<00:01, 27.31batch/s]
# Validation round:  70%|███████   | 64/91 [00:03<00:00, 27.43batch/s]
# Validation round:  74%|███████▎  | 67/91 [00:03<00:00, 27.35batch/s]
# Validation round:  77%|███████▋  | 70/91 [00:03<00:00, 27.49batch/s]
# Validation round:  80%|████████  | 73/91 [00:03<00:00, 24.46batch/s]
# Validation round:  84%|████████▎ | 76/91 [00:03<00:00, 25.32batch/s]
# Validation round:  87%|████████▋ | 79/91 [00:03<00:00, 25.95batch/s]
# Validation round:  90%|█████████ | 82/91 [00:03<00:00, 24.43batch/s]
# Validation round:  93%|█████████▎| 85/91 [00:03<00:00, 25.40batch/s]
# Validation round:  97%|█████████▋| 88/91 [00:03<00:00, 25.93batch/s]
# Validation round: 100%|██████████| 91/91 [00:04<00:00, 25.10batch/s]
#                                                                     INFO: Validation Dice Loss: 0.05684054135293751
# Epoch 1/1:  44%|████▍     | 2912/6597 [01:28<01:15, 49.02img/s, loss (batch)=0.105]
# Validation round:   0%|          | 0/91 [00:00<?, ?batch/s]
# Validation round:   1%|          | 1/91 [00:00<00:59,  1.50batch/s]
# Validation round:   4%|▍         | 4/91 [00:00<00:41,  2.10batch/s]
# Validation round:   8%|▊         | 7/91 [00:00<00:28,  2.90batch/s]
# Validation round:  11%|█         | 10/91 [00:00<00:20,  3.97batch/s]
# Validation round:  14%|█▍        | 13/91 [00:01<00:14,  5.34batch/s]
# Validation round:  18%|█▊        | 16/91 [00:01<00:10,  7.04batch/s]
# Validation round:  21%|██        | 19/91 [00:01<00:07,  9.08batch/s]
# Validation round:  24%|██▍       | 22/91 [00:01<00:06, 11.38batch/s]
# Validation round:  27%|██▋       | 25/91 [00:01<00:04, 13.82batch/s]
# Validation round:  31%|███       | 28/91 [00:01<00:03, 16.29batch/s]
# Validation round:  34%|███▍      | 31/91 [00:01<00:03, 18.63batch/s]
# Validation round:  37%|███▋      | 34/91 [00:01<00:02, 20.62batch/s]
# Validation round:  41%|████      | 37/91 [00:01<00:02, 22.35batch/s]
# Validation round:  44%|████▍     | 40/91 [00:02<00:02, 23.68batch/s]
# Validation round:  47%|████▋     | 43/91 [00:02<00:01, 24.48batch/s]
# Validation round:  51%|█████     | 46/91 [00:02<00:01, 25.44batch/s]
# Validation round:  54%|█████▍    | 49/91 [00:02<00:01, 26.06batch/s]
# Validation round:  57%|█████▋    | 52/91 [00:02<00:01, 26.37batch/s]
# Validation round:  60%|██████    | 55/91 [00:02<00:01, 26.80batch/s]
# Validation round:  64%|██████▎   | 58/91 [00:02<00:01, 27.13batch/s]
# Validation round:  67%|██████▋   | 61/91 [00:02<00:01, 27.01batch/s]
# Validation round:  70%|███████   | 64/91 [00:02<00:01, 26.95batch/s]
# Validation round:  74%|███████▎  | 67/91 [00:03<00:00, 26.72batch/s]
# Validation round:  77%|███████▋  | 70/91 [00:03<00:00, 27.08batch/s]
# Validation round:  80%|████████  | 73/91 [00:03<00:00, 27.30batch/s]
# Validation round:  84%|████████▎ | 76/91 [00:03<00:00, 24.20batch/s]
# Validation round:  87%|████████▋ | 79/91 [00:03<00:00, 25.24batch/s]
# Validation round:  90%|█████████ | 82/91 [00:03<00:00, 26.02batch/s]
# Validation round:  93%|█████████▎| 85/91 [00:03<00:00, 23.81batch/s]
# Validation round:  97%|█████████▋| 88/91 [00:03<00:00, 25.00batch/s]
# Validation round: 100%|██████████| 91/91 [00:04<00:00, 23.22batch/s]
#                                                                     INFO: Validation Dice Loss: 0.05521854193328501
# Epoch 1/1:  55%|█████▌    | 3640/6597 [01:48<00:44, 66.66img/s, loss (batch)=0.111]
# Validation round:   0%|          | 0/91 [00:00<?, ?batch/s]
# Validation round:   1%|          | 1/91 [00:00<00:59,  1.52batch/s]
# Validation round:   3%|▎         | 3/91 [00:00<00:41,  2.11batch/s]
# Validation round:   7%|▋         | 6/91 [00:00<00:29,  2.91batch/s]
# Validation round:  10%|▉         | 9/91 [00:00<00:20,  3.96batch/s]
# Validation round:  13%|█▎        | 12/91 [00:01<00:14,  5.33batch/s]
# Validation round:  16%|█▋        | 15/91 [00:01<00:10,  7.04batch/s]
# Validation round:  20%|█▉        | 18/91 [00:01<00:08,  9.06batch/s]
# Validation round:  23%|██▎       | 21/91 [00:01<00:06, 11.36batch/s]
# Validation round:  26%|██▋       | 24/91 [00:01<00:04, 13.81batch/s]
# Validation round:  30%|██▉       | 27/91 [00:01<00:03, 16.18batch/s]
# Validation round:  33%|███▎      | 30/91 [00:01<00:03, 18.34batch/s]
# Validation round:  36%|███▋      | 33/91 [00:01<00:02, 20.30batch/s]
# Validation round:  40%|███▉      | 36/91 [00:01<00:02, 22.08batch/s]
# Validation round:  43%|████▎     | 39/91 [00:02<00:02, 23.61batch/s]
# Validation round:  46%|████▌     | 42/91 [00:02<00:01, 24.72batch/s]
# Validation round:  49%|████▉     | 45/91 [00:02<00:01, 25.60batch/s]
# Validation round:  53%|█████▎    | 48/91 [00:02<00:01, 26.24batch/s]
# Validation round:  56%|█████▌    | 51/91 [00:02<00:01, 26.36batch/s]
# Validation round:  59%|█████▉    | 54/91 [00:02<00:01, 26.40batch/s]
# Validation round:  63%|██████▎   | 57/91 [00:02<00:01, 25.86batch/s]
# Validation round:  66%|██████▌   | 60/91 [00:02<00:01, 25.67batch/s]
# Validation round:  69%|██████▉   | 63/91 [00:03<00:01, 24.67batch/s]
# Validation round:  73%|███████▎  | 66/91 [00:03<00:01, 24.79batch/s]
# Validation round:  76%|███████▌  | 69/91 [00:03<00:00, 25.44batch/s]
# Validation round:  79%|███████▉  | 72/91 [00:03<00:00, 26.01batch/s]
# Validation round:  82%|████████▏ | 75/91 [00:03<00:00, 26.45batch/s]
# Validation round:  86%|████████▌ | 78/91 [00:03<00:00, 26.83batch/s]
# Validation round:  89%|████████▉ | 81/91 [00:03<00:00, 27.12batch/s]
# Validation round:  92%|█████████▏| 84/91 [00:03<00:00, 27.18batch/s]
# Validation round:  96%|█████████▌| 87/91 [00:03<00:00, 27.41batch/s]
# Validation round:  99%|█████████▉| 90/91 [00:03<00:00, 27.62batch/s]
#                                                                     INFO: Validation Dice Loss: 0.04913145139977172
# Epoch 1/1:  66%|██████▌   | 4368/6597 [02:10<00:41, 54.25img/s, loss (batch)=0.107]
# Validation round:   0%|          | 0/91 [00:00<?, ?batch/s]
# Validation round:   1%|          | 1/91 [00:00<01:06,  1.35batch/s]
# Validation round:   4%|▍         | 4/91 [00:00<00:46,  1.89batch/s]
# Validation round:   8%|▊         | 7/91 [00:00<00:32,  2.61batch/s]
# Validation round:  11%|█         | 10/91 [00:01<00:22,  3.57batch/s]
# Validation round:  14%|█▍        | 13/91 [00:01<00:16,  4.83batch/s]
# Validation round:  18%|█▊        | 16/91 [00:01<00:11,  6.40batch/s]
# Validation round:  21%|██        | 19/91 [00:01<00:08,  8.31batch/s]
# Validation round:  24%|██▍       | 22/91 [00:01<00:06, 10.48batch/s]
# Validation round:  27%|██▋       | 25/91 [00:01<00:05, 12.84batch/s]
# Validation round:  31%|███       | 28/91 [00:01<00:04, 15.34batch/s]
# Validation round:  34%|███▍      | 31/91 [00:01<00:03, 17.66batch/s]
# Validation round:  37%|███▋      | 34/91 [00:01<00:02, 19.76batch/s]
# Validation round:  41%|████      | 37/91 [00:02<00:02, 21.55batch/s]
# Validation round:  44%|████▍     | 40/91 [00:02<00:02, 23.00batch/s]
# Validation round:  47%|████▋     | 43/91 [00:02<00:01, 24.13batch/s]
# Validation round:  51%|█████     | 46/91 [00:02<00:01, 24.94batch/s]
# Validation round:  54%|█████▍    | 49/91 [00:02<00:01, 25.63batch/s]
# Validation round:  57%|█████▋    | 52/91 [00:02<00:01, 26.22batch/s]
# Validation round:  60%|██████    | 55/91 [00:02<00:01, 26.74batch/s]
# Validation round:  64%|██████▎   | 58/91 [00:02<00:01, 26.90batch/s]
# Validation round:  67%|██████▋   | 61/91 [00:02<00:01, 27.25batch/s]
# Validation round:  70%|███████   | 64/91 [00:03<00:00, 27.11batch/s]
# Validation round:  74%|███████▎  | 67/91 [00:03<00:00, 27.19batch/s]
# Validation round:  77%|███████▋  | 70/91 [00:03<00:00, 27.28batch/s]
# Validation round:  80%|████████  | 73/91 [00:03<00:00, 23.94batch/s]
# Validation round:  84%|████████▎ | 76/91 [00:03<00:00, 24.94batch/s]
# Validation round:  87%|████████▋ | 79/91 [00:03<00:00, 25.76batch/s]
# Validation round:  90%|█████████ | 82/91 [00:03<00:00, 23.91batch/s]
# Validation round:  93%|█████████▎| 85/91 [00:03<00:00, 25.03batch/s]
# Validation round:  97%|█████████▋| 88/91 [00:04<00:00, 25.85batch/s]
# Validation round: 100%|██████████| 91/91 [00:04<00:00, 22.94batch/s]
#                                                                     INFO: Validation Dice Loss: 0.04742289129849318
# Epoch 1/1:  77%|███████▋  | 5096/6597 [02:31<00:24, 60.27img/s, loss (batch)=0.0996]
# Validation round:   0%|          | 0/91 [00:00<?, ?batch/s]
# Validation round:   1%|          | 1/91 [00:00<01:03,  1.43batch/s]
# Validation round:   4%|▍         | 4/91 [00:00<00:43,  1.99batch/s]
# Validation round:   8%|▊         | 7/91 [00:00<00:30,  2.75batch/s]
# Validation round:  11%|█         | 10/91 [00:01<00:21,  3.76batch/s]
# Validation round:  14%|█▍        | 13/91 [00:01<00:15,  5.08batch/s]
# Validation round:  18%|█▊        | 16/91 [00:01<00:11,  6.73batch/s]
# Validation round:  21%|██        | 19/91 [00:01<00:08,  8.69batch/s]
# Validation round:  24%|██▍       | 22/91 [00:01<00:06, 10.92batch/s]
# Validation round:  27%|██▋       | 25/91 [00:01<00:04, 13.35batch/s]
# Validation round:  31%|███       | 28/91 [00:01<00:03, 15.81batch/s]
# Validation round:  34%|███▍      | 31/91 [00:01<00:03, 18.17batch/s]
# Validation round:  37%|███▋      | 34/91 [00:01<00:02, 19.53batch/s]
# Validation round:  41%|████      | 37/91 [00:02<00:02, 21.35batch/s]
# Validation round:  44%|████▍     | 40/91 [00:02<00:02, 22.74batch/s]
# Validation round:  47%|████▋     | 43/91 [00:02<00:02, 23.90batch/s]
# Validation round:  51%|█████     | 46/91 [00:02<00:01, 24.71batch/s]
# Validation round:  54%|█████▍    | 49/91 [00:02<00:01, 24.80batch/s]
# Validation round:  57%|█████▋    | 52/91 [00:02<00:01, 25.63batch/s]
# Validation round:  60%|██████    | 55/91 [00:02<00:01, 26.13batch/s]
# Validation round:  64%|██████▎   | 58/91 [00:02<00:01, 24.35batch/s]
# Validation round:  67%|██████▋   | 61/91 [00:02<00:01, 24.99batch/s]
# Validation round:  70%|███████   | 64/91 [00:03<00:01, 25.71batch/s]
# Validation round:  74%|███████▎  | 67/91 [00:03<00:01, 23.15batch/s]
# Validation round:  77%|███████▋  | 70/91 [00:03<00:00, 24.27batch/s]
# Validation round:  80%|████████  | 73/91 [00:03<00:00, 23.62batch/s]
# Validation round:  84%|████████▎ | 76/91 [00:03<00:00, 24.61batch/s]
# Validation round:  87%|████████▋ | 79/91 [00:03<00:00, 25.49batch/s]
# Validation round:  90%|█████████ | 82/91 [00:03<00:00, 22.79batch/s]
# Validation round:  93%|█████████▎| 85/91 [00:03<00:00, 24.16batch/s]
# Validation round:  97%|█████████▋| 88/91 [00:04<00:00, 25.24batch/s]
# Validation round: 100%|██████████| 91/91 [00:04<00:00, 24.09batch/s]
#                                                                     INFO: Validation Dice Loss: 0.051301189012579865
# Epoch 1/1:  88%|████████▊ | 5824/6597 [02:52<00:17, 44.88img/s, loss (batch)=0.0989]
# Validation round:   0%|          | 0/91 [00:00<?, ?batch/s]
# Validation round:   1%|          | 1/91 [00:00<01:05,  1.37batch/s]
# Validation round:   4%|▍         | 4/91 [00:00<00:45,  1.92batch/s]
# Validation round:   8%|▊         | 7/91 [00:00<00:31,  2.65batch/s]
# Validation round:  11%|█         | 10/91 [00:01<00:22,  3.63batch/s]
# Validation round:  14%|█▍        | 13/91 [00:01<00:15,  4.91batch/s]
# Validation round:  18%|█▊        | 16/91 [00:01<00:11,  6.49batch/s]
# Validation round:  21%|██        | 19/91 [00:01<00:08,  8.40batch/s]
# Validation round:  24%|██▍       | 22/91 [00:01<00:06, 10.63batch/s]
# Validation round:  27%|██▋       | 25/91 [00:01<00:05, 13.01batch/s]
# Validation round:  31%|███       | 28/91 [00:01<00:04, 15.47batch/s]
# Validation round:  34%|███▍      | 31/91 [00:01<00:03, 17.76batch/s]
# Validation round:  37%|███▋      | 34/91 [00:01<00:02, 19.76batch/s]
# Validation round:  41%|████      | 37/91 [00:02<00:02, 21.52batch/s]
# Validation round:  44%|████▍     | 40/91 [00:02<00:02, 23.00batch/s]
# Validation round:  47%|████▋     | 43/91 [00:02<00:01, 24.23batch/s]
# Validation round:  51%|█████     | 46/91 [00:02<00:01, 25.14batch/s]
# Validation round:  54%|█████▍    | 49/91 [00:02<00:01, 25.76batch/s]
# Validation round:  57%|█████▋    | 52/91 [00:02<00:01, 26.20batch/s]
# Validation round:  60%|██████    | 55/91 [00:02<00:01, 26.39batch/s]
# Validation round:  64%|██████▎   | 58/91 [00:02<00:01, 26.80batch/s]
# Validation round:  67%|██████▋   | 61/91 [00:02<00:01, 27.06batch/s]
# Validation round:  70%|███████   | 64/91 [00:03<00:00, 27.17batch/s]
# Validation round:  74%|███████▎  | 67/91 [00:03<00:00, 27.10batch/s]
# Validation round:  77%|███████▋  | 70/91 [00:03<00:00, 27.29batch/s]
# Validation round:  80%|████████  | 73/91 [00:03<00:00, 27.36batch/s]
# Validation round:  84%|████████▎ | 76/91 [00:03<00:00, 27.30batch/s]
# Validation round:  87%|████████▋ | 79/91 [00:03<00:00, 27.34batch/s]
# Validation round:  90%|█████████ | 82/91 [00:03<00:00, 27.36batch/s]
# Validation round:  93%|█████████▎| 85/91 [00:03<00:00, 27.47batch/s]
# Validation round:  97%|█████████▋| 88/91 [00:03<00:00, 27.49batch/s]
# Validation round: 100%|██████████| 91/91 [00:04<00:00, 27.48batch/s]
#                                                                     INFO: Validation Dice Loss: 0.04353753632896549
# Epoch 1/1:  89%|████████▉ | 5865/6597 [03:02<00:22, 32.16img/s, loss (batch)=0.0971]
# INFO: Checkpoint 1 saved !

# %%
print("configuring plot one")
domain = len(train_scores1)
x_values = [i+1 for i in range(domain)]
plt.title("UNet")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")
plt.plot(x_values, train_scores1, color="blue", label="train")
plt.plot(x_values, val_scores1, color="orange", label="val")
plt.legend()
plt.show()
plt.close()
# Out:
# configuring plot one

# %%
print("configuring plot two")
domain = len(train_scores2)
x_values = [i+1 for i in range(domain)]
plt.title("SL-Net")
plt.xlabel("Mini-epochs")
plt.ylabel("Dice Loss")
plt.plot(x_values, train_scores2, color="blue", label="train")
plt.plot(x_values, val_scores2, color="orange", label="val")
plt.legend()
plt.show()
plt.close()
# Out:
# configuring plot two

# %%
import math

# Create another simulation dataset for test
train_loader = DataLoader(train, batch_size=2, shuffle=False, num_workers=8, pin_memory=True, drop_last=True)
val_loader = DataLoader(val, batch_size=2, shuffle=False, num_workers=8, pin_memory=True, drop_last=True)
test_loader = DataLoader(test, batch_size=2, shuffle=False, num_workers=8, pin_memory=True, drop_last=True)

# Get the first batch
train_batch = next(iter(train_loader))
val_batch = next(iter(val_loader))
test_batch = next(iter(test_loader))

inputs_train = train_batch['image']
labels_train = train_batch['mask']

inputs_val = val_batch['image']
labels_val = val_batch['mask']

inputs_test = test_batch['image']
labels_test = test_batch['mask']

# %%
net1.eval() 
inputs = inputs_train.to(device=device, dtype=torch.float32)
labels = labels_train.to(device=device, dtype=torch.float32)
        

# Predict
pred = net1(inputs)
# The loss functions include the sigmoid function.
pred = torch.argmax(pred, axis=1).unsqueeze(1)
pred = pred.data.cpu().numpy()

input_images_rgb = [x.squeeze(0) for x in inputs.cpu().numpy()]
target_masks_rgb = [x.squeeze(0) for x in labels.cpu().numpy()]
pred_rgb = [x.squeeze(0) for x in pred]

help.plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])

# %%
net1.eval() 
inputs = inputs_val.to(device=device, dtype=torch.float32)
labels = inputs_val.to(device=device, dtype=torch.float32)
        

# Predict
pred = net1(inputs)
# The loss functions include the sigmoid function.
pred = torch.argmax(pred, axis=1).unsqueeze(1)
pred = pred.data.cpu().numpy()

input_images_rgb = [x.squeeze(0) for x in inputs.cpu().numpy()]
target_masks_rgb = [x.squeeze(0) for x in labels.cpu().numpy()]
pred_rgb = [x.squeeze(0) for x in pred]

help.plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])

# %%
net1.eval() 
inputs = inputs_test.to(device=device, dtype=torch.float32)
labels = labels_test.to(device=device, dtype=torch.float32)
        

# Predict
pred = net1(inputs)
# The loss functions include the sigmoid function.
pred = torch.argmax(pred, axis=1).unsqueeze(1)
pred = pred.data.cpu().numpy()

input_images_rgb = [x.squeeze(0) for x in inputs.cpu().numpy()]
target_masks_rgb = [x.squeeze(0) for x in labels.cpu().numpy()]
pred_rgb = [x.squeeze(0) for x in pred]

help.plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])

# %%
net2.eval()
inputs = inputs_train.to(device=device, dtype=torch.float32)
labels = labels_train.to(device=device, dtype=torch.float32)
        

# Predict
pred = net2(inputs)
# The loss functions include the sigmoid function.
pred = torch.argmax(pred, axis=1).unsqueeze(1)
pred = pred.data.cpu().numpy()

input_images_rgb = [x.squeeze(0) for x in inputs.cpu().numpy()]
target_masks_rgb = [x.squeeze(0) for x in labels.cpu().numpy()]
pred_rgb = [x.squeeze(0) for x in pred]

help.plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])

# %%
net2.eval()
inputs = inputs_val.to(device=device, dtype=torch.float32)
labels = labels_val.to(device=device, dtype=torch.float32)
        

# Predict
pred = net2(inputs)
# The loss functions include the sigmoid function.
pred = torch.argmax(pred, axis=1).unsqueeze(1)
pred = pred.data.cpu().numpy()

input_images_rgb = [x.squeeze(0) for x in inputs.cpu().numpy()]
target_masks_rgb = [x.squeeze(0) for x in labels.cpu().numpy()]
pred_rgb = [x.squeeze(0) for x in pred]

help.plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])

# %%
net2.eval()
inputs = inputs_test.to(device=device, dtype=torch.float32)
labels = labels_test.to(device=device, dtype=torch.float32)
        

# Predict
pred = net2(inputs)
# The loss functions include the sigmoid function.
pred = torch.argmax(pred, axis=1).unsqueeze(1)
pred = pred.data.cpu().numpy()

input_images_rgb = [x.squeeze(0) for x in inputs.cpu().numpy()]
target_masks_rgb = [x.squeeze(0) for x in labels.cpu().numpy()]
pred_rgb = [x.squeeze(0) for x in pred]

help.plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])
